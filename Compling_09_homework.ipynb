# %% [markdown]
# # Домашнее задание № 3. Исправление опечаток

# %% [markdown]
# ## 1. Учет грамматики при оценке исправлений (3 балла)
#
# В последнюю итерацию алгоритма для генерации исправлений добавьте еще один компонент - учет грамматической информации. Частично она уже учитывается за счет языковой модели (вероятность предсказывается для словоформы), но такой подход ограничен из-за того, что модель не может ничего предсказать для словоформ, которых не было в обучающей выборке. Чтобы это исправить постройте еще одну "языковую модель" на грамматических тэгах:
# 1) Используя mystem или pymorphy, разметьте какой-нибудь корпус (например, кусок wiki из семинара) или воспользуйтесь уже размеченным корпусом (например, opencorpora)
# 2) соберите униграмные и биграмные статистики на уровне грамматических тэгов (например, вместо `задача важна` у вас будет биграм `S,жен,неод=им,ед A=ед,кр,жен`). Для простоты можете начать только с частеречных тэгов и добавить остальную информацию позже
# 3) напишите функцию, которая будет оценивать вероятность данного предложения на основе грамматической языковой модели (статистик из предыдущего шага). Функция должна сначала преобразовать текст в грамматические тэги, используя точно такой же подход, что использовался на шаге 1.
# 4) в функции correct_text_with_lm замените compute_sentence_proba на вашу новую функцию и прогоните получившийся алгоритм на данных
# 5) сравните предсказания с предсказанием изначального correct_text_with_lm, проверьте метрики и посмотрите на различие в ошибках и исправлениях, найдите несколько примеров отличий в предсказаниях этих подходов

# %%
# !pip install --break-system-packages pymystem3

# !pip install textdistance
# Out:
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pymystem3) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pymystem3) (2025.11.12)
# Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0
# Collecting textdistance
#   Downloading textdistance-4.6.3-py3-none-any.whl.metadata (18 kB)
# Downloading textdistance-4.6.3-py3-none-any.whl (31 kB)
# Installing collected packages: textdistance
# Successfully installed textdistance-4.6.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://opencorpora.org/files/export/annot/annot.opcorpora.no_ambig_strict.xml.bz2
# !unzip '/content/drive/MyDrive/Colab Notebooks/data.zip'
# Out:
# --2025-12-05 18:53:13--  https://opencorpora.org/files/export/annot/annot.opcorpora.no_ambig_strict.xml.bz2
# Resolving opencorpora.org (opencorpora.org)... 104.21.15.199, 172.67.163.210, 2606:4700:3031::ac43:a3d2, ...
# Connecting to opencorpora.org (opencorpora.org)|104.21.15.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1435452 (1.4M) [application/x-bzip2]
# Saving to: ‘annot.opcorpora.no_ambig_strict.xml.bz2’
#
# annot.opcorpora.no_ 100%[===================>]   1.37M  1.21MB/s    in 1.1s
#
# 2025-12-05 18:53:14 (1.21 MB/s) - ‘annot.opcorpora.no_ambig_strict.xml.bz2’ saved [1435452/1435452]
#
# Archive:  /content/drive/MyDrive/Colab Notebooks/data.zip
#   inflating: correct_sents.txt
#   inflating: sents_with_mistakes.txt
#   inflating: wiki_data.txt
#   inflating: __MACOSX/._wiki_data.txt

# %%
import bz2
from lxml import etree
import numpy as np
import itertools
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
from collections import Counter
from string import punctuation
punctuation += "«»—…“”•"
punct = set(punctuation)
from pymystem3 import Mystem
mystem = Mystem()
import textdistance
import re
from tqdm.notebook import tqdm

# %%
bad = open('/content/sents_with_mistakes.txt', encoding='utf-8').read().splitlines()
true = open('/content/correct_sents.txt', encoding='utf-8').read().splitlines()
corpus = open('/content/wiki_data.txt', encoding='utf8').read()

# %%
with bz2.open('annot.opcorpora.no_ambig_strict.xml.bz2', 'rb') as f_in, open('annot.opcorpora.no_ambig_strict.xml', 'wb') as f_out:
    f_out.write(f_in.read())

# %%
open_corpora = etree.fromstring(open('annot.opcorpora.no_ambig_strict.xml', 'rb').read())
vocab = Counter(re.findall('\w+', corpus.lower()))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2346103062.py:2: SyntaxWarning: invalid escape sequence '\w'
#   vocab = Counter(re.findall('\w+', corpus.lower()))

# %%
def multi_tokenizer(corpora):
    tokens_inf = []
    for sentence in corpora.xpath('//tokens'):
        for token in sentence.xpath('token'):
            word = token.xpath('@text')
            if word[0] not in punct:
                gram_info = token.xpath('tfr/v/l/g/@v')
                tokens_inf.append(gram_info)
    return tokens_inf

# %%
def ngrammer(tokens, n=2):
    ngrams = []
    for i in range(len(tokens)-n+1):
        ngrams.append(' '.join(tokens[i:i+n]))
    return ngrams

# %%
def unigram_stat(tokens):
  morpho_dict = Counter()
  for token in tokens:
      morpho_dict[tuple(token)] += 1
  return morpho_dict

# %%
def bigram_stat(tokens):
    morpho_dict = Counter()
    for i in range(len(tokens) - 1):
        morpho_dict[(*tokens[i], *tokens[i+1])] += 1
    return morpho_dict

# %%
def normalize(text):
    normalized_text = [word.strip(punctuation) for word in text.split()]
    normalized_text = [word.lower() for word in normalized_text if word]
    return normalized_text

# %%
corp_inf = multi_tokenizer(open_corpora)
gram_unigrams = unigram_stat(corp_inf)
gram_bigrams = bigram_stat(corp_inf)

# %%
words = normalize(corpus)
word_unigrams = Counter(words)
word_bigrams = Counter(ngrammer(words))

# %%
word2id = list(vocab.keys())
id2word = {i:word for i, word in enumerate(vocab)}


vec = CountVectorizer(analyzer='char', max_features=10000, ngram_range=(1,3))
X = vec.fit_transform(vocab)

# %%
def get_closest_match_vec(text, X, vec, topn=20):
    v = vec.transform([text])

    # вся эффективноть берется из того, что мы сразу считаем близость
    # 1 вектора ко всей матрице (словам в словаре)
    # считать по отдельности циклом было бы дольше
    # вместо одного вектора может даже целая матрица
    # тогда считаться в итоге будет ещё быстрее

    similarities = cosine_distances(v, X)[0]
    topn = similarities.argsort()[:topn]

    return [(id2word[top], similarities[top]) for top in topn]

# %%
def get_closest_match_with_metric(text, lookup, topn=20, metric=textdistance.levenshtein):
    # Counter можно использовать и с не целыми числами
    similarities = Counter()

    for word in lookup:
        similarities[word] = metric.similarity(text, word)

    return similarities.most_common(topn)

# %%
def get_closest_hybrid_match(text, X, vec, topn=3, metric=textdistance.damerau_levenshtein):
    candidates = get_closest_match_vec(text, X, vec, topn*4)
    lookup = [cand[0] for cand in candidates]
    closest = get_closest_match_with_metric(text, lookup, topn, metric=metric)


    return closest

# %%
def mystem_gr_to_tags(gr):
    return tuple(gr.replace('=', ',').split(','))

# %%
def compute_sentence_proba(text, word_counts=gram_unigrams, bigram_counts=gram_bigrams):
    prob = 0
    analyzed = mystem.analyze(text)
    tags_seq = []
    for word in analyzed:
        w = word.get('text', '').strip()
        if w and w not in punct:
            if 'analysis' in word and word['analysis']:
                gr_str = word['analysis'][0]['gr']
                tags = mystem_gr_to_tags(gr_str)
                tags_seq.append(tags)
            else:
                # Слово не разобрано — добавляем UNK
                tags_seq.append(('UNK',))


    seq = [('<start>',)] + tags_seq + [('<end>',)]


    for i in range(len(seq) - 1):
        word1 = seq[i]
        word2 = seq[i + 1]
        bigram_key = word1 + word2

        if word1 in word_counts and bigram_key in bigram_counts:
            prob += np.log(bigram_counts[bigram_key] / word_counts[word1])
        else:
            prob += np.log(2e-5)

    return prob

# %%
def compute_sentence_proba_prev(text, word_counts=word_unigrams, bigram_counts=word_bigrams):
    prob = 0
    tokens = normalize(text)
    for ngram in ngrammer(['<start>'] + tokens + ['<end>']):
        word1, word2 = ngram.split()
        if word1 in word_counts and ngram in bigram_counts:
            prob += np.log(bigram_counts[ngram]/word_counts[word1])
        else:
            prob += np.log(2e-5)

    return prob

# %%
def predict_mistaken(word, vocab):
    return 0 if word in vocab else 1

# %%
def correct_text_with_lm(text, func):
    sentence = normalize(text)
    corrections = []

    for word in sentence:
        if predict_mistaken(word, vocab):
            preds = get_closest_hybrid_match(word, X, vec)
            preds = [p[0] for p in preds]
            corrections.append(preds)
        else:
            corrections.append([word])

    possible_sentences = [" ".join(words) for words in itertools.product(*corrections)]
    most_prob_sentence = max(possible_sentences, key=lambda x: func(x))

    return most_prob_sentence

# %%
for i in range(20):
    cor_gram = correct_text_with_lm(bad[i], compute_sentence_proba)
    cor_class = correct_text_with_lm(bad[i], compute_sentence_proba_prev)

    if cor_gram != cor_class:
        print(bad[i])
        print('Грамматический:')
        print(cor_gram)
        print('Классический:')
        print(cor_class)
        print()
# Out:
# Основая цель мероприятия - практическая отработка навыков по оказанию помощи гражданам, попавшим в ДТП, а также повышение и совершенствование уровня профессиональной подготовки сотрудников МЧС при проведении аварийно-спасательных работ по ликвидации последствий дорожно-транспортных происшествий, сокращение временных показателей реагирования.
# Грамматический:
# сосновая цель мероприятия практическая отработка навыков по оказанию помощи гражданам попавшим в дтп а также повышение и совершенствование уровня профессиональной подготовки сотрудников мчс при проведении горноспасательных работ по ликвидации последствий автотранспортных происшествий сокращение временных показателей реагирования
# Классический:
# сосновая цель мероприятия практическая отработка навыков по оказанию помощи гражданам попавшим в дтп а также повышение и совершенствование уровня профессиональной подготовки сотрудников мчс при проведении спасательных работ по ликвидации последствий транспортных происшествий сокращение временных показателей реагирования
#
# вобщем как вы знаете из моего не давнего поста я жаловался на пропажу писем с моего ящека на почте.ру
# Грамматический:
# всеобщем как вы знаете из моего не давнего поста я жаловался на пропажу писем с моего щека на почте
# Классический:
# общем как вы знаете из моего не давнего поста я жаловался на пропажу писем с моего щека на почте
#
# хороше что на выходгых не было стен, только деревья да ручьи...
# Грамматический:
# хорошее что на выходных не было стен только деревья да ручьи
# Классический:
# хорошее что на выходах не было стен только деревья да ручьи
#
# А Рите снятся сны, в которых меня убивают, патаму шта я пытаюсь всех спасти.
# Грамматический:
# а ритер выяснятся сны в которых меня убивают патами шта я пытаются всех спасти
# Классический:
# а ритер выяснятся сны в которых меня убивают патами шта я пыталась всех спасти

# %%
def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()

    tokens_1 = [token.strip(punctuation) for token in tokens_1]
    tokens_2 = [token.strip(punctuation) for token in tokens_2]

    tokens_1 = [token for token in tokens_1 if token]
    tokens_2 = [token for token in tokens_2 if token]

    assert len(tokens_1) == len(tokens_2)

    return list(zip(tokens_1, tokens_2))

# %%
y_true = []
y_actual = []
y_preds = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    corrected = correct_text_with_lm(bad[i], compute_sentence_proba).split()

    for i in range(len(word_pairs)):
        true_word = word_pairs[i][0]
        actual_word = word_pairs[i][1]
        pred = corrected[i]

        y_preds.append(pred)
        y_true.append(true_word)
        y_actual.append(actual_word)

# %%
def calculate_metrics(true, actual, predicted):
    correct = 0
    total = 0

    total_mistaken = 0
    mistaken_fixed = 0

    total_correct = 0
    correct_broken = 0

    for i in range(len(true)):
        t, a, p = true[i], actual[i], predicted[i]

        # общая точность
        if t == p:
            correct += 1
        total += 1

        # % сломанных правильных слов
        if t == a:
            total_correct += 1
            if t != p:
                correct_broken += 1
        # % процент правильно исправленных настоящих ошибок
        else:
            total_mistaken += 1
            if t == p:
                mistaken_fixed += 1

    return {"total_accuracy": correct/total,
            "fixed_mistakes": mistaken_fixed/total_mistaken,
            "broken_correct_words": correct_broken/total_correct}

# %%
metrics = calculate_metrics(y_true, y_actual, y_preds)
metrics
# Out:
# {'total_accuracy': 0.8480649784997611,
#  'fixed_mistakes': 0.4267399267399267,
#  'broken_correct_words': 0.08873626373626374}

# %% [markdown]
# 'total_accuracy': 0.847223611805903,
#
#  'fixed_mistakes': 0.4231366459627329,
#
#  'broken_correct_words': 0.09004249454461927

# %%
y_true_1 = []
y_actual_1 = []
y_preds_1 = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    corrected = correct_text_with_lm(bad[i], compute_sentence_proba_prev).split()

    for i in range(len(word_pairs)):
        true_word = word_pairs[i][0]
        actual_word = word_pairs[i][1]
        pred = corrected[i]

        y_preds_1.append(pred)
        y_true_1.append(true_word)
        y_actual_1.append(actual_word)

# %%
metrics = calculate_metrics(y_true_1, y_actual_1, y_preds_1)
metrics

# %% [markdown]
# 'total_accuracy': 0.8477238619309655,
#
#  'fixed_mistakes': 0.42701863354037267,
#
#  'broken_correct_words': 0.09004249454461927

# %% [markdown]
# ## 2.  Symspell (5 баллов)

# %% [markdown]
# Реализуйте алгоритм Symspell. Он похож на алгоритм Норвига, но проще и быстрее. Он основан только на одной операции - удалении символа. Описание алгоритма по шагам:
#
# 1) Составляется словарь правильных слов
# 2) На основе словаря правильных слов составляется словарь удалений - для каждого правильного слова создаются все варианты удалений и создается словарь, где ключ - слово с удалением, а значение - правильное слово  (обратите внимание, что для одного удаления может быть несколько правильных слов!)
# 3) При исправлении слова с опечаткой сначала само слово проверятся по словарю удаления, а затем для этого слова генерируются все варианты удалений, и каждый вариант проверяется по словарю удалений. Если в словаре удалений таким образом находится совпадение, то соответствующее ему правильное слово становится исправлением.
# Если совпадений несколько, то выбирается наиболее вероятное правильное слово
#
#
# Оцените качество полученного алгоритма теми же тремя метриками.

# %%
from collections import defaultdict

# %%
N = sum(vocab.values())

def P(word, N=N):
    return vocab[word] / N

# %%
delete_dict = defaultdict(list)

for word in vocab:
    if len(word) >= 2:
        for i in range(len(word)):
            deletion = word[:i] + word[i+1:]
            delete_dict[deletion].append(word)

# %%
def correction(word):

    if word in vocab:
        return word

    candidates = set()

    if word in delete_dict:
        candidates.update(delete_dict[word])

    for i in range(len(word)):
        deletion = word[:i] + word[i+1:]
        if deletion in delete_dict:
            candidates.update(delete_dict[deletion])

    if candidates:
        return max(candidates, key=lambda w: vocab.get(w, 0))

    return word

# %%
cashed = {}
y_true_2 = []
y_actual_2 = []
y_preds_2 = []
for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])

    for pair in word_pairs:
        # чтобы два раза не исправлять одно и тоже слово - закешируем его
        # перед тем как считать исправление проверим нет ли его в кеше

        predicted = cashed.get(pair[1], correction(pair[1]))
        cashed[pair[1]] = predicted
        y_preds_2.append(predicted)
        y_true_2.append(pair[0])
        y_actual_2.append(pair[1])
# Out:
#   0%|          | 0/915 [00:00<?, ?it/s]

# %%
metrics = calculate_metrics(y_true_2, y_actual_2, y_preds_2)

# %%
metrics
# Out:
# {'total_accuracy': 0.8681340670335168,
#  'fixed_mistakes': 0.30745341614906835,
#  'broken_correct_words': 0.04892615137245894}

# %% [markdown]
# 'total_accuracy': 0.8681340670335168,
#
#  'fixed_mistakes': 0.30745341614906835,
#
#  'broken_correct_words': 0.04892615137245894

# %% [markdown]
# # Задание 3 (2 балла)
#
# Используя любой из алгоритмов из семинара или домашки, детально проанализируйте получаемые ошибки. Улучшите алгоритм так, чтобы исправить ошибки. Улучшения в алгоритме должны быть общими, не привязанными к конкретным словам (например, словарь исключений не будет считаться). За каждое улучшение, которое исправляет 5+ ошибок вы получите 0.5 балла (максимум 2 в целом)

# %%
def count_errors_symspell(bad_sents, true_sents, cor_func):

    total_errors = 0
    total_words = 0
    cache = {}

    for i in range(len(true_sents)):
        word_pairs = align_words(true_sents[i], bad_sents[i])
        for true_word, mistaken_word in word_pairs:
            if mistaken_word in cache:
                pred = cache[mistaken_word]
            else:
                pred = cor_func(mistaken_word)
                cache[mistaken_word] = pred

            total_words += 1
            if true_word != pred:
                total_errors += 1
                print(f"{true_word} ← {mistaken_word} → {pred}")

    accuracy = (total_words - total_errors) / total_words if total_words > 0 else 0

    print(f"{total_errors} ошибок из {total_words} слов")
    print(f"Точность: {accuracy:.3f}")

# %%
count_errors_symspell(bad, true, correction)
# Out:
# симпатичнейшее ← симпатичнейшое → симпатичнейшое
# шпионское ← шпионское → шпионской
# гламурный ← гламурный → гламурным
# clap ← clap → camp
# поясним ← пояним → эпоним
# язычки ← язычки → язычок
# очень ← оччччень → оччччень
# насчет ← нащщот → нащщот
# сетуют ← сетуют → сетует
# основная ← основая → основан
# в ← вобщем → вообще
# общем ← как → как
# как ← вы → вы
# вы ← знаете → знаете
# знаете ← из → из
# из ← моего → моего
# моего ← не → не
# недавнего ← давнего → давнего
# ящика ← ящека → щенка
# рите ← рите → риме
# снятся ← снятся → снялся
# потому ← патаму → панаму
# что ← шта → шта
# пытаюсь ← пытаюсь → пытаясь
# дубраве ← дубраве → дубравы
# повтыкав ← поффтыкав → поффтыкав
# билетным ← билетным → билетные
# ссоре ← соре → соре
# что-то ← чтото → торто
# кредиток ← кредиток → кредитов
# кормилицу ← кормилицу → кормилица
# молодежь ← молодеж → молодеж
# участвовать ← учавствовать → учавствовать
# сегодня ← седня → седан
# навешать ← вешать → вешать
# это ← эт → эт
# конечно ← канешна → казнена
# 4:0 ← 4:0 → 400
# начальник ← начальнег → начальное
# зажег ← зажог → залог
# по-взрослому ← павзрослому → павзрослому
# слег ← слег → селе
# ветрянка ← ветрянка → ветряная
# подсаживается ← подсаживаеться → подсаживаеться
# какие-то ← какието → какието
# малолетние ← малолетнии → малолетний
# наркоманы ← наркоманы → наркомана
# молодежь ← молодеж → молодеж
# ощущаю ← ощушаю → ощушаю
# монголоидом ← монголойдом → монголойдом
# молчала ← молчала → молчали
# молчу ← молчю → молча
# сашкой ← сашкой → самкой
# рассчитаны ← расчитаны → рассчитан
# объелись ← обълись → обълись
# веселились ← ввеселились → ввеселились
# расспрашивая ← распрашивая → раскрашивая
# зубодробительная ← зубодробительня → зубодробительня
# гребенка ← гребенка → гребёнка
# как ← каааак → каааак
# хочется ← хочеться → хочеться
# изводить ← изводить → заводить
# письмена ← писмена → истмена
# супермаркете ← супер-маркете → супер-маркете
# серебряные ← серебрянные → серебрянные
# штучка ← штучка → штучки
# самой-то ← самойто → самойло
# тут ← тул → тул
# вообще ← ваще → чаще
# только ← тока → тока
# сынишке ← сынишке → сынишка
# покорми ← покорми → покорил
# очень ← ооочень → ооочень
# яся ← яся → вся
# стараюсь ← стараюсь → стараясь
# как-то ← както → какой
# мужчину ← мущщину → мущщину
# озаботил ← озаботил → заботила
# никогда ← никада → никуда
# очень ← оооочень → оооочень
# симпатическая ← симаатическая → симаатическая
# потовые ← потовые → почтовые
# слюнные ← слюнные → слюнных
# радовала ← радовала → ратовала
# препараты ← припораты → припораты
# расчете ← рассчете → рассвете
# купим ← купим → купил
# странно ← сранно → ранено
# вообще ← вобще → общей
# приветствуется ← приветствутется → приветствутется
# разжился ← расжился → расжился
# сабжа ← сабжа → самба
# однажды ← однажэды → однажэды
# зубные ← зуные → умные
# пользоваться ← пользоваццо → пользоваццо
# доев ← доев → доме
# креатив ← креатифф → креатифф
# экономикса ← экономикса → экономиста
# челка ← челка → белка
# отросла ← отросла → отослал
# естественно ← естесственно → естественной
# обнимает ← однимает → понимает
# основные ← основыные → основыные
# эриды ← эриды → фриды
# получается ← получаеться → получаеться
# разрушается ← разрушаеться → разрушаеться
# координирует ← кроординирует → кроординирует
# движение ← движениие → движением
# правило ← правила → правила
# даешь ← даешь → даёшь
# кстати ← кстате → статей
# приехали ← прихали → приехал
# прочитал ← проичитал → прочитала
# удивленные ← удивленные → удивленный
# нисхождении ← нисхождении → нисхождение
# открываю ← открыывю → открыывю
# написано ← написанно → написанной
# высыпание ← высыпвние → высыпвние
# пересказывать ← перессказывать → перессказывать
# забавен ← забавен → забавно
# хламину ← хламину → хамзину
# пьяный ← пяный → пятый
# фотка ← фотка → флота
# кстати ← кстате → статей
# что-то ← чтото → торто
# напряге ← напряге → напряги
# каталась ← каталась → казалась
# собственно ← собстно → собстно
# рясах ← рясах → рядах
# неосознанно ← неососознанно → неососознанно
# сохраню ← сохраю → сохара
# сыро ← сыро → срок
# вообще ← ваще → чаще
# ад ← ат → ат
# по-прежнему ← попрежнему → попрежнему
# никогда ← никада → никуда
# кстати ← кстате → статей
# позже ← пожже → пожже
# когда-то ← когдато → когдато
# материей ← материей → материке
# отдала ← отадала → отпадала
# вообще ← ваще → чаще
# вообще ← вобще → общей
# молчу ← молчу → молча
# насчет ← нащет → знает
# самый ← самыи → самым
# гадости ← гадости → радости
# на ← но → но
# никак ← не-как → не-как
# обидели ← обидели → обители
# рекомендации ← рекоммендация → рекомендациям
# напроектировали ← напректировали → напректировали
# одноклассниках ← однокласниках → одноклассника
# раскину ← раскину → траскин
# сплю ← сплю → плюс
# вообще ← ваще → чаще
# снежинка ← снежинка → снежинки
# асфальтоукладчик ← афальтоукладчик → афальтоукладчик
# качество ← кчакчество → кчакчество
# зажатия ← зажатия → зачатия
# пупковой ← пупковой → пусковой
# потому ← потму → потом
# разве ← разьве → разьве
# бегущая ← бегущая → берущая
# прикольные ← прикодьные → прикодьные
# собственно ← собстно → собстно
# хочется ← хочеться → хочеться
# посмотреть ← помотрть → помотрть
# хочется ← хочеться → хочеться
# прикольные ← пприкольные → пприкольные
# начните ← начьните → начьните
# он ← онвыгребает → онвыгребает
# выгребает ← ее → ее
# ее ← из → из
# из-под ← под → под
# не ← небыло → небыло
# было ← никогда → никогда
# никогда ← любви → любви
# любви-то ← то → то
# начальник ← начальнег → начальное
# дружился ← дружился → сдружился
# начальнице ← начальнице → начальнике
# зайти ← заити → знати
# вконтакт ← вконтакт → контракт
# ненавидишь ← ненавидшь → ненавидшь
# мыслящая ← мыслящаю → мыслящаю
# убрать ← убрть → убить
# мишуру ← мишуру → мицуру
# процедура ← процедудура → процедудура
# коммунисты ← коммуниисты → коммуниисты
# гордуму ← гордуму → госдуму
# сегодня ← седня → седан
# продавщицу ← продавщицу → продавщица
# очень ← оооочень → оооочень
# бесит ← бесит → бежит
# получается ← получаеться → получаеться
# увольняться ← увольняться → увольняется
# серой ← сером → сером
# рисунком ← рисунко → рисунок
# сухинова ← сухинова → суханова
# продолжение ← продолжения → продолжения
# бякость ← бякость → яркость
# взываю ← взываю → взрыва
# тасовать ← тасовоать → тасовоать
# основной ← основныой → основныой
# очень ← оочень → оочень
# вообще ← вобще → общей
# опаздываю ← опаздываю → опаздывают
# сегодня ← седня → седан
# страшно ← страааашно → страааашно
# нравятся ← нравяться → равняться
# обогреватель ← обогреватель → обозреватель
# окромя ← окромя → покроя
# конечно ← канешна → казнена
# превратит ← превратит → превратить
# фарш ← фарш → фарм
# праздник ← празнег → празнег
# жуть ← жуть → путь
# встретиться ← встретицца → встретицца
# нахожусь ← нажусь → нажусь
# непонятном ← непонятном → непонятным
# закипания ← закипания → залипания
# сайлау ← сайлау → салаку
# вообще ← ваще → чаще
# долго ← дооолго → дооолго
# садиться ← садится → садится
# залпы ← залпы → альпы
# беглянок ← беглянок → беглянку
# серебряном ← серебрянном → серебряному
# сегодня ← седня → седан
# по-любому ← полюбому → полюбому
# ослуживание ← ослуживание → обслуживание
# безупречное ← безупречноне → безупречноне
# ищете ← ищите → ищите
# какого ← какова → какова
# района ← раена → ранен
# объясни ← объясни → объяснил
# продолжительность ← пролжительность → пролжительность
# продул ← продул → продал
# угощали ← угошали → угошали
# открыл ← отркрыл → открыли
# подделанная ← подделаная → поддельная
# подробный ← подрбный → подобный
# обдумываю ← обдумывю → обдумывю
# постинги ← постинги → постигли
# познакомиться ← познакомицца → познакомицца
# монастырь ← монастрырь → монастрырь
# большой ← большое → большое
# кстати ← кстате → статей
# шульга ← шульга → шульца
# не ← незнаю → незнаю
# знаю ← ходить → ходить
# ходить ← на → на
# на ← море → море
# море ← делать → делать
# делать ← ремонт → ремонт
# ремонт ← кого → кого
# кого-нибудь ← нибудь → нибудь
# вообще ← вобще → общей
# сроду ← сроду → среду
# осчастливленный ← ощастливленный → ощастливленный
# выхожу ← выхожу → выходу
# решаем ← решаем → решает
# оным ← оным → зоны
# колой ← колой → около
# спрашиваю ← спрашиваю → спрашивал
# естественно ← естесственно → естественной
# естественно ← естесственно → естественной
# поведайте ← поведйте → поведйте
# плиз ← плиз → близ
# только ← тока → тока
# т.к ← т.к → так
# сушит ← сушит → сушки
# естественно ← естесственно → естественной
# притянулись ← притянулись → протянулись
# естественно ← естесственно → естественной
# нагибается ← нагибается → загибается
# спасибо ← спапсибо → спасибов
# начальник ← начальнег → начальное
# поднимать ← поднмать → понимать
# читаемость ← читаемсоть → читаемсоть
# мальчики ← мальчеги → мальчеги
# присоединяюсь ← присоединаюсь → присоединаюсь
# негодованию ← негодованию → негодование
# это ← ето → что
# вчерашним ← вчерашним → вчерашний
# сегодня ← седня → седан
# лосьончика ← лосьончека → лосьончека
# скучала ← скучала → скучали
# кстати ← кстате → статей
# девкам ← девкам → древка
# 16-17 ← 16-17 → 16417
# парламентский ← парламентський → парламентський
# двухполюсная ← двухполюсная → двухполосная
# привезла ← приезла → привела
# чудище ← чудище → будище
# просвистевшая ← просвестевшая → просвестевшая
# обернуться ← оберутся → доберутся
# 10-15 ← 10-15 → 12015
# матерю ← матерю → матери
# сегодня ← седня → седан
# лишил ← лешил → решил
# касаемо ← касаемо → касемом
# норнштейн ← норнштейн → норштейна
# гордиться ← гордится → гордится
# поссорилась ← посорилась → покорилась
# каким-нибудь ← какимнить → какимнить
# лж ← лж → же
# выложу ← выложу → вылову
# сначала ← сначла → начала
# пластырь ← пластырь → пластыря
# рюкзак ← рюкзазк → рюкзака
# даже ← дае → дае
# нотную ← нотную → ночную
# молчу ← молчу → молча
# вообще ← ваще → чаще
# любое ← любоее → любеке
# паутину ← паути → паути
# непридуманная ← неридуманная → неридуманная
# пересказываю ← перессказываю → перессказываю
# подгрузился ← подргрузился → подргрузился
# основная ← основвная → основвная
# девчонки ← девченки → девченки
# завизжали ← завижжали → завижжали
# бэндом ← бэндом → бондом
# невозможно ← невозмозможно → невозмозможно
# пишите ← пишиите → пишиите
# строятся ← стороятся → торопятся
# привожу ← привожу → приводу
# расчет ← рассчет → рассвет
# кинокомпанией ← кинопокмпанией → кинопокмпанией
# будешь ← будеш → будет
# вообще ← вобще → общей
# естественно ← естесственно → естественной
# преинтереснейшее ← преинтерснейшее → преинтерснейшее
# долго ← дооолго → дооолго
# тянула ← тянула → стянул
# пятиэтажки ← пятиэтажки → пятиэтажек
# я ← мя → мя
# привыкла ← привыкла → привыкли
# именины ← именины → именным
# ползли ← ползли → ползали
# очень ← оооочень → оооочень
# сегодня ← седня → седан
# что ← што → што
# бомжи ← бомжи → боями
# дерущиеся ← дерущиеся → дерущийся
# бомжи ← бомжи → боями
# осталось ← осталалось → оставалось
# статусы ← стратусы → стратусы
# однокурсница ← однокурссница → однокурссница
# аське ← аське → маске
# естественно ← естесственно → естественной
# свалились ← свалились → сжалились
# треснуть ← треснуть → треснуто
# тарусу ← тарусу → тарасу
# естественно ← ессно → тесно
# завтра ← заффтра → заффтра
# попробую ← попробую → попробуй
# зарылась ← зарылась → закрылась
# кстати ← кстате → статей
# получается ← получаеться → получаеться
# неделимое ← неделимое → неделимой
# маршрутки ← маршрутки → маршрутка
# битком ← битком → ситком
# придется ← придеться → придается
# позавчера ← позаввчера → позаввчера
# горбатую ← горбатую → горбатюк
# наконец-то ← наконецто → наконецто
# ручонки ← рученки → ученики
# кнопочки ← кнопачки → кнопачки
# накатать ← накатать → наказать
# прикладываем ← прикладывам → прикладывая
# лобику ← лобику → логику
# извлеченное ← извлеченное → изувеченное
# осматриваем ← осматриваем → осматривает
# следите ← следеите → следеите
# пассажирам ← пасажирам → пассажира
# лежаки ← лежаки → лежали
# деньги ← денги → денги
# отдаются ← отдаються → отдаються
# насчет ← нащет → знает
# трехчасовой ← 3хчасовой → 3хчасовой
# кодексам ← кодексам → кодексом
# заверив ← заверив → завершив
# проставив ← проставив → подставив
# официально ← оффициально → официальном
# поздравляю ← поздравляю → поздравляют
# обрадовались ← обрадовались → образовались
# доброжелательный ← доброжелательный → доброжелательным
# очень ← ооочень → ооочень
# накачанными ← накачанными → наказанными
# прагматично ← прогматично → прогматично
# вообще ← вобще → общей
# общаются ← общаються → общаються
# в ← вобщем → вообще
# общем ← сниццо → сниццо
# снится ← мне → мне
# мне ← что → что
# что ← я → я
# я ← нашел → нашел
# нашел-таки ← таки → таки
# практически ← практичнески → практических
# естественно ← естесственно → естественной
# сволочи ← сволачи → сволачи
# подхожу ← подхожу → похожую
# она ← ана → ана
# как-то ← както → какой
# наливаю ← наливаю → наливают
# кулере ← кулере → кулеры
# смешиваю ← смешиваю → смешивают
# очень ← оооочень → оооочень
# холодная ← холооодная → холооодная
# гостиная ← гостинная → гостинная
# вообще ← ваще → чаще
# долго-долго-долго ← доолго-дооолго-доооолго → доолго-дооолго-доооолго
# насчет ← нащет → знает
# естественно ← ессно → тесно
# экскурсоводы ← эксурсоводы → экскурсовод
# покажут ← покажунт → покажунт
# кино ← кено → кено
# кидал ← кедал → кедра
# кидалы ← кедалы → кедалы
# подскажите ← подскажыте → подскажыте
# кровищи ← кровищщи → кровищщи
# предлагаю ← прердлагаю → предлагают
# нравятся ← нравяться → равняться
# покопаться ← покапаться → показаться
# выхи ← выхи → всхи
# люда ← люда → люди
# очень ← ооочень → ооочень
# рекомендую ← рекокомендую → рекокомендую
# промозгло ← проморзгло → проморзгло
# муторно ← муторно → моторно
# в ← вообщем → вообщем
# общем-то ← то → то
# распределить ← рапредилить → рапредилить
# пекарской ← пекарской → пекарский
# цедру ← цедру → педру
# сушить ← сушить → судить
# кстати ← кстате → статей
# напьешься ← напьешся → напьешся
# соратникам ← соратникам → соратником
# насущного ← нсущного → нсущного
# теоретизированное ← теоретизированое → теоретизированое
# чтобы ← что → что
# больно ← бы → бы
# не ← больно → больно
# было ← небыло → небыло
# хочется ← хочеться → хочеться
# мочь ← мочь → дочь
# это ← ето → что
# одна ← одно → одно
# очень ← оооочень → оооочень
# адски ← аццки → дацки
# способность ← спаособность → способностью
# несколько ← нескольнко → нескольнко
# мамочки ← мааааммоооочкииии → мааааммоооочкииии
# госов ← госов → годов
# нравится ← нравиться → развиться
# осложнен ← осложнен → осложнён
# программка ← програмка → программа
# пресловутая ← преславутая → преславутая
# подкованная ← подкованная → подорванная
# выразился ← вырозился → вывозился
# напомнило ← напоменило → напоменило
# старый ← стааарый → стааарый
# придя ← прийдя → пройдя
# это ← ето → что
# объехав ← обьехав → обьехав
# въехал ← вьехал → выехал
# сандово ← сандово → садовое
# получается ← получаеться → получаеться
# получается ← получаеться → получаеться
# не ← ни → ни
# натянуто ← натянуто → натянуть
# естественно ← естесственно → естественной
# как ← какбы → крабы
# бы ← из → из
# из-под ← под → под
# очень ← ооочень → ооочень
# вообще ← вобще → общей
# новозаветная ← новозаветняя → новозаветняя
# рулит ← рулит → рулет
# это ← ето → что
# это ← ето → что
# обычные ← обычныэ → обычных
# негодные ← негодныэ → негодным
# люблю ← любю → любую
# кефир ← кефир → зефир
# потратить ← потртатить → потртатить
# расчетов ← рассчетов → рассчетов
# неприглядно ← неприглядно → неприглядна
# как-то ← както → какой
# вообще ← ваще → чаще
# бабешку ← бабежку → бабежку
# трепа ← трепа → трека
# нарыть ← нарыть → накрыт
# жемчужинки ← жемчуженки → жемчуженки
# постарее ← постраее → постраее
# придя ← прийдя → пройдя
# сачков ← сачков → саксов
# острове ← острое → острое
# превратиться ← превратититься → превратититься
# смяться ← смяться → сняться
# разжижиться ← разжижиться → разжижаться
# стечь ← стечь → степь
# горестными ← горестными → окрестными
# ссоримся ← ссоримся → ссорится
# правоты ← правоты → правоту
# все-таки ← все-таик → все-таик
# фотки ← фотки → фотия
# наконец-то ← наконецто → наконецто
# наконец-то ← наконецто → наконецто
# фоток ← фоток → поток
# залил ← залил → забил
# что ← че → че
# это ← ето → что
# вообще ← вобще → общей
# утешаюсь ← утешюсь → утешюсь
# ошпаренных ← ошпареных → ошпареных
# пытаюсь ← пыттаюсь → пыттаюсь
# универа ← универа → нившера
# отпраздную ← отпразную → отправную
# отвечу ← отвечу → ответу
# простите ← проостите → проостите
# начали ← начаили → научили
# хочется ← хочеться → хочеться
# кстати ← кстате → статей
# убеждены ← убеждены → убеждена
# полетим ← поелетим → поелетим
# сказала ← скзала → сказал
# советую ← советую → светлую
# вообще ← вобще → общей
# спасибо ← пасиб → пасхи
# сегодня ← седня → седан
# рванина ← рванина → равнина
# со ← сос → сос
# старыми ← тарыми → старым
# встречавшимися ← встречавщимися → встречающимися
# обогреваемый ← обогреваемый → обогреваемые
# солнышком ← солнушком → солнушком
# насчет ← насчт → начат
# меняемся ← меняемся → меняется
# пронзительно ← пронизтельно → пронизтельно
# а-ля ← а-ля → даля
# хочется ← хочеться → хочеться
# теперешний ← теперешний → теперешней
# начальник ← начальнег → начальное
# сегодня ← седня → седан
# чудесный ← чудестный → чудестный
# ждем ← ждем → демо
# напыщенные ← напыщеные → напыщеные
# понедельник ← понедельнег → понедельнег
# продолжаем ← прдолжаем → прдолжаем
# только ← тока → тока
# сегодня ← седня → седан
# прямо ← пррямо → прямой
# пинг-понг ← пингу-понгу → пингу-понгу
# предыстория ← предъистория → предъистория
# творятся ← творятся → творится
# очень ← ооочень → ооочень
# повозиться ← повозиться → подвозится
# сегодня ← седня → седан
# очень ← оочень → оочень
# глюки ← глюки → глюка
# мещанский ← мещанский → мещанской
# добавляю ← добавляю → добавляют
# елку ← елку → реку
# отдирала ← отдирла → отдирла
# бантики ← бантики → балтики
# извини ← извини → извинил
# отдыхаем ← отыхаем → отыхаем
# садиков ← садиков → осадков
# вообще ← вобще → общей
# конечно ← канешно → казнено
# по-любому ← полюбому → полюбому
# пересмотрю ← пересмотрю → пересмотра
# ого-го ← огого → оного
# захожу ← захожу → нахожу
# вообще ← ваще → чаще
# незнакомая ← низакомая → низакомая
# девчонка ← дивченка → дивченка
# погода ← погда → когда
# установится ← установится → становиться
# рекомендуемо ← рекомундуемо → рекомундуемо
# равно ← ровно → ровно
# тахту ← тахту → тарту
# стеллаж ← стеллаж → стеллан
# появляюсь ← появляюсь → появляясь
# шкварчать ← шкворчать → шкворчать
# остальное ← остально → остальной
# ничего ← ниччего → ниччего
# парикмахерском ← парикмахерском → парикмахерскому
# искусстве ← икусстве → искусств
# тогда ← огда → года
# справедливыми ← саправедливыми → саправедливыми
# слезятся ← слезяться → слезяться
# просмотреть ← просмотрет → посмотреть
# очень ← оочень → оочень
# что-то ← чтото → торто
# как-то ← както → какой
# разве ← разьве → разьве
# пескин ← пескин → пекине
# получилась ← получилсась → получилсась
# найдутся ← найдуться → найдуться
# удлинять ← удлинять → удлинить
# т.к ← т.к → так
# очень ← ооочень → ооочень
# раскрытие ← расскрытие → раскрытием
# нашел ← нашол → нашли
# совсем ← сосвсем → сосвсем
# прикольный ← прикольный → привольный
# сигаретным ← сигаретным → сигаретных
# прожигам ← прожегам → прожегам
# мелькающим ← мелькающим → мелькающими
# впереди ← впреди → вперед
# очень ← ооочень → ооочень
# мужчина ← мущщина → мущщина
# нефиг ← нефиг → нефти
# хочется ← хочеться → хочеться
# нелепо ← нелепо → нелепое
# присоединишься ← присоеденишься → присоеденишься
# эх ← ээээххх → ээээххх
# девчонки ← девчонки → девчонка
# очень ← оочень → оочень
# продажа ← продаа → продаж
# путевок ← путевок → путевой
# поздравляю ← поздравяю → поздравяю
# никогда ← никоглда → никоглда
# приколов ← приколов → проколов
# смирительную ← смерительную → смерительную
# дав ← даф → два
# как-то ← както → какой
# отсрочку ← осрочку → строчку
# непроницаемым ← непроницаемым → непроницаемыми
# клевое ← клевое → клерво
# по-любому ← полюбому → полюбому
# сортир ← сортир → сотира
# сегодня ← седня → седан
# винзаводе ← винзаводе → винзавода
# отчаивайся ← отчаивайся → отчаивался
# очень ← ооооочень → ооооочень
# больше ← болше → более
# дергаю ← дергаю → дергач
# нашел ← нашол → нашли
# хочется ← хочеться → хочеться
# горча ← горча → горах
# вообще ← ваще → чаще
# из-за ← из-за → иззат
# трех ← 3ех → тех
# поздравляю ← паздравляю → паздравляю
# это ← ето → что
# лепнина ← лепнина → репнина
# опять ← опяь → пять
# хрен ← хрень → ренье
# скучно ← скууучнооо → скууучнооо
# расчет ← рассчет → рассвет
# ковшей ← ковшей → кровей
# чугуном ← чугуном → чугунов
# как-то ← как → как
# странно ← то → то
# на ← странно → странно
# улице ← на → на
# супер ← улице → улице
# просто ← супер → супер
# а ← просто → просто
# я ← а → а
# целый ← я → я
# день ← целый → целый
# проспала ← день → день
# потом ← проспала → проспала
# уборкой ← потом → потом
# занималась ← уборкой → уборкой
# ну ← занималась → занималась
# в ← ну → ну
# общем ← вобщем → вообще
# низкокалорийное ← низкоколлорийное → низкоколлорийное
# ничего ← ничо → нико
# посмотри ← посмоти → посмоти
# выпей ← выпей → вытей
# танюха ← танюха → танаха
# запропала ← запрапала → запрапала
# расчеты ← рассчеты → рассветы
# стенания ← стенания → стефания
# исключительности ← исключительности → исключительность
# как-то ← както → какой
# подискутировали ← подисскутировали → подисскутировали
# кривоте ← кривоте → кривоти
# люблю ← люблюд → люблюд
# счастлив ← счастлифф → счастлифф
# президент ← прензидент → президента
# рассказик ← рассказег → рассказег
# потянет ← потянет → потянут
# где ← гнде → гнев
# хочется ← хочеться → хочеться
# перезванивает ← презванивает → презванивает
# по-любому ← полюбому → полюбому
# любимый ← любимоый → любимоый
# прогулялся ← пррогулялся → пррогулялся
# пулять ← пулять → гулять
# диабетиков ← диабетиков → диабетиком
# наконец-то ← наконецто → наконецто
# опосля ← опопсля → опопсля
# левостороннее ← левостроннее → левостроннее
# перекрестков ← перекрестков → перекрестком
# выпадет ← выпадет → впадает
# из-за ← изза → миза
# авиабилет ← авиабилет → авиабилете
# напротив ← напрортив → напрортив
# угораздило ← угараздило → угараздило
# кстати ← кстате → статей
# намазываем ← намазывем → намазывем
# остывший ← остывший → остывшей
# фромаж ← фромаж → фромма
# риккота ← риккота → рикотта
# естественно ← естессно → естессно
# встречке ← встречке → встречен
# коридоры ← корридоры → корридоры
# бродили ← бродили → бросили
# ранее ← раннее → раннее
# фотки ← фотки → фотия
# сажусь ← сажусь → самусь
# что-то ← чтото → торто
# рыться ← рыццо → риццо
# хз ← хз → из
# ничего ← ничо → нико
# эксперты ← экперты → эксперт
# хочется ← хочеться → хочеться
# сколько ← скока → скока
# сегодня ← седня → седан
# опухли ← опухли → опухоли
# девчонки ← девченки → девченки
# целоваться ← целоваццо → целоваццо
# неудачники ← неудачнеги → неудачнеги
# спать ← сппать → спасть
# смуглый ← смуглый → смуглой
# погуляем ← погкуляем → погкуляем
# обязательно ← обязаательно → обязательной
# тусовка ← туссовка → трусовка
# обещанные ← обесчанные → обесчанные
# четвертая ← четвртая → четвёртая
# потому ← птому → этому
# сокровенным ← сокровенным → откровенным
# скинь ← скинь → синьи
# аськи ← аськи → маски
# свой ← сво → сво
# батьке ← батьке → батьки
# очередная ← очеренданя → очеренданя
# рассчитаны ← расчитаны → рассчитан
# усыплен ← усыплен → усыплена
# оттуда ← отуда → труда
# кто-то ← ктото → киото
# шлите ← шлите → литве
# папилломавирусы ← папиломавирусы → папиломавирусы
# естественно ← естессно → естессно
# хрень ← хрень → ренье
# комендант ← коммендант → коменданта
# резво ← резво → резко
# подножку ← подножку → подножки
# кстати ← кстате → статей
# утят ← утят → чтят
# адски ← ацки → таки
# патологически ← паталогически → паталогически
# пожелайте ← пожалайте → пожалейте
# улочке ← улочке → улочка
# представьте ← представитьте → представитьте
# разделенный ← разделеннный → разделеннный
# старую ← струю → струю
# только ← толькго → столько
# что ← што → што
# смущение ← смушение → смешение
# одолевает ← одолевает → одолевать
# хочется ← хочеться → хочеться
# ничего ← ничо → нико
# пятница ← пятницца → пятницам
# из-за ← изза → миза
# запарного ← запарного → западного
# вчера ← в4ера → ветра
# вечер ← ве4ер → ветер
# напроситесь ← напрситесь → напрситесь
# оказывается ← оказуеться → оказуеться
# сегодня ← седня → седан
# подойдите ← подойтите → подойтите
# требую ← требую → требуют
# порядочности ← порядочности → порядочность
# естественно ← естесственно → естественной
# лентяев ← лентяев → лентяем
# профессиональные ← проффессиональные → проффессиональные
# какая ← какя → края
# незнакомка ← незнакомка → незнакомца
# берете ← берете → бресте
# стартапу ← страртапу → страртапу
# что ← што → што
# приходится ← приходиться → приходиться
# мелодрамы ← мелодрамми → мелодрамми
# вообще ← вобще → общей
# наконец-то ← наконецто → наконецто
# очень ← ооооочень → ооооочень
# полночи ← полночи → полуночи
# однокурсники ← однокурсники → однокурсника
# могрен ← могрен → морено
# базируемся ← базируемся → базируется
# сажусь ← сажусь → самусь
# купается ← купается → купаться
# молодежь ← молодеж → молодеж
# что-то ← чтото → торто
# вообще ← вобще → общей
# сходили ← схходили → исходили
# скилл ← скилл → силла
# хочется ← хочеться → хочеться
# сегодня ← седня → седан
# шажочки ← шажочки → шапочки
# тьфу ← тьфу → тофу
# сегодня ← седня → седан
# универе ← универе → ниверне
# что ← че → че
# вот ← вооот → ворот
# кстати ← кстате → статей
# 4-х ← 4х → 4х
# фоток ← фоток → поток
# 2-я ← 2-я → 2мя
# фаланги ← фалаги → фланги
# отрезано ← отрезано → отрезаны
# смотрятся ← смотряться → смотреться
# удалить ← удаплить → удаплить
# из-за ← изза → миза
# сердце ← серце → сфере
# недобрый ← недобрый → недобрых
# отбеливание ← отбеливанее → отбеливанее
# кривляться ← кривлятся → кривлятся
# хочется ← хочеться → хочеться
# самодостаточность ← самоодостаточность → самоодостаточность
# разве ← разьве → разьве
# аep ← аep → elp
# 4.29 ← 4.29 → 1429
# кстати ← кстате → статей
# гигов ← гигов → григо
# парализована ← парализованна → парализованна
# что ← чтот → этот
# что-то ← чтото → торто
# в ← у → у
# очень ← ооочень → ооочень
# ненавижу ← неневижу → неневижу
# нельзя ← нельязя → нельязя
# прощать ← прощать → продать
# неверию ← неверию → неверие
# яси ← яси → сил
# скачиваю ← скачиваю → скачивают
# очень ← ооооочень → ооооочень
# плодовита ← плодовита → плодовиты
# цитология ← цитология → цитологии
# сегодня ← седня → седан
# сегодня ← седня → седан
# вещать ← вещать → вмещать
# позитив ← пазитив → пазитив
# очень ← оооочень → оооочень
# обтереть ← обтиреть → обтиреть
# обмахать ← обмахать → помахать
# претендент ← претендет → претендует
# очень ← ооооочень → ооооочень
# повезет ← повезет → повезёт
# проклятые ← прррроклятые → прррроклятые
# буржуи ← буржуи → буржуа
# морить ← морить → мортье
# скачанный ← скачанный → скачанных
# ясей ← ясей → всей
# универ ← универ → унверт
# ведомость ← ведомость → ведомости
# очень ← ооочень → ооочень
# сегодня ← седня → седан
# узбечка ← узбечка → узбекам
# приятно ← притно → приток
# жуть ← жуть → путь
# вообще ← ваще → чаще
# уродские ← уродские → урадские
# поскользнулся ← поскользулся → поскользулся
# юзер ← юзер → юзеф
# хирурге ← хирурге → хирурга
# тигране ← тигране → тиграна
# алексаняне ← алексаняне → алексаняна
# девчонки ← девченки → девченки
# собственно ← собстно → собстно
# посмотрела ← поссмотрела → просмотрела
# бурлака ← бурлака → булавка
# самый ← сааамый → сааамый
# очень-очень ← ооочень-очень → ооочень-очень
# видать ← видать → видеть
# придется ← придеться → придается
# чертов ← чортов → сортов
# онтогенетически ← онтогинетически → онтогинетически
# растолкала ← расталкала → расталкала
# какая-то ← какаято → какаято
# бумажка ← бумажка → бумажку
# пишется ← пишеться → пишеться
# приметы ← прметы → примет
# кстати ← кстате → статей
# едем ← едем → демо
# съемочной ← съемолчной → съемолчной
# напрашиваются ← напрашиваюттся → напрашиваюттся
# уйма ← уйма → шума
# собственно ← собстно → собстно
# передвигалась ← передвигалась → передвигались
# очень ← ооочень → ооочень
# агатов ← агатов → агаков
# тащусь ← ташшусь → ташшусь
# может ← можеть → сможет
# френдам ← френдам → брендам
# вообще ← вобще → общей
# вообще ← ващще → ващще
# подонок ← падонаг → падонаг
# измывается ← измывается → измываться
# неопределенное ← неопределнное → неопределённое
# неопределенное ← неопределенное → неопределённое
# почему-то ← почему → почему
# завис ← то → то
# в ← завис → завес
# общем ← вообщем → вообщем
# в ← вообщем → вообщем
# общем-то ← то → то
# отрисовала ← отрисавала → отрисавала
# кто-то ← ктото → киото
# умудрится ← умудрится → умудрился
# смачно ← смачно → мрачно
# ведь ← веть → есть
# все-таки ← фсе-таки → фсе-таки
# естественно ← естессно → естессно
# получается ← получаеться → получаеться
# потому ← потомучто → потомучто
# что ← просто → просто
# просто ← невозможно → невозможно
# невозможно ← все → все
# все ← это → это
# это ← выместить → выместить
# вместить ← в → в
# в ← карточку → карточку
# карточку ← ну → ну
# ну ← ни → ни
# никак ← как → как
# наверху ← нверху → сверху
# поддерживаем ← поддерживаем → поддерживает
# пожалеть ← пажалеть → пажалеть
# его ← иво → иво
# сочувствие ← сачуствие → сачуствие
# человека ← чилавека → чилавека
# сегодня ← седня → седан
# миллион ← мильон → миньон
# вообще ← ваще → чаще
# творите ← тварите → тварите
# теперь ← терь → тель
# возрастающей ← возростающей → возростающей
# из-за ← из-за → иззат
# напились ← напились → напилась
# вообще ← ваще → чаще
# отлично ← атлична → татлина
# кому-то ← комуто → комуто
# неорганизованная ← неорганизованая → неорганизованая
# организм ← организьм → организма
# смешной ← смешной → смешное
# становится ← становиццо → становиццо
# ватной ← ватной → важной
# наверно ← наврено → навечно
# скрестить ← скрестить → окрестить
# мечи ← мячи → мячи
# сегодня ← сегододня → сегододня
# попытке ← попытки → попытки
# компе ← компе → кроме
# ответственность ← ответствтенность → ответственностью
# осамы ← осамы → самым
# слетел ← члетел → улетел
# рязань ← рязнань → рязанью
# папилломовирус ← папиломовирус → папиломовирус
# сейчас ← ща → ща
# успокоится ← успокоится → успокоился
# ничего ← ничо → нико
# младенцам ← младенцам → младенцем
# адский ← аццкий → шацкий
# меркле ← меркле → меркер
# из-за ← из-за → иззат
# будить ← будить → судить
# ласками ← ласками → масками
# одел ← одел → ходе
# akg ← akg → apg
# что-то ← чтото → торто
# чувствуется ← чувствуеться → чувствуеться
# сегодня ← седня → седан
# геныч ← геныч → гиены
# ползал ← ползал → послал
# предлагаю ← предалагаю → предлагают
# конечно ← канешна → казнена
# солидных ← солидных → солидный
# частников ← частников → участников
# ничего ← ничо → нико
# не ← нне → нне
# тарабарщина ← тарабарщина → тарабарщину
# вообще ← вобще → общей
# почувствовала ← почувстовала → почувствовал
# режиссеру ← режисеру → режиссер
# что ← што → што
# что ← то → то
# когда-то ← когдато → когдато
# естественно ← естесственно → естественной
# сегодня ← седня → седан
# из-за ← изза → миза
# придется ← прийдется → придается
# очень ← ооочень → ооочень
# фотке ← фотке → флоте
# ненавижу ← нинавижу → нинавижу
# девок ← девак → деака
# умилением ← умилением → усилением
# постараюсь ← постарюсь → постарюсь
# приемлемый ← приемлимый → приемлимый
# вообще ← ваще → чаще
# товарищ ← товарисч → товарисч
# сегодня ← седня → седан
# загребла ← загребла → загребля
# пронесла ← пронесла → принесла
# электрокнигу ← электрогнигу → электрогнигу
# как ← каааак → каааак
# гаркнет ← гаркнет → гарнета
# очень ← оооочень → оооочень
# хочется ← хочеца → хочеца
# усиленно ← усиленено → усиленной
# репбазы ← реп → рек
# которые ← базы → базы
# оказались ← которые → которые
# крайне ← оказались → оказались
# близкими ← крайне → крайне
# друзьями ← близкими → близкими
# нежданным ← друзьями → друзьями
# в ← нежданным → нежданные
# общем ← вобщем → вообще
# позитива ← позитива → позитивна
# рок-н-ролла ← рокенрола → рокенрола
# кстати ← кстате → статей
# катином ← катином → актином
# любовь ← любоффь → любоффь
# естественно ← естесственно → естественной
# проанализировали ← проаализировали → проанализировал
# распределили ← распределили → распределяли
# бусинка ← бусинка → гусинка
# хочется ← хочеться → хочеться
# обнимать ← обнимать → понимать
# собранное ← собьранное → собьранное
# натянутое ← натянутое → натянутой
# зажмите ← зажмите → зажгите
# оказалось ← оказалалось → оказалалось
# что ← че → че
# это ← ето → что
# вообще-то ← вобще-то → вобще-то
# фантастические ← фантаститечские → фантаститечские
# вкуснее ← вкуснее → вкусное
# вообще ← вобще → общей
# состояние ← сосотояние → состоянием
# невменяемое ← невменяемое → невменяемой
# слушаются ← слушаются → случаются
# реагируют ← реагирует → реагирует
# очень ← ооооочень → ооооочень
# жутко ← жутко → жуков
# еще ← ишшо → мишо
# симеиз ← симеиз → симери
# обещаю ← обещаю → обещал
# это ← ето → что
# очень ← оооочень → оооочень
# вообще ← ваще → чаще
# черт-те ← черти → черти
# спасибо ← спаааасиб → спаааасиб
# насчет ← нащет → знает
# люблю ← любю → любую
# естественно ← естесственно → естественной
# естественно ← естессно → естессно
# сливает ← сливает → сбивает
# урока ← урока → срока
# сворачиваю ← сварачиваю → сварачиваю
# маминой ← маминой → машиной
# очень ← оооочень → оооочень
# товарищ ← товарисч → товарисч
# компом ← компом → кормом
# определяешься ← определяешся → определяется
# сообщите ← сообщете → сообщает
# как-то ← както → какой
# наберешься ← наберешся → наберешся
# наглости ← наглости → наглость
# позвонишь ← позвонишь → позвонить
# тварь ← тварррь → тварррь
# ничего ← ничо → нико
# товарищ ← товарисч → товарисч
# можно ← можнго → монтго
# расставаньям ← раставаньям → раставаньям
# девчонки ← девченки → девченки
# спускаюсь ← спускюсь → спускюсь
# товарищ ← товарисч → товарисч
# убери ← убери → хубер
# что ← че → че
# извращения ← извращения → извращение
# еще ← ещее → щене
# тысяч ← тыш → тыс
# поздравляю ← поздравлдяю → поздравляют
# давно ← давнооо → давнооо
# посмотрели ← пасмарели → пасмарели
# улыбнулись ← улыбнулись → улыбнулась
# проблемная ← проблемнная → проблемнная
# приехали ← прихали → приехал
# рейсовыми ← рейсовыми → рейковыми
# оттуда ← отуда → труда
# и ← ии → ии
# профилактика ← профилиактика → профилиактика
# комнатки ← комнатки → комнатке
# вообще ← ваще → чаще
# оказывается ← оказываецца → оказываецца
# посочувствовали ← посочуствовали → посочуствовали
# накинулись ← накинулись → наткнулись
# курю ← курю → курс
# порожке ← порожке → дорожке
# спрашиваю ← спрашиваю → спрашивал
# очень ← ооочень → ооочень
# поспишь ← поспшь → поспшь
# непонятных ← непонятнх → непонятно
# объясняла ← объяснала → объяснила
# начальнице ← началнице → началнице
# серебряные ← серебрянные → серебрянные
# вплетал ← вплетал → вылетал
# из-за ← изза → миза
# покажутся ← покажутся → покажется
# куску ← куску → куско
# как-то ← както → какой
# бомжи ← бомжи → боями
# банкроты ← банкроты → банкноты
# юзаю ← юзаю → знаю
# придется ← придеться → придается
# юзать ← юзать → знать
# стесняюсь ← стисняюсь → стисняюсь
# долго ← дооолго → дооолго
# остается ← остаецца → остаецца
# смириться ← смириццо → смириццо
# бороться ← бороццо → бороццо
# 4.60 ← 4.60 → 1460
# что ← што → што
# черный ← чорный → чёрный
# мультики ← мууультики → мууультики
# вернулась ← вернууулась → вернууулась
# рaда ← рааада → рашада
# представьте ← представте → представит
# возьмешь ← возьмешь → возьмёшь
# напишут ← напишут → напишет
# обрызгивается ← оббрызгивается → оббрызгивается
# дешевыми ← дешевыми → душевыми
# потихоньку ← по-тихоньку → по-тихоньку
# планируем ← планируем → планирует
# развиться ← развицо → развито
# кстати ← кстате → статей
# мужчина ← мущщина → мущщина
# молчат ← молчат → молчать
# проверяю ← проверяю → проверяя
# трата ← трата → брата
# вообще ← вобще → общей
# аборигенку ← абоpигенку → абоpигенку
# приезжей ← пpиезжей → пpиезжей
# насчет ← нащет → знает
# свершениям ← свершениям → совершения
# blanca ← blanca → lancia
# поешьте ← поеште → полете
# насчет ← нащет → знает
# yкладываются ← yкладываются → складываются
# тоpмозные ← тоpмозные → тормозные
# котоpых ← котоpых → которых
# не ← ни → ни
# пискнул ← пискнул → рискнул
# вообще ← вобще → общей
# мамином ← мамином → марином
# очень ← ооочень → ооочень
# потрясающая ← потресающия → потресающия
# преподавательница ← преподовательница → преподовательница
# нравятся ← нравяться → равняться
# счастливая ← счастлиывая → счастлиывая
# кошка ← кошшшшка → кошшшшка
# становлюсь ← становлюсь → остановлюсь
# кто-то ← ктото → киото
# кто-то ← ктото → киото
# кто-то ← ктото → киото
# естественно ← естесственно → естественной
# сегодня ← седня → седан
# принципы ← приниципы → приниципы
# применяю ← применяю → применяют
# срываюсь ← срываюсь → срываясь
# естественно ← естесственно → естественной
# одиночеством ← одночеством → одиночество
# блеклым ← блеклым → блеклых
# желаньем ← желаньем → желанием
# просмотр ← просмотер → просмотра
# контакте ← контакти → контракт
# естественно ← естесственно → естественной
# никуда ← нукда → наука
# ответьте ← ответтье → ответить
# адресую ← адресую → андресу
# созваниваемся ← созваниваемся → созванивается
# естественно ← естесственно → естественной
# пробкам ← пробкам → пробках
# минутам ← минутам → минутах
# какие-то ← какие → какие
# плотники ← то → то
# объясняя ← плотники → плотники
# экзаменатору ← объясняя → объясняя
# что ← экзаменатору → экзаменатору
# связались ← что → что
# с ← связались → связались
# ней ← с → с
# через ← ней → ней
# емайл ← через → через
# говорилось ← емайл → майкл
# о ← говорилось → говорилось
# заборе ← о → о
# который ← заборе → заборе
# не ← который → который
# закрывается ← не → не
# затем ← закрывается → закрывается
# зашла ← затем → затем
# не ← зашла → зашла
# знаю ← незнаю → незнаю
# что-то ← чо-то → чо-то
# инете ← инете → интер
# ничего ← ничо → нико
# скажи ← сцкажи → сцкажи
# его ← иво → иво
# шоколаде ← шоколаде → шоколада
# придется ← прийдется → придается
# связываем ← связываем → связывает
# когда-то ← когдато → когдато
# компы ← компы → окопы
# запятых ← запятых → занятых
# матерные ← матерные → матерным
# позаботьтесь ← позабодтесь → позабодтесь
# пофотографировав ← пофоторафировав → пофоторафировав
# волнующие ← волнующие → волнующее
# естественно ← ессно → тесно
# вообще ← ваще → чаще
# постебался ← постибалса → постибалса
# потому ← потсому → поэтому
# сногсшибательной ← сногсшибальной → сногсшибальной
# удается ← удеается → делается
# едкому ← едкому → редком
# аромату ← аромату → аромата
# штабель ← штабель → штюбель
# сумбур ← сумбур → субуры
# это ← эта → эта
# проверка ← провекрка → проверкам
# когда-то ← когдато → когдато
# девчонки ← девченки → девченки
# глянули ← глянули → грянули
# стасу ← стасу → статс
# ливня ← ливня → линия
# мыле ← мыле → мысе
# пытаюсь ← пыраюсь → пыраюсь
# нарезает ← нарезает → нарезают
# непредвиденные ← непридвиденные → непридвиденные
# поздравляю ← поздрваляю → поздрваляю
# говорю ← грю → грю
# ничего ← ничо → нико
# как-то ← както → какой
# хотеться ← хотеццо → хотеццо
# убиться ← убиться → учиться
# веником ← веником → великом
# плинтуса ← плинтуса → плинтусах
# нравится ← нравиццо → нравиццо
# поздравляю ← посдравляю → посдравляю
# очень ← ооочень → ооочень
# погода ← погда → когда
# как ← кааак → казак
# как ← каааак → каааак
# поверхностное ← поверхносное → поверхностно
# неискреннее ← неискренное → неискренное
# мастер-классах ← мастре-классах → мастре-классах
# вот ← воооот → воооот
# хочется ← хочеться → хочеться
# понаобещал ← понаобещщал → понаобещщал
# кстати ← кстате → статей
# неуравновешенно ← неуравновешено → неуравновешено
# центром ← центрм → центра
# сильно ← вильно → вильно
# влево ← влева → слева
# расскажу ← рассказжу → расскажут
# покажи ← покажиииии → покажиииии
# пожинаем ← поженаем → поженаем
# забегаю ← забегаю → забегах
# болтаю ← болтаю → болота
# девчонками ← девочнками → девочнками
# радужном ← радужном → радужным
# маршрутки ← маршрутки → маршрутка
# торбой ← торбой → второй
# 2/3 ← 2/3 → 230
# придется ← придеться → придается
# некоторым ← некотороым → некоторыми
# собственно ← собсно → сосной
# прямо ← пррямо → прямой
# зуб ← ззуб → зубы
# зуб ← ззуб → зубы
# попадает ← поппадает → пропадает
# как-то ← какето → ракето
# мне ← мной → мной
# будешь ← будеш → будет
# свои ← сваи → сваи
# описывать ← аписывать → записывать
# чтоб ← шоб → шоу
# расчет ← рассчет → рассвет
# берем ← берем → берег
# ничего ← ничо → нико
# совладав ← совлаладав → совлаладав
# прочитала ← прочтала → прочитал
# прочитавшие ← прочитавшие → прочитавшей
# жизнь ← жизни → жизни
# очень ← оччень → чечень
# денется ← денется → дерется
# неожиданно ← неожиданнго → неожиданной
# прекратите ← прератите → прекратит
# собственно ← собссно → собссно
# квартирку ← квартирку → квартирке
# вообще ← вобще → общей
# хочется ← хочеться → хочеться
# 1318 ошибок из 9995 слов
# Точность: 0.868

# %% [markdown]
# 1318 ошибок из 9995 слов
#
# Точность: 0.868

# %%
def correction_1(word):

    if not word.isalpha():
        return word
    if any(c.isupper() for c in word[1:]):
        return word

    if word in vocab:
        return word

    candidates = set()

    if word in delete_dict:
        candidates.update(delete_dict[word])

    for i in range(len(word)):
        deletion = word[:i] + word[i+1:]
        if deletion in delete_dict:
            candidates.update(delete_dict[deletion])

    if candidates:
        return max(candidates, key=lambda w: vocab.get(w, 0))

    return word

# %%
count_errors_symspell(bad, true, correction_1)
# Out:
# симпатичнейшее ← симпатичнейшое → симпатичнейшое
# шпионское ← шпионское → шпионской
# гламурный ← гламурный → гламурным
# clap ← clap → camp
# поясним ← пояним → эпоним
# язычки ← язычки → язычок
# очень ← оччччень → оччччень
# насчет ← нащщот → нащщот
# сетуют ← сетуют → сетует
# основная ← основая → основан
# в ← вобщем → вообще
# общем ← как → как
# как ← вы → вы
# вы ← знаете → знаете
# знаете ← из → из
# из ← моего → моего
# моего ← не → не
# недавнего ← давнего → давнего
# ящика ← ящека → щенка
# рите ← рите → риме
# снятся ← снятся → снялся
# потому ← патаму → панаму
# что ← шта → шта
# пытаюсь ← пытаюсь → пытаясь
# дубраве ← дубраве → дубравы
# повтыкав ← поффтыкав → поффтыкав
# билетным ← билетным → билетные
# ссоре ← соре → соре
# что-то ← чтото → торто
# кредиток ← кредиток → кредитов
# кормилицу ← кормилицу → кормилица
# молодежь ← молодеж → молодеж
# участвовать ← учавствовать → учавствовать
# сегодня ← седня → седан
# навешать ← вешать → вешать
# это ← эт → эт
# конечно ← канешна → казнена
# начальник ← начальнег → начальное
# зажег ← зажог → залог
# по-взрослому ← павзрослому → павзрослому
# слег ← слег → селе
# ветрянка ← ветрянка → ветряная
# подсаживается ← подсаживаеться → подсаживаеться
# какие-то ← какието → какието
# малолетние ← малолетнии → малолетний
# наркоманы ← наркоманы → наркомана
# молодежь ← молодеж → молодеж
# ощущаю ← ощушаю → ощушаю
# монголоидом ← монголойдом → монголойдом
# молчала ← молчала → молчали
# молчу ← молчю → молча
# сашкой ← сашкой → самкой
# рассчитаны ← расчитаны → рассчитан
# объелись ← обълись → обълись
# веселились ← ввеселились → ввеселились
# расспрашивая ← распрашивая → раскрашивая
# зубодробительная ← зубодробительня → зубодробительня
# гребенка ← гребенка → гребёнка
# как ← каааак → каааак
# хочется ← хочеться → хочеться
# изводить ← изводить → заводить
# письмена ← писмена → истмена
# супермаркете ← супер-маркете → супер-маркете
# серебряные ← серебрянные → серебрянные
# штучка ← штучка → штучки
# самой-то ← самойто → самойло
# тут ← тул → тул
# вообще ← ваще → чаще
# только ← тока → тока
# сынишке ← сынишке → сынишка
# покорми ← покорми → покорил
# очень ← ооочень → ооочень
# яся ← яся → вся
# стараюсь ← стараюсь → стараясь
# как-то ← както → какой
# мужчину ← мущщину → мущщину
# озаботил ← озаботил → заботила
# никогда ← никада → никуда
# очень ← оооочень → оооочень
# симпатическая ← симаатическая → симаатическая
# потовые ← потовые → почтовые
# слюнные ← слюнные → слюнных
# радовала ← радовала → ратовала
# препараты ← припораты → припораты
# расчете ← рассчете → рассвете
# купим ← купим → купил
# странно ← сранно → ранено
# вообще ← вобще → общей
# приветствуется ← приветствутется → приветствутется
# разжился ← расжился → расжился
# сабжа ← сабжа → самба
# однажды ← однажэды → однажэды
# зубные ← зуные → умные
# пользоваться ← пользоваццо → пользоваццо
# доев ← доев → доме
# креатив ← креатифф → креатифф
# экономикса ← экономикса → экономиста
# челка ← челка → белка
# отросла ← отросла → отослал
# естественно ← естесственно → естественной
# обнимает ← однимает → понимает
# основные ← основыные → основыные
# эриды ← эриды → фриды
# получается ← получаеться → получаеться
# разрушается ← разрушаеться → разрушаеться
# координирует ← кроординирует → кроординирует
# движение ← движениие → движением
# правило ← правила → правила
# даешь ← даешь → даёшь
# кстати ← кстате → статей
# приехали ← прихали → приехал
# прочитал ← проичитал → прочитала
# удивленные ← удивленные → удивленный
# нисхождении ← нисхождении → нисхождение
# открываю ← открыывю → открыывю
# написано ← написанно → написанной
# высыпание ← высыпвние → высыпвние
# пересказывать ← перессказывать → перессказывать
# забавен ← забавен → забавно
# хламину ← хламину → хамзину
# пьяный ← пяный → пятый
# фотка ← фотка → флота
# кстати ← кстате → статей
# что-то ← чтото → торто
# напряге ← напряге → напряги
# каталась ← каталась → казалась
# собственно ← собстно → собстно
# рясах ← рясах → рядах
# неосознанно ← неососознанно → неососознанно
# сохраню ← сохраю → сохара
# сыро ← сыро → срок
# вообще ← ваще → чаще
# ад ← ат → ат
# по-прежнему ← попрежнему → попрежнему
# никогда ← никада → никуда
# кстати ← кстате → статей
# позже ← пожже → пожже
# когда-то ← когдато → когдато
# материей ← материей → материке
# отдала ← отадала → отпадала
# вообще ← ваще → чаще
# вообще ← вобще → общей
# молчу ← молчу → молча
# насчет ← нащет → знает
# самый ← самыи → самым
# гадости ← гадости → радости
# на ← но → но
# никак ← не-как → не-как
# обидели ← обидели → обители
# рекомендации ← рекоммендация → рекомендациям
# напроектировали ← напректировали → напректировали
# одноклассниках ← однокласниках → одноклассника
# раскину ← раскину → траскин
# сплю ← сплю → плюс
# вообще ← ваще → чаще
# снежинка ← снежинка → снежинки
# асфальтоукладчик ← афальтоукладчик → афальтоукладчик
# качество ← кчакчество → кчакчество
# зажатия ← зажатия → зачатия
# пупковой ← пупковой → пусковой
# потому ← потму → потом
# разве ← разьве → разьве
# бегущая ← бегущая → берущая
# прикольные ← прикодьные → прикодьные
# собственно ← собстно → собстно
# хочется ← хочеться → хочеться
# посмотреть ← помотрть → помотрть
# хочется ← хочеться → хочеться
# прикольные ← пприкольные → пприкольные
# начните ← начьните → начьните
# он ← онвыгребает → онвыгребает
# выгребает ← ее → ее
# ее ← из → из
# из-под ← под → под
# не ← небыло → небыло
# было ← никогда → никогда
# никогда ← любви → любви
# любви-то ← то → то
# начальник ← начальнег → начальное
# дружился ← дружился → сдружился
# начальнице ← начальнице → начальнике
# зайти ← заити → знати
# вконтакт ← вконтакт → контракт
# ненавидишь ← ненавидшь → ненавидшь
# мыслящая ← мыслящаю → мыслящаю
# убрать ← убрть → убить
# мишуру ← мишуру → мицуру
# процедура ← процедудура → процедудура
# коммунисты ← коммуниисты → коммуниисты
# гордуму ← гордуму → госдуму
# сегодня ← седня → седан
# продавщицу ← продавщицу → продавщица
# очень ← оооочень → оооочень
# бесит ← бесит → бежит
# получается ← получаеться → получаеться
# увольняться ← увольняться → увольняется
# серой ← сером → сером
# рисунком ← рисунко → рисунок
# сухинова ← сухинова → суханова
# продолжение ← продолжения → продолжения
# бякость ← бякость → яркость
# взываю ← взываю → взрыва
# тасовать ← тасовоать → тасовоать
# основной ← основныой → основныой
# очень ← оочень → оочень
# вообще ← вобще → общей
# опаздываю ← опаздываю → опаздывают
# сегодня ← седня → седан
# страшно ← страааашно → страааашно
# нравятся ← нравяться → равняться
# обогреватель ← обогреватель → обозреватель
# окромя ← окромя → покроя
# конечно ← канешна → казнена
# превратит ← превратит → превратить
# фарш ← фарш → фарм
# праздник ← празнег → празнег
# жуть ← жуть → путь
# встретиться ← встретицца → встретицца
# нахожусь ← нажусь → нажусь
# непонятном ← непонятном → непонятным
# закипания ← закипания → залипания
# сайлау ← сайлау → салаку
# вообще ← ваще → чаще
# долго ← дооолго → дооолго
# садиться ← садится → садится
# залпы ← залпы → альпы
# беглянок ← беглянок → беглянку
# серебряном ← серебрянном → серебряному
# сегодня ← седня → седан
# по-любому ← полюбому → полюбому
# ослуживание ← ослуживание → обслуживание
# безупречное ← безупречноне → безупречноне
# ищете ← ищите → ищите
# какого ← какова → какова
# района ← раена → ранен
# объясни ← объясни → объяснил
# продолжительность ← пролжительность → пролжительность
# продул ← продул → продал
# угощали ← угошали → угошали
# открыл ← отркрыл → открыли
# подделанная ← подделаная → поддельная
# подробный ← подрбный → подобный
# обдумываю ← обдумывю → обдумывю
# постинги ← постинги → постигли
# познакомиться ← познакомицца → познакомицца
# монастырь ← монастрырь → монастрырь
# большой ← большое → большое
# кстати ← кстате → статей
# шульга ← шульга → шульца
# не ← незнаю → незнаю
# знаю ← ходить → ходить
# ходить ← на → на
# на ← море → море
# море ← делать → делать
# делать ← ремонт → ремонт
# ремонт ← кого → кого
# кого-нибудь ← нибудь → нибудь
# вообще ← вобще → общей
# сроду ← сроду → среду
# осчастливленный ← ощастливленный → ощастливленный
# выхожу ← выхожу → выходу
# решаем ← решаем → решает
# оным ← оным → зоны
# колой ← колой → около
# спрашиваю ← спрашиваю → спрашивал
# естественно ← естесственно → естественной
# естественно ← естесственно → естественной
# поведайте ← поведйте → поведйте
# плиз ← плиз → близ
# только ← тока → тока
# сушит ← сушит → сушки
# естественно ← естесственно → естественной
# притянулись ← притянулись → протянулись
# естественно ← естесственно → естественной
# нагибается ← нагибается → загибается
# спасибо ← спапсибо → спасибов
# начальник ← начальнег → начальное
# поднимать ← поднмать → понимать
# читаемость ← читаемсоть → читаемсоть
# мальчики ← мальчеги → мальчеги
# присоединяюсь ← присоединаюсь → присоединаюсь
# негодованию ← негодованию → негодование
# это ← ето → что
# вчерашним ← вчерашним → вчерашний
# сегодня ← седня → седан
# лосьончика ← лосьончека → лосьончека
# скучала ← скучала → скучали
# кстати ← кстате → статей
# девкам ← девкам → древка
# парламентский ← парламентський → парламентський
# двухполюсная ← двухполюсная → двухполосная
# привезла ← приезла → привела
# чудище ← чудище → будище
# просвистевшая ← просвестевшая → просвестевшая
# обернуться ← оберутся → доберутся
# матерю ← матерю → матери
# сегодня ← седня → седан
# лишил ← лешил → решил
# касаемо ← касаемо → касемом
# норнштейн ← норнштейн → норштейна
# гордиться ← гордится → гордится
# поссорилась ← посорилась → покорилась
# каким-нибудь ← какимнить → какимнить
# лж ← лж → же
# выложу ← выложу → вылову
# сначала ← сначла → начала
# пластырь ← пластырь → пластыря
# рюкзак ← рюкзазк → рюкзака
# даже ← дае → дае
# нотную ← нотную → ночную
# молчу ← молчу → молча
# вообще ← ваще → чаще
# любое ← любоее → любеке
# паутину ← паути → паути
# непридуманная ← неридуманная → неридуманная
# пересказываю ← перессказываю → перессказываю
# подгрузился ← подргрузился → подргрузился
# основная ← основвная → основвная
# девчонки ← девченки → девченки
# завизжали ← завижжали → завижжали
# бэндом ← бэндом → бондом
# невозможно ← невозмозможно → невозмозможно
# пишите ← пишиите → пишиите
# строятся ← стороятся → торопятся
# привожу ← привожу → приводу
# расчет ← рассчет → рассвет
# кинокомпанией ← кинопокмпанией → кинопокмпанией
# будешь ← будеш → будет
# вообще ← вобще → общей
# естественно ← естесственно → естественной
# преинтереснейшее ← преинтерснейшее → преинтерснейшее
# долго ← дооолго → дооолго
# тянула ← тянула → стянул
# пятиэтажки ← пятиэтажки → пятиэтажек
# я ← мя → мя
# привыкла ← привыкла → привыкли
# именины ← именины → именным
# ползли ← ползли → ползали
# очень ← оооочень → оооочень
# сегодня ← седня → седан
# что ← што → што
# бомжи ← бомжи → боями
# дерущиеся ← дерущиеся → дерущийся
# бомжи ← бомжи → боями
# осталось ← осталалось → оставалось
# статусы ← стратусы → стратусы
# однокурсница ← однокурссница → однокурссница
# аське ← аське → маске
# естественно ← естесственно → естественной
# свалились ← свалились → сжалились
# треснуть ← треснуть → треснуто
# тарусу ← тарусу → тарасу
# естественно ← ессно → тесно
# завтра ← заффтра → заффтра
# попробую ← попробую → попробуй
# зарылась ← зарылась → закрылась
# кстати ← кстате → статей
# получается ← получаеться → получаеться
# неделимое ← неделимое → неделимой
# маршрутки ← маршрутки → маршрутка
# битком ← битком → ситком
# придется ← придеться → придается
# позавчера ← позаввчера → позаввчера
# горбатую ← горбатую → горбатюк
# наконец-то ← наконецто → наконецто
# ручонки ← рученки → ученики
# кнопочки ← кнопачки → кнопачки
# накатать ← накатать → наказать
# прикладываем ← прикладывам → прикладывая
# лобику ← лобику → логику
# извлеченное ← извлеченное → изувеченное
# осматриваем ← осматриваем → осматривает
# следите ← следеите → следеите
# пассажирам ← пасажирам → пассажира
# лежаки ← лежаки → лежали
# деньги ← денги → денги
# отдаются ← отдаються → отдаються
# насчет ← нащет → знает
# трехчасовой ← 3хчасовой → 3хчасовой
# кодексам ← кодексам → кодексом
# заверив ← заверив → завершив
# проставив ← проставив → подставив
# официально ← оффициально → официальном
# поздравляю ← поздравляю → поздравляют
# обрадовались ← обрадовались → образовались
# доброжелательный ← доброжелательный → доброжелательным
# очень ← ооочень → ооочень
# накачанными ← накачанными → наказанными
# прагматично ← прогматично → прогматично
# вообще ← вобще → общей
# общаются ← общаються → общаються
# в ← вобщем → вообще
# общем ← сниццо → сниццо
# снится ← мне → мне
# мне ← что → что
# что ← я → я
# я ← нашел → нашел
# нашел-таки ← таки → таки
# практически ← практичнески → практических
# естественно ← естесственно → естественной
# сволочи ← сволачи → сволачи
# подхожу ← подхожу → похожую
# она ← ана → ана
# как-то ← както → какой
# наливаю ← наливаю → наливают
# кулере ← кулере → кулеры
# смешиваю ← смешиваю → смешивают
# очень ← оооочень → оооочень
# холодная ← холооодная → холооодная
# гостиная ← гостинная → гостинная
# вообще ← ваще → чаще
# долго-долго-долго ← доолго-дооолго-доооолго → доолго-дооолго-доооолго
# насчет ← нащет → знает
# естественно ← ессно → тесно
# экскурсоводы ← эксурсоводы → экскурсовод
# покажут ← покажунт → покажунт
# кино ← кено → кено
# кидал ← кедал → кедра
# кидалы ← кедалы → кедалы
# подскажите ← подскажыте → подскажыте
# кровищи ← кровищщи → кровищщи
# предлагаю ← прердлагаю → предлагают
# нравятся ← нравяться → равняться
# покопаться ← покапаться → показаться
# выхи ← выхи → всхи
# люда ← люда → люди
# очень ← ооочень → ооочень
# рекомендую ← рекокомендую → рекокомендую
# промозгло ← проморзгло → проморзгло
# муторно ← муторно → моторно
# в ← вообщем → вообщем
# общем-то ← то → то
# распределить ← рапредилить → рапредилить
# пекарской ← пекарской → пекарский
# цедру ← цедру → педру
# сушить ← сушить → судить
# кстати ← кстате → статей
# напьешься ← напьешся → напьешся
# соратникам ← соратникам → соратником
# насущного ← нсущного → нсущного
# теоретизированное ← теоретизированое → теоретизированое
# чтобы ← что → что
# больно ← бы → бы
# не ← больно → больно
# было ← небыло → небыло
# хочется ← хочеться → хочеться
# мочь ← мочь → дочь
# это ← ето → что
# одна ← одно → одно
# очень ← оооочень → оооочень
# адски ← аццки → дацки
# способность ← спаособность → способностью
# несколько ← нескольнко → нескольнко
# мамочки ← мааааммоооочкииии → мааааммоооочкииии
# госов ← госов → годов
# нравится ← нравиться → развиться
# осложнен ← осложнен → осложнён
# программка ← програмка → программа
# пресловутая ← преславутая → преславутая
# подкованная ← подкованная → подорванная
# выразился ← вырозился → вывозился
# напомнило ← напоменило → напоменило
# старый ← стааарый → стааарый
# придя ← прийдя → пройдя
# это ← ето → что
# объехав ← обьехав → обьехав
# въехал ← вьехал → выехал
# сандово ← сандово → садовое
# получается ← получаеться → получаеться
# получается ← получаеться → получаеться
# не ← ни → ни
# натянуто ← натянуто → натянуть
# естественно ← естесственно → естественной
# как ← какбы → крабы
# бы ← из → из
# из-под ← под → под
# очень ← ооочень → ооочень
# вообще ← вобще → общей
# новозаветная ← новозаветняя → новозаветняя
# рулит ← рулит → рулет
# это ← ето → что
# это ← ето → что
# обычные ← обычныэ → обычных
# негодные ← негодныэ → негодным
# люблю ← любю → любую
# кефир ← кефир → зефир
# потратить ← потртатить → потртатить
# расчетов ← рассчетов → рассчетов
# неприглядно ← неприглядно → неприглядна
# как-то ← както → какой
# вообще ← ваще → чаще
# бабешку ← бабежку → бабежку
# трепа ← трепа → трека
# нарыть ← нарыть → накрыт
# жемчужинки ← жемчуженки → жемчуженки
# постарее ← постраее → постраее
# придя ← прийдя → пройдя
# сачков ← сачков → саксов
# острове ← острое → острое
# превратиться ← превратититься → превратититься
# смяться ← смяться → сняться
# разжижиться ← разжижиться → разжижаться
# стечь ← стечь → степь
# горестными ← горестными → окрестными
# ссоримся ← ссоримся → ссорится
# правоты ← правоты → правоту
# все-таки ← все-таик → все-таик
# фотки ← фотки → фотия
# наконец-то ← наконецто → наконецто
# наконец-то ← наконецто → наконецто
# фоток ← фоток → поток
# залил ← залил → забил
# что ← че → че
# это ← ето → что
# вообще ← вобще → общей
# утешаюсь ← утешюсь → утешюсь
# ошпаренных ← ошпареных → ошпареных
# пытаюсь ← пыттаюсь → пыттаюсь
# универа ← универа → нившера
# отпраздную ← отпразную → отправную
# отвечу ← отвечу → ответу
# простите ← проостите → проостите
# начали ← начаили → научили
# хочется ← хочеться → хочеться
# кстати ← кстате → статей
# убеждены ← убеждены → убеждена
# полетим ← поелетим → поелетим
# сказала ← скзала → сказал
# советую ← советую → светлую
# вообще ← вобще → общей
# спасибо ← пасиб → пасхи
# сегодня ← седня → седан
# рванина ← рванина → равнина
# со ← сос → сос
# старыми ← тарыми → старым
# встречавшимися ← встречавщимися → встречающимися
# обогреваемый ← обогреваемый → обогреваемые
# солнышком ← солнушком → солнушком
# насчет ← насчт → начат
# меняемся ← меняемся → меняется
# пронзительно ← пронизтельно → пронизтельно
# хочется ← хочеться → хочеться
# теперешний ← теперешний → теперешней
# начальник ← начальнег → начальное
# сегодня ← седня → седан
# чудесный ← чудестный → чудестный
# ждем ← ждем → демо
# напыщенные ← напыщеные → напыщеные
# понедельник ← понедельнег → понедельнег
# продолжаем ← прдолжаем → прдолжаем
# только ← тока → тока
# сегодня ← седня → седан
# прямо ← пррямо → прямой
# пинг-понг ← пингу-понгу → пингу-понгу
# предыстория ← предъистория → предъистория
# творятся ← творятся → творится
# очень ← ооочень → ооочень
# повозиться ← повозиться → подвозится
# сегодня ← седня → седан
# очень ← оочень → оочень
# глюки ← глюки → глюка
# мещанский ← мещанский → мещанской
# добавляю ← добавляю → добавляют
# елку ← елку → реку
# отдирала ← отдирла → отдирла
# бантики ← бантики → балтики
# извини ← извини → извинил
# отдыхаем ← отыхаем → отыхаем
# садиков ← садиков → осадков
# вообще ← вобще → общей
# конечно ← канешно → казнено
# по-любому ← полюбому → полюбому
# пересмотрю ← пересмотрю → пересмотра
# ого-го ← огого → оного
# захожу ← захожу → нахожу
# вообще ← ваще → чаще
# незнакомая ← низакомая → низакомая
# девчонка ← дивченка → дивченка
# погода ← погда → когда
# установится ← установится → становиться
# рекомендуемо ← рекомундуемо → рекомундуемо
# равно ← ровно → ровно
# тахту ← тахту → тарту
# стеллаж ← стеллаж → стеллан
# появляюсь ← появляюсь → появляясь
# шкварчать ← шкворчать → шкворчать
# остальное ← остально → остальной
# ничего ← ниччего → ниччего
# парикмахерском ← парикмахерском → парикмахерскому
# искусстве ← икусстве → искусств
# тогда ← огда → года
# справедливыми ← саправедливыми → саправедливыми
# слезятся ← слезяться → слезяться
# просмотреть ← просмотрет → посмотреть
# очень ← оочень → оочень
# что-то ← чтото → торто
# как-то ← както → какой
# разве ← разьве → разьве
# пескин ← пескин → пекине
# получилась ← получилсась → получилсась
# найдутся ← найдуться → найдуться
# удлинять ← удлинять → удлинить
# очень ← ооочень → ооочень
# раскрытие ← расскрытие → раскрытием
# нашел ← нашол → нашли
# совсем ← сосвсем → сосвсем
# прикольный ← прикольный → привольный
# сигаретным ← сигаретным → сигаретных
# прожигам ← прожегам → прожегам
# мелькающим ← мелькающим → мелькающими
# впереди ← впреди → вперед
# очень ← ооочень → ооочень
# мужчина ← мущщина → мущщина
# нефиг ← нефиг → нефти
# хочется ← хочеться → хочеться
# нелепо ← нелепо → нелепое
# присоединишься ← присоеденишься → присоеденишься
# эх ← ээээххх → ээээххх
# девчонки ← девчонки → девчонка
# очень ← оочень → оочень
# продажа ← продаа → продаж
# путевок ← путевок → путевой
# поздравляю ← поздравяю → поздравяю
# никогда ← никоглда → никоглда
# приколов ← приколов → проколов
# смирительную ← смерительную → смерительную
# дав ← даф → два
# как-то ← както → какой
# отсрочку ← осрочку → строчку
# непроницаемым ← непроницаемым → непроницаемыми
# клевое ← клевое → клерво
# по-любому ← полюбому → полюбому
# сортир ← сортир → сотира
# сегодня ← седня → седан
# винзаводе ← винзаводе → винзавода
# отчаивайся ← отчаивайся → отчаивался
# очень ← ооооочень → ооооочень
# больше ← болше → более
# дергаю ← дергаю → дергач
# нашел ← нашол → нашли
# хочется ← хочеться → хочеться
# горча ← горча → горах
# вообще ← ваще → чаще
# трех ← 3ех → 3ех
# поздравляю ← паздравляю → паздравляю
# это ← ето → что
# лепнина ← лепнина → репнина
# опять ← опяь → пять
# хрен ← хрень → ренье
# скучно ← скууучнооо → скууучнооо
# расчет ← рассчет → рассвет
# ковшей ← ковшей → кровей
# чугуном ← чугуном → чугунов
# как-то ← как → как
# странно ← то → то
# на ← странно → странно
# улице ← на → на
# супер ← улице → улице
# просто ← супер → супер
# а ← просто → просто
# я ← а → а
# целый ← я → я
# день ← целый → целый
# проспала ← день → день
# потом ← проспала → проспала
# уборкой ← потом → потом
# занималась ← уборкой → уборкой
# ну ← занималась → занималась
# в ← ну → ну
# общем ← вобщем → вообще
# низкокалорийное ← низкоколлорийное → низкоколлорийное
# ничего ← ничо → нико
# посмотри ← посмоти → посмоти
# выпей ← выпей → вытей
# танюха ← танюха → танаха
# запропала ← запрапала → запрапала
# расчеты ← рассчеты → рассветы
# стенания ← стенания → стефания
# исключительности ← исключительности → исключительность
# как-то ← както → какой
# подискутировали ← подисскутировали → подисскутировали
# кривоте ← кривоте → кривоти
# люблю ← люблюд → люблюд
# счастлив ← счастлифф → счастлифф
# президент ← прензидент → президента
# рассказик ← рассказег → рассказег
# потянет ← потянет → потянут
# где ← гнде → гнев
# хочется ← хочеться → хочеться
# перезванивает ← презванивает → презванивает
# по-любому ← полюбому → полюбому
# любимый ← любимоый → любимоый
# прогулялся ← пррогулялся → пррогулялся
# пулять ← пулять → гулять
# диабетиков ← диабетиков → диабетиком
# наконец-то ← наконецто → наконецто
# опосля ← опопсля → опопсля
# левостороннее ← левостроннее → левостроннее
# перекрестков ← перекрестков → перекрестком
# выпадет ← выпадет → впадает
# из-за ← изза → миза
# авиабилет ← авиабилет → авиабилете
# напротив ← напрортив → напрортив
# угораздило ← угараздило → угараздило
# кстати ← кстате → статей
# намазываем ← намазывем → намазывем
# остывший ← остывший → остывшей
# фромаж ← фромаж → фромма
# риккота ← риккота → рикотта
# естественно ← естессно → естессно
# встречке ← встречке → встречен
# коридоры ← корридоры → корридоры
# бродили ← бродили → бросили
# ранее ← раннее → раннее
# фотки ← фотки → фотия
# сажусь ← сажусь → самусь
# что-то ← чтото → торто
# рыться ← рыццо → риццо
# хз ← хз → из
# ничего ← ничо → нико
# эксперты ← экперты → эксперт
# хочется ← хочеться → хочеться
# сколько ← скока → скока
# сегодня ← седня → седан
# опухли ← опухли → опухоли
# девчонки ← девченки → девченки
# целоваться ← целоваццо → целоваццо
# неудачники ← неудачнеги → неудачнеги
# спать ← сппать → спасть
# смуглый ← смуглый → смуглой
# погуляем ← погкуляем → погкуляем
# обязательно ← обязаательно → обязательной
# тусовка ← туссовка → трусовка
# обещанные ← обесчанные → обесчанные
# четвертая ← четвртая → четвёртая
# потому ← птому → этому
# сокровенным ← сокровенным → откровенным
# скинь ← скинь → синьи
# аськи ← аськи → маски
# свой ← сво → сво
# батьке ← батьке → батьки
# очередная ← очеренданя → очеренданя
# рассчитаны ← расчитаны → рассчитан
# усыплен ← усыплен → усыплена
# оттуда ← отуда → труда
# кто-то ← ктото → киото
# шлите ← шлите → литве
# папилломавирусы ← папиломавирусы → папиломавирусы
# естественно ← естессно → естессно
# хрень ← хрень → ренье
# комендант ← коммендант → коменданта
# резво ← резво → резко
# подножку ← подножку → подножки
# кстати ← кстате → статей
# утят ← утят → чтят
# адски ← ацки → таки
# патологически ← паталогически → паталогически
# пожелайте ← пожалайте → пожалейте
# улочке ← улочке → улочка
# представьте ← представитьте → представитьте
# разделенный ← разделеннный → разделеннный
# старую ← струю → струю
# только ← толькго → столько
# что ← што → што
# смущение ← смушение → смешение
# одолевает ← одолевает → одолевать
# хочется ← хочеться → хочеться
# ничего ← ничо → нико
# пятница ← пятницца → пятницам
# из-за ← изза → миза
# запарного ← запарного → западного
# вчера ← в4ера → в4ера
# вечер ← ве4ер → ве4ер
# напроситесь ← напрситесь → напрситесь
# оказывается ← оказуеться → оказуеться
# сегодня ← седня → седан
# подойдите ← подойтите → подойтите
# требую ← требую → требуют
# порядочности ← порядочности → порядочность
# естественно ← естесственно → естественной
# лентяев ← лентяев → лентяем
# профессиональные ← проффессиональные → проффессиональные
# какая ← какя → края
# незнакомка ← незнакомка → незнакомца
# берете ← берете → бресте
# стартапу ← страртапу → страртапу
# что ← што → што
# приходится ← приходиться → приходиться
# мелодрамы ← мелодрамми → мелодрамми
# вообще ← вобще → общей
# наконец-то ← наконецто → наконецто
# очень ← ооооочень → ооооочень
# полночи ← полночи → полуночи
# однокурсники ← однокурсники → однокурсника
# могрен ← могрен → морено
# базируемся ← базируемся → базируется
# сажусь ← сажусь → самусь
# купается ← купается → купаться
# молодежь ← молодеж → молодеж
# что-то ← чтото → торто
# вообще ← вобще → общей
# сходили ← схходили → исходили
# скилл ← скилл → силла
# хочется ← хочеться → хочеться
# сегодня ← седня → седан
# шажочки ← шажочки → шапочки
# тьфу ← тьфу → тофу
# сегодня ← седня → седан
# универе ← универе → ниверне
# что ← че → че
# вот ← вооот → ворот
# кстати ← кстате → статей
# 4-х ← 4х → 4х
# фоток ← фоток → поток
# фаланги ← фалаги → фланги
# отрезано ← отрезано → отрезаны
# смотрятся ← смотряться → смотреться
# удалить ← удаплить → удаплить
# из-за ← изза → миза
# сердце ← серце → сфере
# недобрый ← недобрый → недобрых
# отбеливание ← отбеливанее → отбеливанее
# кривляться ← кривлятся → кривлятся
# хочется ← хочеться → хочеться
# самодостаточность ← самоодостаточность → самоодостаточность
# разве ← разьве → разьве
# аep ← аep → elp
# кстати ← кстате → статей
# гигов ← гигов → григо
# парализована ← парализованна → парализованна
# что ← чтот → этот
# что-то ← чтото → торто
# в ← у → у
# очень ← ооочень → ооочень
# ненавижу ← неневижу → неневижу
# нельзя ← нельязя → нельязя
# прощать ← прощать → продать
# неверию ← неверию → неверие
# яси ← яси → сил
# скачиваю ← скачиваю → скачивают
# очень ← ооооочень → ооооочень
# плодовита ← плодовита → плодовиты
# цитология ← цитология → цитологии
# сегодня ← седня → седан
# сегодня ← седня → седан
# вещать ← вещать → вмещать
# позитив ← пазитив → пазитив
# очень ← оооочень → оооочень
# обтереть ← обтиреть → обтиреть
# обмахать ← обмахать → помахать
# претендент ← претендет → претендует
# очень ← ооооочень → ооооочень
# повезет ← повезет → повезёт
# проклятые ← прррроклятые → прррроклятые
# буржуи ← буржуи → буржуа
# морить ← морить → мортье
# скачанный ← скачанный → скачанных
# ясей ← ясей → всей
# универ ← универ → унверт
# ведомость ← ведомость → ведомости
# очень ← ооочень → ооочень
# сегодня ← седня → седан
# узбечка ← узбечка → узбекам
# приятно ← притно → приток
# жуть ← жуть → путь
# вообще ← ваще → чаще
# уродские ← уродские → урадские
# поскользнулся ← поскользулся → поскользулся
# юзер ← юзер → юзеф
# хирурге ← хирурге → хирурга
# тигране ← тигране → тиграна
# алексаняне ← алексаняне → алексаняна
# девчонки ← девченки → девченки
# собственно ← собстно → собстно
# посмотрела ← поссмотрела → просмотрела
# бурлака ← бурлака → булавка
# самый ← сааамый → сааамый
# очень-очень ← ооочень-очень → ооочень-очень
# видать ← видать → видеть
# придется ← придеться → придается
# чертов ← чортов → сортов
# онтогенетически ← онтогинетически → онтогинетически
# растолкала ← расталкала → расталкала
# какая-то ← какаято → какаято
# бумажка ← бумажка → бумажку
# пишется ← пишеться → пишеться
# приметы ← прметы → примет
# кстати ← кстате → статей
# едем ← едем → демо
# съемочной ← съемолчной → съемолчной
# напрашиваются ← напрашиваюттся → напрашиваюттся
# уйма ← уйма → шума
# собственно ← собстно → собстно
# передвигалась ← передвигалась → передвигались
# очень ← ооочень → ооочень
# агатов ← агатов → агаков
# тащусь ← ташшусь → ташшусь
# может ← можеть → сможет
# френдам ← френдам → брендам
# вообще ← вобще → общей
# вообще ← ващще → ващще
# подонок ← падонаг → падонаг
# измывается ← измывается → измываться
# неопределенное ← неопределнное → неопределённое
# неопределенное ← неопределенное → неопределённое
# почему-то ← почему → почему
# завис ← то → то
# в ← завис → завес
# общем ← вообщем → вообщем
# в ← вообщем → вообщем
# общем-то ← то → то
# отрисовала ← отрисавала → отрисавала
# кто-то ← ктото → киото
# умудрится ← умудрится → умудрился
# смачно ← смачно → мрачно
# ведь ← веть → есть
# все-таки ← фсе-таки → фсе-таки
# естественно ← естессно → естессно
# получается ← получаеться → получаеться
# потому ← потомучто → потомучто
# что ← просто → просто
# просто ← невозможно → невозможно
# невозможно ← все → все
# все ← это → это
# это ← выместить → выместить
# вместить ← в → в
# в ← карточку → карточку
# карточку ← ну → ну
# ну ← ни → ни
# никак ← как → как
# наверху ← нверху → сверху
# поддерживаем ← поддерживаем → поддерживает
# пожалеть ← пажалеть → пажалеть
# его ← иво → иво
# сочувствие ← сачуствие → сачуствие
# человека ← чилавека → чилавека
# сегодня ← седня → седан
# миллион ← мильон → миньон
# вообще ← ваще → чаще
# творите ← тварите → тварите
# теперь ← терь → тель
# возрастающей ← возростающей → возростающей
# напились ← напились → напилась
# вообще ← ваще → чаще
# отлично ← атлична → татлина
# кому-то ← комуто → комуто
# неорганизованная ← неорганизованая → неорганизованая
# организм ← организьм → организма
# смешной ← смешной → смешное
# становится ← становиццо → становиццо
# ватной ← ватной → важной
# наверно ← наврено → навечно
# скрестить ← скрестить → окрестить
# мечи ← мячи → мячи
# сегодня ← сегододня → сегододня
# попытке ← попытки → попытки
# компе ← компе → кроме
# ответственность ← ответствтенность → ответственностью
# осамы ← осамы → самым
# слетел ← члетел → улетел
# рязань ← рязнань → рязанью
# папилломовирус ← папиломовирус → папиломовирус
# сейчас ← ща → ща
# успокоится ← успокоится → успокоился
# ничего ← ничо → нико
# младенцам ← младенцам → младенцем
# адский ← аццкий → шацкий
# меркле ← меркле → меркер
# будить ← будить → судить
# ласками ← ласками → масками
# одел ← одел → ходе
# akg ← akg → apg
# что-то ← чтото → торто
# чувствуется ← чувствуеться → чувствуеться
# сегодня ← седня → седан
# геныч ← геныч → гиены
# ползал ← ползал → послал
# предлагаю ← предалагаю → предлагают
# конечно ← канешна → казнена
# солидных ← солидных → солидный
# частников ← частников → участников
# ничего ← ничо → нико
# не ← нне → нне
# тарабарщина ← тарабарщина → тарабарщину
# вообще ← вобще → общей
# почувствовала ← почувстовала → почувствовал
# режиссеру ← режисеру → режиссер
# что ← што → што
# что ← то → то
# когда-то ← когдато → когдато
# естественно ← естесственно → естественной
# сегодня ← седня → седан
# из-за ← изза → миза
# придется ← прийдется → придается
# очень ← ооочень → ооочень
# фотке ← фотке → флоте
# ненавижу ← нинавижу → нинавижу
# девок ← девак → деака
# умилением ← умилением → усилением
# постараюсь ← постарюсь → постарюсь
# приемлемый ← приемлимый → приемлимый
# вообще ← ваще → чаще
# товарищ ← товарисч → товарисч
# сегодня ← седня → седан
# загребла ← загребла → загребля
# пронесла ← пронесла → принесла
# электрокнигу ← электрогнигу → электрогнигу
# как ← каааак → каааак
# гаркнет ← гаркнет → гарнета
# очень ← оооочень → оооочень
# хочется ← хочеца → хочеца
# усиленно ← усиленено → усиленной
# репбазы ← реп → рек
# которые ← базы → базы
# оказались ← которые → которые
# крайне ← оказались → оказались
# близкими ← крайне → крайне
# друзьями ← близкими → близкими
# нежданным ← друзьями → друзьями
# в ← нежданным → нежданные
# общем ← вобщем → вообще
# позитива ← позитива → позитивна
# рок-н-ролла ← рокенрола → рокенрола
# кстати ← кстате → статей
# катином ← катином → актином
# любовь ← любоффь → любоффь
# естественно ← естесственно → естественной
# проанализировали ← проаализировали → проанализировал
# распределили ← распределили → распределяли
# бусинка ← бусинка → гусинка
# хочется ← хочеться → хочеться
# обнимать ← обнимать → понимать
# собранное ← собьранное → собьранное
# натянутое ← натянутое → натянутой
# зажмите ← зажмите → зажгите
# оказалось ← оказалалось → оказалалось
# что ← че → че
# это ← ето → что
# вообще-то ← вобще-то → вобще-то
# фантастические ← фантаститечские → фантаститечские
# вкуснее ← вкуснее → вкусное
# вообще ← вобще → общей
# состояние ← сосотояние → состоянием
# невменяемое ← невменяемое → невменяемой
# слушаются ← слушаются → случаются
# реагируют ← реагирует → реагирует
# очень ← ооооочень → ооооочень
# жутко ← жутко → жуков
# еще ← ишшо → мишо
# симеиз ← симеиз → симери
# обещаю ← обещаю → обещал
# это ← ето → что
# очень ← оооочень → оооочень
# вообще ← ваще → чаще
# черт-те ← черти → черти
# спасибо ← спаааасиб → спаааасиб
# насчет ← нащет → знает
# люблю ← любю → любую
# естественно ← естесственно → естественной
# естественно ← естессно → естессно
# сливает ← сливает → сбивает
# урока ← урока → срока
# сворачиваю ← сварачиваю → сварачиваю
# маминой ← маминой → машиной
# очень ← оооочень → оооочень
# товарищ ← товарисч → товарисч
# компом ← компом → кормом
# определяешься ← определяешся → определяется
# сообщите ← сообщете → сообщает
# как-то ← както → какой
# наберешься ← наберешся → наберешся
# наглости ← наглости → наглость
# позвонишь ← позвонишь → позвонить
# тварь ← тварррь → тварррь
# ничего ← ничо → нико
# товарищ ← товарисч → товарисч
# можно ← можнго → монтго
# расставаньям ← раставаньям → раставаньям
# девчонки ← девченки → девченки
# спускаюсь ← спускюсь → спускюсь
# товарищ ← товарисч → товарисч
# убери ← убери → хубер
# что ← че → че
# извращения ← извращения → извращение
# еще ← ещее → щене
# тысяч ← тыш → тыс
# поздравляю ← поздравлдяю → поздравляют
# давно ← давнооо → давнооо
# посмотрели ← пасмарели → пасмарели
# улыбнулись ← улыбнулись → улыбнулась
# проблемная ← проблемнная → проблемнная
# приехали ← прихали → приехал
# рейсовыми ← рейсовыми → рейковыми
# оттуда ← отуда → труда
# и ← ии → ии
# профилактика ← профилиактика → профилиактика
# комнатки ← комнатки → комнатке
# вообще ← ваще → чаще
# оказывается ← оказываецца → оказываецца
# посочувствовали ← посочуствовали → посочуствовали
# накинулись ← накинулись → наткнулись
# курю ← курю → курс
# порожке ← порожке → дорожке
# спрашиваю ← спрашиваю → спрашивал
# очень ← ооочень → ооочень
# поспишь ← поспшь → поспшь
# непонятных ← непонятнх → непонятно
# объясняла ← объяснала → объяснила
# начальнице ← началнице → началнице
# серебряные ← серебрянные → серебрянные
# вплетал ← вплетал → вылетал
# из-за ← изза → миза
# покажутся ← покажутся → покажется
# куску ← куску → куско
# как-то ← както → какой
# бомжи ← бомжи → боями
# банкроты ← банкроты → банкноты
# юзаю ← юзаю → знаю
# придется ← придеться → придается
# юзать ← юзать → знать
# стесняюсь ← стисняюсь → стисняюсь
# долго ← дооолго → дооолго
# остается ← остаецца → остаецца
# смириться ← смириццо → смириццо
# бороться ← бороццо → бороццо
# что ← што → што
# черный ← чорный → чёрный
# мультики ← мууультики → мууультики
# вернулась ← вернууулась → вернууулась
# рaда ← рааада → рашада
# представьте ← представте → представит
# возьмешь ← возьмешь → возьмёшь
# напишут ← напишут → напишет
# обрызгивается ← оббрызгивается → оббрызгивается
# дешевыми ← дешевыми → душевыми
# потихоньку ← по-тихоньку → по-тихоньку
# планируем ← планируем → планирует
# развиться ← развицо → развито
# кстати ← кстате → статей
# мужчина ← мущщина → мущщина
# молчат ← молчат → молчать
# проверяю ← проверяю → проверяя
# трата ← трата → брата
# вообще ← вобще → общей
# аборигенку ← абоpигенку → абоpигенку
# приезжей ← пpиезжей → пpиезжей
# насчет ← нащет → знает
# свершениям ← свершениям → совершения
# blanca ← blanca → lancia
# поешьте ← поеште → полете
# насчет ← нащет → знает
# yкладываются ← yкладываются → складываются
# тоpмозные ← тоpмозные → тормозные
# котоpых ← котоpых → которых
# не ← ни → ни
# пискнул ← пискнул → рискнул
# вообще ← вобще → общей
# мамином ← мамином → марином
# очень ← ооочень → ооочень
# потрясающая ← потресающия → потресающия
# преподавательница ← преподовательница → преподовательница
# нравятся ← нравяться → равняться
# счастливая ← счастлиывая → счастлиывая
# кошка ← кошшшшка → кошшшшка
# становлюсь ← становлюсь → остановлюсь
# кто-то ← ктото → киото
# кто-то ← ктото → киото
# кто-то ← ктото → киото
# естественно ← естесственно → естественной
# сегодня ← седня → седан
# принципы ← приниципы → приниципы
# применяю ← применяю → применяют
# срываюсь ← срываюсь → срываясь
# естественно ← естесственно → естественной
# одиночеством ← одночеством → одиночество
# блеклым ← блеклым → блеклых
# желаньем ← желаньем → желанием
# просмотр ← просмотер → просмотра
# контакте ← контакти → контракт
# естественно ← естесственно → естественной
# никуда ← нукда → наука
# ответьте ← ответтье → ответить
# адресую ← адресую → андресу
# созваниваемся ← созваниваемся → созванивается
# естественно ← естесственно → естественной
# пробкам ← пробкам → пробках
# минутам ← минутам → минутах
# какие-то ← какие → какие
# плотники ← то → то
# объясняя ← плотники → плотники
# экзаменатору ← объясняя → объясняя
# что ← экзаменатору → экзаменатору
# связались ← что → что
# с ← связались → связались
# ней ← с → с
# через ← ней → ней
# емайл ← через → через
# говорилось ← емайл → майкл
# о ← говорилось → говорилось
# заборе ← о → о
# который ← заборе → заборе
# не ← который → который
# закрывается ← не → не
# затем ← закрывается → закрывается
# зашла ← затем → затем
# не ← зашла → зашла
# знаю ← незнаю → незнаю
# что-то ← чо-то → чо-то
# инете ← инете → интер
# ничего ← ничо → нико
# скажи ← сцкажи → сцкажи
# его ← иво → иво
# шоколаде ← шоколаде → шоколада
# придется ← прийдется → придается
# связываем ← связываем → связывает
# когда-то ← когдато → когдато
# компы ← компы → окопы
# запятых ← запятых → занятых
# матерные ← матерные → матерным
# позаботьтесь ← позабодтесь → позабодтесь
# пофотографировав ← пофоторафировав → пофоторафировав
# волнующие ← волнующие → волнующее
# естественно ← ессно → тесно
# вообще ← ваще → чаще
# постебался ← постибалса → постибалса
# потому ← потсому → поэтому
# сногсшибательной ← сногсшибальной → сногсшибальной
# удается ← удеается → делается
# едкому ← едкому → редком
# аромату ← аромату → аромата
# штабель ← штабель → штюбель
# сумбур ← сумбур → субуры
# это ← эта → эта
# проверка ← провекрка → проверкам
# когда-то ← когдато → когдато
# девчонки ← девченки → девченки
# глянули ← глянули → грянули
# стасу ← стасу → статс
# ливня ← ливня → линия
# мыле ← мыле → мысе
# пытаюсь ← пыраюсь → пыраюсь
# нарезает ← нарезает → нарезают
# непредвиденные ← непридвиденные → непридвиденные
# поздравляю ← поздрваляю → поздрваляю
# говорю ← грю → грю
# ничего ← ничо → нико
# как-то ← както → какой
# хотеться ← хотеццо → хотеццо
# убиться ← убиться → учиться
# веником ← веником → великом
# плинтуса ← плинтуса → плинтусах
# нравится ← нравиццо → нравиццо
# поздравляю ← посдравляю → посдравляю
# очень ← ооочень → ооочень
# погода ← погда → когда
# как ← кааак → казак
# как ← каааак → каааак
# поверхностное ← поверхносное → поверхностно
# неискреннее ← неискренное → неискренное
# мастер-классах ← мастре-классах → мастре-классах
# вот ← воооот → воооот
# хочется ← хочеться → хочеться
# понаобещал ← понаобещщал → понаобещщал
# кстати ← кстате → статей
# неуравновешенно ← неуравновешено → неуравновешено
# центром ← центрм → центра
# сильно ← вильно → вильно
# влево ← влева → слева
# расскажу ← рассказжу → расскажут
# покажи ← покажиииии → покажиииии
# пожинаем ← поженаем → поженаем
# забегаю ← забегаю → забегах
# болтаю ← болтаю → болота
# девчонками ← девочнками → девочнками
# радужном ← радужном → радужным
# маршрутки ← маршрутки → маршрутка
# торбой ← торбой → второй
# придется ← придеться → придается
# некоторым ← некотороым → некоторыми
# собственно ← собсно → сосной
# прямо ← пррямо → прямой
# зуб ← ззуб → зубы
# зуб ← ззуб → зубы
# попадает ← поппадает → пропадает
# как-то ← какето → ракето
# мне ← мной → мной
# будешь ← будеш → будет
# свои ← сваи → сваи
# описывать ← аписывать → записывать
# чтоб ← шоб → шоу
# расчет ← рассчет → рассвет
# берем ← берем → берег
# ничего ← ничо → нико
# совладав ← совлаладав → совлаладав
# прочитала ← прочтала → прочитал
# прочитавшие ← прочитавшие → прочитавшей
# жизнь ← жизни → жизни
# очень ← оччень → чечень
# денется ← денется → дерется
# неожиданно ← неожиданнго → неожиданной
# прекратите ← прератите → прекратит
# собственно ← собссно → собссно
# квартирку ← квартирку → квартирке
# вообще ← вобще → общей
# хочется ← хочеться → хочеться
# 1305 ошибок из 9995 слов
# Точность: 0.869

# %% [markdown]
# 1305 ошибок из 9995 слов
#
# Точность: 0.869

# %%
def correction_2(word):

    if not word.isalpha():  # содержит цифры, точки, дефисы и т.д.
        return word
    if any(c.isupper() for c in word[1:]):  # CamelCase или случайные заглавные (редко в середине ошибок)
        return word

    if word in vocab:
        return word

    candidates = set()

    if word in delete_dict:
        candidates.update(delete_dict[word])

    for i in range(len(word)):
        deletion = word[:i] + word[i+1:]
        if deletion in delete_dict:
            candidates.update(delete_dict[deletion])


    MIN_FREQ = 13
    candidates = {w for w in candidates if vocab.get(w, 0) >= MIN_FREQ}

    if candidates:
        return max(candidates, key=lambda w: vocab.get(w, 0))

    return word

# %%
count_errors_symspell(bad, true, correction_2)
# Out:
# симпатичнейшее ← симпатичнейшое → симпатичнейшое
# апофеозом ← опофеозом → опофеозом
# поясним ← пояним → пояним
# получатся ← полчатся → полчатся
# очень ← оччччень → оччччень
# насчет ← нащщот → нащщот
# основная ← основая → основан
# напрасно ← нарасно → нарасно
# в ← вобщем → вообще
# общем ← как → как
# как ← вы → вы
# вы ← знаете → знаете
# знаете ← из → из
# из ← моего → моего
# моего ← не → не
# недавнего ← давнего → давнего
# ящика ← ящека → ящека
# предлагаю ← предлагю → предлагю
# сегодняшнее ← сегодяшнее → сегодяшнее
# рите ← рите → риме
# снятся ← снятся → снялся
# потому ← патаму → патаму
# что ← шта → шта
# пытаюсь ← пытаюсь → пытаясь
# повтыкав ← поффтыкав → поффтыкав
# ссоре ← соре → соре
# что-то ← чтото → чтото
# молодежь ← молодеж → молодеж
# участвовать ← учавствовать → учавствовать
# сегодня ← седня → седня
# навешать ← вешать → вешать
# это ← эт → эт
# конечно ← канешна → канешна
# начальник ← начальнег → начальное
# зажег ← зажог → залог
# по-взрослому ← павзрослому → павзрослому
# предыдущую ← предудущую → предудущую
# слег ← слег → селе
# подсаживается ← подсаживаеться → подсаживаеться
# какие-то ← какието → какието
# малолетние ← малолетнии → малолетнии
# молодежь ← молодеж → молодеж
# ощущаю ← ощушаю → ощушаю
# монголоидом ← монголойдом → монголойдом
# молчу ← молчю → молчю
# рассчитаны ← расчитаны → рассчитан
# объелись ← обълись → обълись
# веселились ← ввеселились → ввеселились
# расспрашивая ← распрашивая → распрашивая
# зубодробительная ← зубодробительня → зубодробительня
# как ← каааак → каааак
# хочется ← хочеться → хочеться
# письмена ← писмена → писмена
# супермаркете ← супер-маркете → супер-маркете
# серебряные ← серебрянные → серебрянные
# расшифровать ← расщифровать → расщифровать
# самой-то ← самойто → самойто
# тут ← тул → тул
# вообще ← ваще → чаще
# только ← тока → тока
# очень ← ооочень → ооочень
# яся ← яся → вся
# стараюсь ← стараюсь → стараясь
# как-то ← както → какой
# мужчину ← мущщину → мущщину
# никогда ← никада → никуда
# очень ← оооочень → оооочень
# симпатическая ← симаатическая → симаатическая
# потовые ← потовые → почтовые
# перспектива ← першпектива → першпектива
# препараты ← припораты → припораты
# съездили ← съездели → съездели
# расчете ← рассчете → рассвете
# купим ← купим → купил
# странно ← сранно → ранено
# вообще ← вобще → общей
# приветствуется ← приветствутется → приветствутется
# разжился ← расжился → расжился
# однажды ← однажэды → однажэды
# зубные ← зуные → зуные
# пользоваться ← пользоваццо → пользоваццо
# сочувствующие ← сочуствующие → сочуствующие
# доев ← доев → доме
# креатив ← креатифф → креатифф
# челка ← челка → белка
# естественно ← естесственно → естественной
# обнимает ← однимает → понимает
# основные ← основыные → основыные
# получается ← получаеться → получаеться
# разрушается ← разрушаеться → разрушаеться
# координирует ← кроординирует → кроординирует
# движение ← движениие → движением
# правило ← правила → правила
# кстати ← кстате → статей
# рассказчик ← расказчик → расказчик
# приехали ← прихали → приехал
# прочитал ← проичитал → проичитал
# открываю ← открыывю → открыывю
# написано ← написанно → написанной
# высыпание ← высыпвние → высыпвние
# пересказывать ← перессказывать → перессказывать
# пьяный ← пяный → пятый
# фотка ← фотка → флота
# кстати ← кстате → статей
# что-то ← чтото → чтото
# собственно ← собстно → собстно
# священнослужители ← священослужители → священослужители
# рясах ← рясах → рядах
# неосознанно ← неососознанно → неососознанно
# сохраню ← сохраю → сохраю
# сыро ← сыро → срок
# вообще ← ваще → чаще
# ад ← ат → ат
# по-прежнему ← попрежнему → попрежнему
# никогда ← никада → никуда
# кстати ← кстате → статей
# позже ← пожже → пожже
# когда-то ← когдато → когдато
# отдала ← отадала → отадала
# вообще ← ваще → чаще
# вообще ← вобще → общей
# насчет ← нащет → знает
# гулливера ← гуливера → гуливера
# самый ← самыи → самым
# гадости ← гадости → радости
# на ← но → но
# никак ← не-как → не-как
# обидели ← обидели → обители
# рекомендации ← рекоммендация → рекоммендация
# напроектировали ← напректировали → напректировали
# одноклассниках ← однокласниках → однокласниках
# сплю ← сплю → плюс
# вообще ← ваще → чаще
# асфальтоукладчик ← афальтоукладчик → афальтоукладчик
# качество ← кчакчество → кчакчество
# зажатия ← зажатия → зачатия
# потому ← потму → потом
# разве ← разьве → разьве
# прикольные ← прикодьные → прикодьные
# одноклассников ← однокласников → однокласников
# собственно ← собстно → собстно
# хочется ← хочеться → хочеться
# посмотреть ← помотрть → помотрть
# хочется ← хочеться → хочеться
# прикольные ← пприкольные → пприкольные
# начните ← начьните → начьните
# он ← онвыгребает → онвыгребает
# выгребает ← ее → ее
# ее ← из → из
# из-под ← под → под
# не ← небыло → небыло
# было ← никогда → никогда
# никогда ← любви → любви
# любви-то ← то → то
# мужиков ← мужуков → мужуков
# сегодняшние ← сегодяшние → сегодяшние
# начальник ← начальнег → начальное
# зайти ← заити → знати
# вконтакт ← вконтакт → контракт
# ненавидишь ← ненавидшь → ненавидшь
# мыслящая ← мыслящаю → мыслящаю
# убрать ← убрть → убить
# процедура ← процедудура → процедудура
# коммунисты ← коммуниисты → коммуниисты
# сегодня ← седня → седня
# ответственно ← ответсвенно → ответсвенно
# очень ← оооочень → оооочень
# бесит ← бесит → бежит
# получается ← получаеться → получаеться
# серой ← сером → сером
# рисунком ← рисунко → рисунок
# продолжение ← продолжения → продолжения
# бякость ← бякость → яркость
# взываю ← взываю → взрыва
# тасовать ← тасовоать → тасовоать
# основной ← основныой → основныой
# очень ← оочень → оочень
# вообще ← вобще → общей
# сегодня ← седня → седня
# страшно ← страааашно → страааашно
# нравятся ← нравяться → нравяться
# обогреватель ← обогреватель → обозреватель
# конечно ← канешна → канешна
# превратит ← превратит → превратить
# фарш ← фарш → фарм
# праздник ← празнег → празнег
# жуть ← жуть → путь
# встретиться ← встретицца → встретицца
# нахожусь ← нажусь → нажусь
# вообще ← ваще → чаще
# долго ← дооолго → дооолго
# садиться ← садится → садится
# залпы ← залпы → альпы
# серебряном ← серебрянном → серебрянном
# сегодня ← седня → седня
# по-любому ← полюбому → полюбому
# ослуживание ← ослуживание → обслуживание
# безупречное ← безупречноне → безупречноне
# ищете ← ищите → ищите
# какого ← какова → какова
# района ← раена → ранен
# объясни ← объясни → объяснил
# продолжительность ← пролжительность → пролжительность
# симпатичный ← симпотичный → симпотичный
# продул ← продул → продал
# угощали ← угошали → угошали
# открыл ← отркрыл → открыли
# подделанная ← подделаная → подделаная
# подробный ← подрбный → подобный
# обдумываю ← обдумывю → обдумывю
# познакомиться ← познакомицца → познакомицца
# монастырь ← монастрырь → монастрырь
# большой ← большое → большое
# кстати ← кстате → статей
# не ← незнаю → незнаю
# знаю ← ходить → ходить
# ходить ← на → на
# на ← море → море
# море ← делать → делать
# делать ← ремонт → ремонт
# ремонт ← кого → кого
# кого-нибудь ← нибудь → нибудь
# вообще ← вобще → общей
# сроду ← сроду → среду
# осчастливленный ← ощастливленный → ощастливленный
# выхожу ← выхожу → выходу
# решаем ← решаем → решает
# оным ← оным → зоны
# колой ← колой → около
# естественно ← естесственно → естественной
# естественно ← естесственно → естественной
# поведайте ← поведйте → поведйте
# плиз ← плиз → близ
# только ← тока → тока
# естественно ← естесственно → естественной
# естественно ← естесственно → естественной
# спасибо ← спапсибо → спапсибо
# начальник ← начальнег → начальное
# поднимать ← поднмать → понимать
# читаемость ← читаемсоть → читаемсоть
# мальчики ← мальчеги → мальчеги
# работодатели ← работадатели → работадатели
# присоединяюсь ← присоединаюсь → присоединаюсь
# это ← ето → что
# сегодня ← седня → седня
# лосьончика ← лосьончека → лосьончека
# кстати ← кстате → статей
# девкам ← девкам → древка
# парламентский ← парламентський → парламентський
# привезла ← приезла → привела
# просвистевшая ← просвестевшая → просвестевшая
# обернуться ← оберутся → оберутся
# матерю ← матерю → матери
# сегодня ← седня → седня
# лишил ← лешил → решил
# постарайтесь ← постарайтеь → постарайтеь
# сумасшедшего ← сумашедшего → сумашедшего
# извините ← извените → извените
# чувствовалась ← чувстовалась → чувстовалась
# гордиться ← гордится → гордится
# поссорилась ← посорилась → посорилась
# каким-нибудь ← какимнить → какимнить
# лж ← лж → же
# сначала ← сначла → начала
# рюкзак ← рюкзазк → рюкзазк
# даже ← дае → дае
# вообще ← ваще → чаще
# мозаика ← мозайка → мозайка
# любое ← любоее → любоее
# паутину ← паути → паути
# непридуманная ← неридуманная → неридуманная
# пересказываю ← перессказываю → перессказываю
# подгрузился ← подргрузился → подргрузился
# основная ← основвная → основвная
# набирала ← наберала → наберала
# девчонки ← девченки → девченки
# завизжали ← завижжали → завижжали
# невозможно ← невозмозможно → невозмозможно
# пишите ← пишиите → пишиите
# неоднозначное ← неодназначное → неодназначное
# строятся ← стороятся → стороятся
# расчет ← рассчет → рассвет
# эмоциональная ← эмоциональаня → эмоциональаня
# кинокомпанией ← кинопокмпанией → кинопокмпанией
# будешь ← будеш → будет
# вообще ← вобще → общей
# естественно ← естесственно → естественной
# преинтереснейшее ← преинтерснейшее → преинтерснейшее
# долго ← дооолго → дооолго
# я ← мя → мя
# привыкла ← привыкла → привыкли
# именины ← именины → именным
# очень ← оооочень → оооочень
# сегодня ← седня → седня
# что ← што → што
# бомжи ← бомжи → боями
# бомжи ← бомжи → боями
# осталось ← осталалось → оставалось
# статусы ← стратусы → стратусы
# смешные ← смшные → смшные
# однокурсница ← однокурссница → однокурссница
# аське ← аське → маске
# естественно ← естесственно → естественной
# естественно ← ессно → тесно
# завтра ← заффтра → заффтра
# кстати ← кстате → статей
# получается ← получаеться → получаеться
# придется ← придеться → придеться
# позавчера ← позаввчера → позаввчера
# наконец-то ← наконецто → наконецто
# ручонки ← рученки → ученики
# кнопочки ← кнопачки → кнопачки
# прикладываем ← прикладывам → прикладывам
# следите ← следеите → следеите
# пассажирам ← пасажирам → пассажира
# лежаки ← лежаки → лежали
# любопытства ← любопатства → любопатства
# деньги ← денги → денги
# отдаются ← отдаються → отдаються
# замечательные ← замечаельные → замечаельные
# насчет ← нащет → знает
# отбеливания ← отбеливание → отбеливание
# трехчасовой ← 3хчасовой → 3хчасовой
# кодексам ← кодексам → кодексом
# заверив ← заверив → завершив
# официально ← оффициально → официальном
# обрадовались ← обрадовались → образовались
# очень ← ооочень → ооочень
# прагматично ← прогматично → прогматично
# вообще ← вобще → общей
# общаются ← общаються → общаються
# соедините ← соедените → соедените
# в ← вобщем → вообще
# общем ← сниццо → сниццо
# снится ← мне → мне
# мне ← что → что
# что ← я → я
# я ← нашел → нашел
# нашел-таки ← таки → таки
# практически ← практичнески → практических
# естественно ← естесственно → естественной
# сволочи ← сволачи → сволачи
# она ← ана → ана
# стрельбище ← стельбище → стельбище
# как-то ← както → какой
# очень ← оооочень → оооочень
# холодная ← холооодная → холооодная
# гостиная ← гостинная → гостинная
# вообще ← ваще → чаще
# долго-долго-долго ← доолго-дооолго-доооолго → доолго-дооолго-доооолго
# насчет ← нащет → знает
# естественно ← ессно → тесно
# экскурсоводы ← эксурсоводы → эксурсоводы
# покажут ← покажунт → покажунт
# кино ← кено → кено
# кидал ← кедал → кедра
# кидалы ← кедалы → кедалы
# подскажите ← подскажыте → подскажыте
# кровищи ← кровищщи → кровищщи
# предлагаю ← прердлагаю → предлагают
# нравятся ← нравяться → нравяться
# покопаться ← покапаться → показаться
# люда ← люда → люди
# очень ← ооочень → ооочень
# сентябрьский ← сентябрский → сентябрский
# рекомендую ← рекокомендую → рекокомендую
# промозгло ← проморзгло → проморзгло
# в ← вообщем → вообщем
# общем-то ← то → то
# распределить ← рапредилить → рапредилить
# сушить ← сушить → судить
# кстати ← кстате → статей
# одноклассники ← однаклассники → однаклассники
# напьешься ← напьешся → напьешся
# обожаю ← обажаю → обажаю
# насущного ← нсущного → нсущного
# теоретизированное ← теоретизированое → теоретизированое
# чтобы ← что → что
# больно ← бы → бы
# не ← больно → больно
# было ← небыло → небыло
# созерцать ← соцерцать → соцерцать
# разгадать ← разгодать → разгодать
# хочется ← хочеться → хочеться
# мочь ← мочь → дочь
# это ← ето → что
# одна ← одно → одно
# очень ← оооочень → оооочень
# адски ← аццки → аццки
# кощунство ← кошунство → кошунство
# способность ← спаособность → способностью
# несколько ← нескольнко → нескольнко
# одноклассники ← однаклассники → однаклассники
# мамочки ← мааааммоооочкииии → мааааммоооочкииии
# госов ← госов → годов
# нравится ← нравиться → развиться
# программка ← програмка → программа
# пресловутая ← преславутая → преславутая
# извините ← извените → извените
# выразился ← вырозился → вырозился
# напомнило ← напоменило → напоменило
# старый ← стааарый → стааарый
# придя ← прийдя → пройдя
# ирокез ← иракез → иракез
# это ← ето → что
# прикол ← прекол → прекол
# объехав ← обьехав → обьехав
# въехал ← вьехал → выехал
# сандово ← сандово → садовое
# получается ← получаеться → получаеться
# получается ← получаеться → получаеться
# не ← ни → ни
# половозрелые ← половозрлые → половозрлые
# естественно ← естесственно → естественной
# как ← какбы → какбы
# бы ← из → из
# из-под ← под → под
# очень ← ооочень → ооочень
# вообще ← вобще → общей
# новозаветная ← новозаветняя → новозаветняя
# это ← ето → что
# это ← ето → что
# обычные ← обычныэ → обычных
# негодные ← негодныэ → негодныэ
# люблю ← любю → любую
# потратить ← потртатить → потртатить
# расчетов ← рассчетов → рассчетов
# как-то ← както → какой
# вообще ← ваще → чаще
# бабешку ← бабежку → бабежку
# трепа ← трепа → трека
# жемчужинки ← жемчуженки → жемчуженки
# постарее ← постраее → постраее
# придя ← прийдя → пройдя
# острове ← острое → острое
# семантическая ← семантческая → семантческая
# превратиться ← превратититься → превратититься
# смяться ← смяться → сняться
# стечь ← стечь → степь
# все-таки ← все-таик → все-таик
# фотки ← фотки → фотия
# наконец-то ← наконецто → наконецто
# наконец-то ← наконецто → наконецто
# фоток ← фоток → поток
# залил ← залил → забил
# что ← че → че
# это ← ето → что
# вообще ← вобще → общей
# утешаюсь ← утешюсь → утешюсь
# обмороженных ← обмороженых → обмороженых
# ошпаренных ← ошпареных → ошпареных
# пытаюсь ← пыттаюсь → пыттаюсь
# отпраздную ← отпразную → отпразную
# простите ← проостите → проостите
# начали ← начаили → начаили
# хочется ← хочеться → хочеться
# кстати ← кстате → статей
# полетим ← поелетим → поелетим
# сказала ← скзала → сказал
# вообще ← вобще → общей
# спасибо ← пасиб → пасхи
# сегодня ← седня → седня
# рванина ← рванина → равнина
# со ← сос → сос
# старыми ← тарыми → старым
# встречавшимися ← встречавщимися → встречавщимися
# солнышком ← солнушком → солнушком
# насчет ← насчт → начат
# меняемся ← меняемся → меняется
# пронзительно ← пронизтельно → пронизтельно
# хочется ← хочеться → хочеться
# начальник ← начальнег → начальное
# сегодня ← седня → седня
# чудесный ← чудестный → чудестный
# ждем ← ждем → демо
# напыщенные ← напыщеные → напыщеные
# понедельник ← понедельнег → понедельнег
# продолжаем ← прдолжаем → прдолжаем
# только ← тока → тока
# сегодня ← седня → седня
# прямо ← пррямо → прямой
# пинг-понг ← пингу-понгу → пингу-понгу
# предыстория ← предъистория → предъистория
# очень ← ооочень → ооочень
# сегодня ← седня → седня
# очень ← оочень → оочень
# добавляю ← добавляю → добавляют
# мясные ← мысные → мысные
# елку ← елку → реку
# отдирала ← отдирла → отдирла
# бантики ← бантики → балтики
# отдыхаем ← отыхаем → отыхаем
# садиков ← садиков → осадков
# вообще ← вобще → общей
# конечно ← канешно → канешно
# по-любому ← полюбому → полюбому
# ого-го ← огого → огого
# вообще ← ваще → чаще
# незнакомая ← низакомая → низакомая
# девчонка ← дивченка → дивченка
# погода ← погда → когда
# установится ← установится → становиться
# рекомендуемо ← рекомундуемо → рекомундуемо
# равно ← ровно → ровно
# тахту ← тахту → тарту
# шкварчать ← шкворчать → шкворчать
# остальное ← остально → остальной
# ничего ← ниччего → ниччего
# искусстве ← икусстве → искусств
# тогда ← огда → года
# справедливыми ← саправедливыми → саправедливыми
# слезятся ← слезяться → слезяться
# просмотреть ← просмотрет → посмотреть
# очень ← оочень → оочень
# что-то ← чтото → чтото
# как-то ← както → какой
# разве ← разьве → разьве
# пескин ← пескин → пекине
# получилась ← получилсась → получилсась
# найдутся ← найдуться → найдуться
# экспериментируя ← эксперементируя → эксперементируя
# очень ← ооочень → ооочень
# раскрытие ← расскрытие → расскрытие
# нашел ← нашол → нашли
# совсем ← сосвсем → сосвсем
# прожигам ← прожегам → прожегам
# впереди ← впреди → вперед
# очень ← ооочень → ооочень
# мужчина ← мущщина → мущщина
# нефиг ← нефиг → нефти
# хочется ← хочеться → хочеться
# эгоистично ← егоистично → егоистично
# присоединишься ← присоеденишься → присоеденишься
# эх ← ээээххх → ээээххх
# очень ← оочень → оочень
# продажа ← продаа → продаж
# поздравляю ← поздравяю → поздравяю
# никогда ← никоглда → никоглда
# смирительную ← смерительную → смерительную
# дав ← даф → два
# как-то ← както → какой
# отсрочку ← осрочку → строчку
# охранник ← охраниик → охраниик
# по-любому ← полюбому → полюбому
# сегодня ← седня → седня
# очень ← ооооочень → ооооочень
# больше ← болше → более
# нашел ← нашол → нашли
# хочется ← хочеться → хочеться
# горча ← горча → горах
# вообще ← ваще → чаще
# миллиарды ← милиардны → милиардны
# трех ← 3ех → 3ех
# поздравляю ← паздравляю → паздравляю
# это ← ето → что
# пассажир ← пассижир → пассижир
# опять ← опяь → пять
# хрен ← хрень → хрень
# скучно ← скууучнооо → скууучнооо
# дирижер ← дерижер → дерижер
# расчет ← рассчет → рассвет
# транспортировка ← траспортировка → траспортировка
# как-то ← как → как
# странно ← то → то
# на ← странно → странно
# улице ← на → на
# супер ← улице → улице
# просто ← супер → супер
# а ← просто → просто
# я ← а → а
# целый ← я → я
# день ← целый → целый
# проспала ← день → день
# потом ← проспала → проспала
# уборкой ← потом → потом
# занималась ← уборкой → уборкой
# ну ← занималась → занималась
# в ← ну → ну
# общем ← вобщем → вообще
# низкокалорийное ← низкоколлорийное → низкоколлорийное
# ничего ← ничо → нико
# посмотри ← посмоти → посмоти
# запропала ← запрапала → запрапала
# расчеты ← рассчеты → рассчеты
# как-то ← както → какой
# подозрительно ← подощрительно → подощрительно
# подискутировали ← подисскутировали → подисскутировали
# люблю ← люблюд → люблюд
# счастлив ← счастлифф → счастлифф
# президент ← прензидент → президента
# рассказик ← рассказег → рассказег
# где ← гнде → гнев
# хочется ← хочеться → хочеться
# перезванивает ← презванивает → презванивает
# по-любому ← полюбому → полюбому
# любимый ← любимоый → любимоый
# нечаянно ← нечайнно → нечайнно
# правильная ← правльная → правльная
# прогулялся ← пррогулялся → пррогулялся
# наконец-то ← наконецто → наконецто
# опосля ← опопсля → опопсля
# левостороннее ← левостроннее → левостроннее
# выпадет ← выпадет → впадает
# из-за ← изза → миза
# напротив ← напрортив → напрортив
# угораздило ← угараздило → угараздило
# кстати ← кстате → статей
# намазываем ← намазывем → намазывем
# естественно ← естессно → естессно
# встречке ← встречке → встречен
# коридоры ← корридоры → корридоры
# бродили ← бродили → бросили
# ранее ← раннее → раннее
# фотки ← фотки → фотия
# что-то ← чтото → чтото
# рыться ← рыццо → рыццо
# хз ← хз → из
# ничего ← ничо → нико
# эксперты ← экперты → эксперт
# хочется ← хочеться → хочеться
# методологическое ← методолгическое → методолгическое
# сколько ← скока → скока
# сегодня ← седня → седня
# опухли ← опухли → опухоли
# девчонки ← девченки → девченки
# приземлились ← призимлились → призимлились
# целоваться ← целоваццо → целоваццо
# неудачники ← неудачнеги → неудачнеги
# спать ← сппать → сппать
# симпатичный ← симпотичный → симпотичный
# погуляем ← погкуляем → погкуляем
# обязательно ← обязаательно → обязательной
# послезавтра ← послезафтра → послезафтра
# тусовка ← туссовка → туссовка
# обещанные ← обесчанные → обесчанные
# четвертая ← четвртая → четвёртая
# потому ← птому → этому
# аськи ← аськи → маски
# свой ← сво → сво
# пожалуйста ← пожалуйсто → пожалуйсто
# очередная ← очеренданя → очеренданя
# рассчитаны ← расчитаны → рассчитан
# оттуда ← отуда → труда
# кто-то ← ктото → ктото
# шлите ← шлите → литве
# привязанность ← првязанность → првязанность
# папилломавирусы ← папиломавирусы → папиломавирусы
# естественно ← естессно → естессно
# приятного ← прияного → прияного
# комендант ← коммендант → коменданта
# резво ← резво → резко
# кстати ← кстате → статей
# продавцы ← проавцы → проавцы
# адски ← ацки → таки
# патологически ← паталогически → паталогически
# пожелайте ← пожалайте → пожалайте
# представьте ← представитьте → представитьте
# попадались ← попадлись → попадлись
# съездил ← сьездил → сьездил
# разделенный ← разделеннный → разделеннный
# старую ← струю → струю
# только ← толькго → столько
# что ← што → што
# смущение ← смушение → смешение
# хочется ← хочеться → хочеться
# ничего ← ничо → нико
# пятница ← пятницца → пятницца
# из-за ← изза → миза
# запарного ← запарного → западного
# вчера ← в4ера → в4ера
# вечер ← ве4ер → ве4ер
# напроситесь ← напрситесь → напрситесь
# оказывается ← оказуеться → оказуеться
# сегодня ← седня → седня
# подойдите ← подойтите → подойтите
# требую ← требую → требуют
# террористический ← террорестический → террорестический
# естественно ← естесственно → естественной
# профессиональные ← проффессиональные → проффессиональные
# какая ← какя → края
# незнакомка ← незнакомка → незнакомца
# стартапу ← страртапу → страртапу
# катастрофически ← катострофически → катострофически
# что ← што → што
# причисляя ← причесляя → причесляя
# приходится ← приходиться → приходиться
# мелодрамы ← мелодрамми → мелодрамми
# вообще ← вобще → общей
# наконец-то ← наконецто → наконецто
# очень ← ооооочень → ооооочень
# полночи ← полночи → полуночи
# одноклассники ← однаклассники → однаклассники
# базируемся ← базируемся → базируется
# молодежь ← молодеж → молодеж
# что-то ← чтото → чтото
# вообще ← вобще → общей
# сходили ← схходили → схходили
# скилл ← скилл → силла
# хочется ← хочеться → хочеться
# сегодня ← седня → седня
# сегодня ← седня → седня
# что ← че → че
# вот ← вооот → ворот
# кстати ← кстате → статей
# 4-х ← 4х → 4х
# фоток ← фоток → поток
# фаланги ← фалаги → фалаги
# смотрятся ← смотряться → смотряться
# удалить ← удаплить → удаплить
# из-за ← изза → миза
# сердце ← серце → сфере
# отбеливание ← отбеливанее → отбеливанее
# обожаю ← обажаю → обажаю
# кривляться ← кривлятся → кривлятся
# хочется ← хочеться → хочеться
# самодостаточность ← самоодостаточность → самоодостаточность
# разве ← разьве → разьве
# кстати ← кстате → статей
# гигов ← гигов → григо
# парализована ← парализованна → парализованна
# что ← чтот → этот
# что-то ← чтото → чтото
# в ← у → у
# очень ← ооочень → ооочень
# ненавижу ← неневижу → неневижу
# безысходность ← бузысходность → бузысходность
# нельзя ← нельязя → нельязя
# прощать ← прощать → продать
# яси ← яси → сил
# очень ← ооооочень → ооооочень
# сегодня ← седня → седня
# сегодня ← седня → седня
# позитив ← пазитив → пазитив
# террористы ← терраристы → терраристы
# очень ← оооочень → оооочень
# обтереть ← обтиреть → обтиреть
# претендент ← претендет → претендет
# очень ← ооооочень → ооооочень
# проклятые ← прррроклятые → прррроклятые
# ясей ← ясей → всей
# ведомость ← ведомость → ведомости
# очень ← ооочень → ооочень
# сегодня ← седня → седня
# приятно ← притно → приток
# восхитительный ← восхетительный → восхетительный
# жуть ← жуть → путь
# вообще ← ваще → чаще
# поскользнулся ← поскользулся → поскользулся
# хирурге ← хирурге → хирурга
# девчонки ← девченки → девченки
# собственно ← собстно → собстно
# посмотрела ← поссмотрела → поссмотрела
# самый ← сааамый → сааамый
# очень-очень ← ооочень-очень → ооочень-очень
# видать ← видать → видеть
# придется ← придеться → придеться
# чертов ← чортов → сортов
# онтогенетически ← онтогинетически → онтогинетически
# растолкала ← расталкала → расталкала
# какая-то ← какаято → какаято
# пишется ← пишеться → пишеться
# приметы ← прметы → примет
# кстати ← кстате → статей
# едем ← едем → демо
# съемочной ← съемолчной → съемолчной
# зарегистрироваться ← зарегистрироаться → зарегистрироаться
# напрашиваются ← напрашиваюттся → напрашиваюттся
# уйма ← уйма → шума
# собственно ← собстно → собстно
# очень ← ооочень → ооочень
# тащусь ← ташшусь → ташшусь
# может ← можеть → сможет
# вообще ← вобще → общей
# вообще ← ващще → ващще
# подонок ← падонаг → падонаг
# неопределенное ← неопределнное → неопределнное
# перкуссионист ← перкуссинист → перкуссинист
# одноклассники ← однокласники → однокласники
# почему-то ← почему → почему
# завис ← то → то
# в ← завис → завис
# общем ← вообщем → вообщем
# в ← вообщем → вообщем
# общем-то ← то → то
# отрисовала ← отрисавала → отрисавала
# кто-то ← ктото → ктото
# ведь ← веть → есть
# все-таки ← фсе-таки → фсе-таки
# естественно ← естессно → естессно
# получается ← получаеться → получаеться
# потому ← потомучто → потомучто
# что ← просто → просто
# просто ← невозможно → невозможно
# невозможно ← все → все
# все ← это → это
# это ← выместить → выместить
# вместить ← в → в
# в ← карточку → карточку
# карточку ← ну → ну
# ну ← ни → ни
# никак ← как → как
# накатило ← нактило → нактило
# наверху ← нверху → сверху
# поддерживаем ← поддерживаем → поддерживает
# пожалеть ← пажалеть → пажалеть
# его ← иво → иво
# сочувствие ← сачуствие → сачуствие
# успокоить ← успакоить → успакоить
# человека ← чилавека → чилавека
# сегодня ← седня → седня
# миллион ← мильон → миньон
# вообще ← ваще → чаще
# творите ← тварите → тварите
# теперь ← терь → тель
# возрастающей ← возростающей → возростающей
# вообще ← ваще → чаще
# отлично ← атлична → атлична
# предлагаю ← предлогаю → предлогаю
# кому-то ← комуто → комуто
# неорганизованная ← неорганизованая → неорганизованая
# организм ← организьм → организма
# становится ← становиццо → становиццо
# ватной ← ватной → важной
# наверно ← наврено → навечно
# мечи ← мячи → мячи
# сегодня ← сегододня → сегододня
# попытке ← попытки → попытки
# компе ← компе → кроме
# ответственность ← ответствтенность → ответственностью
# осамы ← осамы → самым
# слетел ← члетел → члетел
# рязань ← рязнань → рязнань
# папилломовирус ← папиломовирус → папиломовирус
# чувствую ← чувсвую → чувсвую
# сейчас ← ща → ща
# ничего ← ничо → нико
# адский ← аццкий → аццкий
# миллиардер ← милиардер → милиардер
# будить ← будить → судить
# одел ← одел → ходе
# akg ← akg → apg
# что-то ← чтото → чтото
# чувствуется ← чувствуеться → чувствуеться
# сегодня ← седня → седня
# ползал ← ползал → послал
# карачках ← корачках → корачках
# предлагаю ← предалагаю → предлагают
# конечно ← канешна → канешна
# частников ← частников → участников
# ничего ← ничо → нико
# не ← нне → нне
# вообще ← вобще → общей
# почувствовала ← почувстовала → почувствовал
# режиссеру ← режисеру → режисеру
# что ← што → што
# что ← то → то
# когда-то ← когдато → когдато
# естественно ← естесственно → естественной
# процветание ← прочветание → прочветание
# сегодня ← седня → седня
# из-за ← изза → миза
# придется ← прийдется → прийдется
# очень ← ооочень → ооочень
# фотке ← фотке → флоте
# ненавижу ← нинавижу → нинавижу
# девок ← девак → девак
# постараюсь ← постарюсь → постарюсь
# приемлемый ← приемлимый → приемлимый
# вообще ← ваще → чаще
# товарищ ← товарисч → товарисч
# сегодня ← седня → седня
# пронесла ← пронесла → принесла
# электрокнигу ← электрогнигу → электрогнигу
# как ← каааак → каааак
# очень ← оооочень → оооочень
# хочется ← хочеца → хочеца
# усиленно ← усиленено → усиленной
# репбазы ← реп → рек
# которые ← базы → базы
# оказались ← которые → которые
# крайне ← оказались → оказались
# близкими ← крайне → крайне
# друзьями ← близкими → близкими
# нежданным ← друзьями → друзьями
# в ← нежданным → нежданным
# общем ← вобщем → вообще
# рок-н-ролла ← рокенрола → рокенрола
# кстати ← кстате → статей
# любовь ← любоффь → любоффь
# естественно ← естесственно → естественной
# проанализировали ← проаализировали → проаализировали
# распределили ← распределили → распределяли
# хочется ← хочеться → хочеться
# обнимать ← обнимать → понимать
# собранное ← собьранное → собьранное
# оказалось ← оказалалось → оказалалось
# что ← че → че
# это ← ето → что
# вообще-то ← вобще-то → вобще-то
# фантастические ← фантаститечские → фантаститечские
# вообще ← вобще → общей
# состояние ← сосотояние → состоянием
# реагируют ← реагирует → реагирует
# захотела ← заъотела → заъотела
# очень ← ооооочень → ооооочень
# жутко ← жутко → жуков
# еще ← ишшо → ишшо
# обещаю ← обещаю → обещал
# это ← ето → что
# открытки ← откпытки → откпытки
# очень ← оооочень → оооочень
# вообще ← ваще → чаще
# черт-те ← черти → черти
# спасибо ← спаааасиб → спаааасиб
# насчет ← нащет → знает
# люблю ← любю → любую
# естественно ← естесственно → естественной
# естественно ← естессно → естессно
# сливает ← сливает → сбивает
# урока ← урока → срока
# сворачиваю ← сварачиваю → сварачиваю
# баррикады ← барикады → барикады
# обещают ← обешают → обешают
# маминой ← маминой → машиной
# очень ← оооочень → оооочень
# товарищ ← товарисч → товарисч
# определяешься ← определяешся → определяется
# сообщите ← сообщете → сообщает
# как-то ← както → какой
# наберешься ← наберешся → наберешся
# тварь ← тварррь → тварррь
# ничего ← ничо → нико
# товарищ ← товарисч → товарисч
# можно ← можнго → можнго
# расставаньям ← раставаньям → раставаньям
# девчонки ← девченки → девченки
# спускаюсь ← спускюсь → спускюсь
# товарищ ← товарисч → товарисч
# убери ← убери → хубер
# что ← че → че
# еще ← ещее → ещее
# тысяч ← тыш → тыс
# поздравляю ← поздравлдяю → поздравлдяю
# давно ← давнооо → давнооо
# посмотрели ← пасмарели → пасмарели
# проблемная ← проблемнная → проблемнная
# приехали ← прихали → приехал
# оттуда ← отуда → труда
# и ← ии → ии
# коктейль ← коктель → коктель
# усовершенствованный ← усовершенстваванный → усовершенстваванный
# профилактика ← профилиактика → профилиактика
# химиотерапии ← химиотерпии → химиотерпии
# скриншот ← скришнот → скришнот
# вообще ← ваще → чаще
# оказывается ← оказываецца → оказываецца
# посочувствовали ← посочуствовали → посочуствовали
# курю ← курю → курс
# охранник ← охраниик → охраниик
# очень ← ооочень → ооочень
# ссылка ← сцылка → сцылка
# поспишь ← поспшь → поспшь
# непонятных ← непонятнх → непонятно
# объясняла ← объяснала → объяснила
# начальнице ← началнице → началнице
# серебряные ← серебрянные → серебрянные
# из-за ← изза → миза
# куску ← куску → куско
# как-то ← както → какой
# бомжи ← бомжи → боями
# банкроты ← банкроты → банкноты
# юзаю ← юзаю → знаю
# придется ← придеться → придеться
# юзать ← юзать → знать
# стесняюсь ← стисняюсь → стисняюсь
# коломенское ← коломнеское → коломнеское
# одноклассники ← однаклассники → однаклассники
# долго ← дооолго → дооолго
# остается ← остаецца → остаецца
# смириться ← смириццо → смириццо
# бороться ← бороццо → бороццо
# что ← што → што
# черный ← чорный → чёрный
# мультики ← мууультики → мууультики
# вернулась ← вернууулась → вернууулась
# рaда ← рааада → рааада
# представьте ← представте → представте
# обрызгивается ← оббрызгивается → оббрызгивается
# подливает ← подливет → подливет
# потихоньку ← по-тихоньку → по-тихоньку
# планируем ← планируем → планирует
# развиться ← развицо → развито
# кстати ← кстате → статей
# мужчина ← мущщина → мущщина
# трата ← трата → брата
# вообще ← вобще → общей
# постарайтесь ← прстарайтесь → прстарайтесь
# аборигенку ← абоpигенку → абоpигенку
# приезжей ← пpиезжей → пpиезжей
# насчет ← нащет → знает
# почувствовав ← почувстовав → почувстовав
# свершениям ← свершениям → совершения
# поешьте ← поеште → поеште
# насчет ← нащет → знает
# yкладываются ← yкладываются → складываются
# котоpых ← котоpых → которых
# не ← ни → ни
# вообще ← вобще → общей
# очень ← ооочень → ооочень
# потрясающая ← потресающия → потресающия
# преподавательница ← преподовательница → преподовательница
# нравятся ← нравяться → нравяться
# счастливая ← счастлиывая → счастлиывая
# кошка ← кошшшшка → кошшшшка
# мягче ← мягше → мягше
# кто-то ← ктото → ктото
# кто-то ← ктото → ктото
# кто-то ← ктото → ктото
# естественно ← естесственно → естественной
# сегодня ← седня → седня
# принципы ← приниципы → приниципы
# применяю ← применяю → применяют
# естественно ← естесственно → естественной
# одиночеством ← одночеством → одночеством
# желаньем ← желаньем → желанием
# просмотр ← просмотер → просмотра
# контакте ← контакти → контракт
# естественно ← естесственно → естественной
# никуда ← нукда → наука
# ответьте ← ответтье → ответить
# естественно ← естесственно → естественной
# минутам ← минутам → минутах
# какие-то ← какие → какие
# плотники ← то → то
# объясняя ← плотники → плотники
# экзаменатору ← объясняя → объясняя
# что ← экзаменатору → экзаменатору
# связались ← что → что
# с ← связались → связались
# ней ← с → с
# через ← ней → ней
# емайл ← через → через
# говорилось ← емайл → майкл
# о ← говорилось → говорилось
# заборе ← о → о
# который ← заборе → заборе
# не ← который → который
# закрывается ← не → не
# затем ← закрывается → закрывается
# зашла ← затем → затем
# не ← зашла → зашла
# знаю ← незнаю → незнаю
# что-то ← чо-то → чо-то
# инете ← инете → интер
# ничего ← ничо → нико
# скажи ← сцкажи → сцкажи
# его ← иво → иво
# шоколаде ← шоколаде → шоколада
# придется ← прийдется → прийдется
# совпали ← срвпали → срвпали
# связываем ← связываем → связывает
# заботились ← забоились → забоились
# когда-то ← когдато → когдато
# запятых ← запятых → занятых
# вставлял ← встявлял → встявлял
# позаботьтесь ← позабодтесь → позабодтесь
# пофотографировав ← пофоторафировав → пофоторафировав
# очищенный ← очищеный → очищеный
# новогоднее ← навогоднее → навогоднее
# естественно ← ессно → тесно
# вообще ← ваще → чаще
# постебался ← постибалса → постибалса
# потому ← потсому → поэтому
# сногсшибательной ← сногсшибальной → сногсшибальной
# удается ← удеается → делается
# извините ← извените → извените
# это ← эта → эта
# проверка ← провекрка → провекрка
# когда-то ← когдато → когдато
# девчонки ← девченки → девченки
# стасу ← стасу → статс
# ливня ← ливня → линия
# мыле ← мыле → мысе
# пытаюсь ← пыраюсь → пыраюсь
# непредвиденные ← непридвиденные → непридвиденные
# поздравляю ← поздрваляю → поздрваляю
# говорю ← грю → грю
# ничего ← ничо → нико
# как-то ← както → какой
# хотеться ← хотеццо → хотеццо
# убиться ← убиться → учиться
# веником ← веником → великом
# нравится ← нравиццо → нравиццо
# поздравляю ← посдравляю → посдравляю
# очень ← ооочень → ооочень
# чувствовать ← чувстоввать → чувстоввать
# погода ← погда → когда
# как ← кааак → казак
# как ← каааак → каааак
# поверхностное ← поверхносное → поверхносное
# неискреннее ← неискренное → неискренное
# мастер-классах ← мастре-классах → мастре-классах
# вот ← воооот → воооот
# хочется ← хочеться → хочеться
# съездила ← съездела → съездела
# понаобещал ← понаобещщал → понаобещщал
# кстати ← кстате → статей
# неуравновешенно ← неуравновешено → неуравновешено
# центром ← центрм → центра
# сильно ← вильно → вильно
# влево ← влева → слева
# расскажу ← рассказжу → рассказжу
# покажи ← покажиииии → покажиииии
# пожинаем ← поженаем → поженаем
# болтаю ← болтаю → болота
# девчонками ← девочнками → девочнками
# торбой ← торбой → второй
# придется ← придеться → придеться
# некоторым ← некотороым → некоторыми
# лекарствами ← лекарствоми → лекарствоми
# собственно ← собсно → собсно
# прямо ← пррямо → прямой
# зуб ← ззуб → зубы
# зуб ← ззуб → зубы
# попадает ← поппадает → поппадает
# как-то ← какето → какето
# изюминку ← изуминку → изуминку
# мне ← мной → мной
# будешь ← будеш → будет
# свои ← сваи → сваи
# описывать ← аписывать → записывать
# чтоб ← шоб → шоу
# расчет ← рассчет → рассвет
# берем ← берем → берег
# ничего ← ничо → нико
# совладав ← совлаладав → совлаладав
# мудрейший ← мудреший → мудреший
# прочитала ← прочтала → прочитал
# жизнь ← жизни → жизни
# очень ← оччень → оччень
# неожиданно ← неожиданнго → неожиданнго
# прекратите ← прератите → прератите
# собственно ← собссно → собссно
# вообще ← вобще → общей
# хочется ← хочеться → хочеться
# 1145 ошибок из 9995 слов
# Точность: 0.885

# %% [markdown]
# 1145 ошибок из 9995 слов
#
# Точность: 0.885

# %%
def correction_3(word):
    if word in vocab:
        return word

    candidates = set()

    if word in delete_dict:
        candidates.update(delete_dict[word])

    for i in range(len(word)):
        deletion = word[:i] + word[i+1:]
        if deletion in delete_dict:
            candidates.update(delete_dict[deletion])

    MIN_FREQ = 13
    candidates = {w for w in candidates if vocab.get(w, 0) >= MIN_FREQ}


    MAX_DISTANCE = 1
    candidates = {w for w in candidates if textdistance.levenshtein.distance(word, w) <= MAX_DISTANCE}

    if candidates:
        return max(candidates, key=lambda w: vocab.get(w, 0))

    return word

# %%
count_errors_symspell(bad, true, correction_3)
# Out:
# симпатичнейшее ← симпатичнейшое → симпатичнейшое
# апофеозом ← опофеозом → опофеозом
# поясним ← пояним → пояним
# получатся ← полчатся → полчатся
# очень ← оччччень → оччччень
# насчет ← нащщот → нащщот
# основная ← основая → основан
# напрасно ← нарасно → нарасно
# в ← вобщем → вобщем
# общем ← как → как
# как ← вы → вы
# вы ← знаете → знаете
# знаете ← из → из
# из ← моего → моего
# моего ← не → не
# недавнего ← давнего → давнего
# ящика ← ящека → ящека
# предлагаю ← предлагю → предлагю
# сегодняшнее ← сегодяшнее → сегодяшнее
# рите ← рите → риме
# снятся ← снятся → снялся
# потому ← патаму → патаму
# что ← шта → шта
# пытаюсь ← пытаюсь → пытаясь
# повтыкав ← поффтыкав → поффтыкав
# ссоре ← соре → соре
# что-то ← чтото → чтото
# молодежь ← молодеж → молодеж
# участвовать ← учавствовать → учавствовать
# сегодня ← седня → седня
# навешать ← вешать → вешать
# это ← эт → эт
# конечно ← канешна → канешна
# 4:0 ← 4:0 → 400
# начальник ← начальнег → начальнег
# зажег ← зажог → залог
# по-взрослому ← павзрослому → павзрослому
# предыдущую ← предудущую → предудущую
# слег ← слег → олег
# подсаживается ← подсаживаеться → подсаживаеться
# какие-то ← какието → какието
# малолетние ← малолетнии → малолетнии
# молодежь ← молодеж → молодеж
# ощущаю ← ощушаю → ощушаю
# монголоидом ← монголойдом → монголойдом
# молчу ← молчю → молчю
# объелись ← обълись → обълись
# веселились ← ввеселились → ввеселились
# расспрашивая ← распрашивая → распрашивая
# зубодробительная ← зубодробительня → зубодробительня
# как ← каааак → каааак
# хочется ← хочеться → хочеться
# письмена ← писмена → писмена
# супермаркете ← супер-маркете → супер-маркете
# серебряные ← серебрянные → серебрянные
# расшифровать ← расщифровать → расщифровать
# самой-то ← самойто → самойто
# тут ← тул → тул
# вообще ← ваще → чаще
# только ← тока → тока
# наверное ← навернео → навернео
# очень ← ооочень → ооочень
# яся ← яся → вся
# стараюсь ← стараюсь → стараясь
# как-то ← както → факто
# мужчину ← мущщину → мущщину
# никогда ← никада → никуда
# очень ← оооочень → оооочень
# симпатическая ← симаатическая → симаатическая
# потовые ← потовые → почтовые
# перспектива ← першпектива → першпектива
# препараты ← припораты → припораты
# съездили ← съездели → съездели
# расчете ← рассчете → рассвете
# купим ← купим → купил
# приветствуется ← приветствутется → приветствутется
# опасался ← опаслася → опаслася
# разжился ← расжился → расжился
# однажды ← однажэды → однажэды
# зубные ← зуные → зуные
# пользоваться ← пользоваццо → пользоваццо
# сочувствующие ← сочуствующие → сочуствующие
# доев ← доев → боев
# креатив ← креатифф → креатифф
# челка ← челка → белка
# естественно ← естесственно → естесственно
# обнимает ← однимает → поднимает
# основные ← основыные → основыные
# получается ← получаеться → получаеться
# разрушается ← разрушаеться → разрушаеться
# координирует ← кроординирует → кроординирует
# движение ← движениие → движениие
# правило ← правила → правила
# рассказчик ← расказчик → расказчик
# прочитал ← проичитал → проичитал
# открываю ← открыывю → открыывю
# написано ← написанно → написанной
# высыпание ← высыпвние → высыпвние
# пересказывать ← перессказывать → перессказывать
# пьяный ← пяный → пятый
# что-то ← чтото → чтото
# собственно ← собстно → собстно
# священнослужители ← священослужители → священослужители
# рясах ← рясах → рядах
# неосознанно ← неососознанно → неососознанно
# сохраню ← сохраю → сохраю
# сыро ← сыро → серо
# вообще ← ваще → чаще
# ад ← ат → ат
# по-прежнему ← попрежнему → попрежнему
# никогда ← никада → никуда
# позже ← пожже → пожже
# когда-то ← когдато → когдато
# отдала ← отадала → отадала
# вообще ← ваще → чаще
# насчет ← нащет → нащет
# гулливера ← гуливера → гуливера
# самый ← самыи → самым
# гадости ← гадости → радости
# на ← но → но
# никак ← не-как → не-как
# обидели ← обидели → обители
# рекомендации ← рекоммендация → рекоммендация
# напроектировали ← напректировали → напректировали
# одноклассниках ← однокласниках → однокласниках
# вообще ← ваще → чаще
# асфальтоукладчик ← афальтоукладчик → афальтоукладчик
# качество ← кчакчество → кчакчество
# зажатия ← зажатия → зачатия
# разве ← разьве → разьве
# прикольные ← прикодьные → прикодьные
# одноклассников ← однокласников → однокласников
# собственно ← собстно → собстно
# хочется ← хочеться → хочеться
# посмотреть ← помотрть → помотрть
# хочется ← хочеться → хочеться
# прикольные ← пприкольные → пприкольные
# начните ← начьните → начьните
# он ← онвыгребает → онвыгребает
# выгребает ← ее → ее
# ее ← из → из
# из-под ← под → под
# не ← небыло → небыло
# было ← никогда → никогда
# никогда ← любви → любви
# любви-то ← то → то
# мужиков ← мужуков → мужуков
# сегодняшние ← сегодяшние → сегодяшние
# начальник ← начальнег → начальнег
# зайти ← заити → гаити
# вконтакт ← вконтакт → вконтакте
# потеряна ← потреяна → потреяна
# ненавидишь ← ненавидшь → ненавидшь
# мыслящая ← мыслящаю → мыслящаю
# убрать ← убрть → убить
# процедура ← процедудура → процедудура
# коммунисты ← коммуниисты → коммуниисты
# сегодня ← седня → седня
# ответственно ← ответсвенно → ответсвенно
# очень ← оооочень → оооочень
# бесит ← бесит → бежит
# получается ← получаеться → получаеться
# серой ← сером → сером
# рисунком ← рисунко → рисунки
# продолжение ← продолжения → продолжения
# спасибо ← сапсибо → сапсибо
# тасовать ← тасовоать → тасовоать
# основной ← основныой → основныой
# очень ← оочень → оочень
# сегодня ← седня → седня
# страшно ← страааашно → страааашно
# нравятся ← нравяться → нравяться
# обогреватель ← обогреватель → обозреватель
# конечно ← канешна → канешна
# компания ← компнаия → компнаия
# превратит ← превратит → превратить
# фарш ← фарш → фарм
# праздник ← празнег → празнег
# жуть ← жуть → путь
# встретиться ← встретицца → встретицца
# нахожусь ← нажусь → нажусь
# вообще ← ваще → чаще
# организмы ← огранизмы → огранизмы
# долго ← дооолго → дооолго
# садиться ← садится → садится
# серебряном ← серебрянном → серебрянном
# сегодня ← седня → седня
# по-любому ← полюбому → полюбому
# ослуживание ← ослуживание → обслуживание
# безупречное ← безупречноне → безупречноне
# ищете ← ищите → ищите
# какого ← какова → какова
# района ← раена → равна
# объясни ← объясни → объяснил
# продолжительность ← пролжительность → пролжительность
# симпатичный ← симпотичный → симпотичный
# продул ← продул → продал
# угощали ← угошали → угошали
# открыл ← отркрыл → отркрыл
# подделанная ← подделаная → подделаная
# подробный ← подрбный → подобный
# обдумываю ← обдумывю → обдумывю
# отечественные ← отечетсвенные → отечетсвенные
# познакомиться ← познакомицца → познакомицца
# монастырь ← монастрырь → монастрырь
# большой ← большое → большое
# не ← незнаю → незнаю
# знаю ← ходить → ходить
# ходить ← на → на
# на ← море → море
# море ← делать → делать
# делать ← ремонт → ремонт
# ремонт ← кого → кого
# кого-нибудь ← нибудь → нибудь
# сроду ← сроду → среду
# осчастливленный ← ощастливленный → ощастливленный
# выхожу ← выхожу → выходу
# решаем ← решаем → решает
# оным ← оным → иным
# колой ← колой → школой
# естественно ← естесственно → естесственно
# естественно ← естесственно → естесственно
# поведайте ← поведйте → поведйте
# плиз ← плиз → близ
# только ← тока → тока
# т.к ← т.к → так
# естественно ← естесственно → естесственно
# естественно ← естесственно → естесственно
# спасибо ← спапсибо → спапсибо
# начальник ← начальнег → начальнег
# поднимать ← поднмать → поднмать
# читаемость ← читаемсоть → читаемсоть
# мальчики ← мальчеги → мальчеги
# хорошее ← хооршее → хооршее
# потому ← потмоу → потмоу
# работодатели ← работадатели → работадатели
# присоединяюсь ← присоединаюсь → присоединаюсь
# это ← ето → что
# сегодня ← седня → седня
# лосьончика ← лосьончека → лосьончека
# очень ← очнеь → очнеь
# парламентский ← парламентський → парламентський
# привезла ← приезла → приезда
# просвистевшая ← просвестевшая → просвестевшая
# обернуться ← оберутся → оберутся
# матерю ← матерю → матери
# сегодня ← седня → седня
# лишил ← лешил → решил
# постарайтесь ← постарайтеь → постарайтеь
# сумасшедшего ← сумашедшего → сумашедшего
# извините ← извените → извените
# чувствовалась ← чувстовалась → чувстовалась
# гордиться ← гордится → гордится
# поссорилась ← посорилась → посорилась
# каким-нибудь ← какимнить → какимнить
# лж ← лж → ли
# рюкзак ← рюкзазк → рюкзазк
# даже ← дае → дае
# вообще ← ваще → чаще
# мозаика ← мозайка → мозайка
# любое ← любоее → любоее
# паутину ← паути → паути
# непридуманная ← неридуманная → неридуманная
# история ← истоиря → истоиря
# пересказываю ← перессказываю → перессказываю
# подгрузился ← подргрузился → подргрузился
# основная ← основвная → основвная
# набирала ← наберала → наберала
# девчонки ← девченки → девченки
# завизжали ← завижжали → завижжали
# невозможно ← невозмозможно → невозмозможно
# пишите ← пишиите → пишиите
# неоднозначное ← неодназначное → неодназначное
# строятся ← стороятся → стороятся
# расчет ← рассчет → рассвет
# эмоциональная ← эмоциональаня → эмоциональаня
# кинокомпанией ← кинопокмпанией → кинопокмпанией
# будешь ← будеш → будет
# естественно ← естесственно → естесственно
# преинтереснейшее ← преинтерснейшее → преинтерснейшее
# долго ← дооолго → дооолго
# я ← мя → мя
# привыкла ← привыкла → привыкли
# очень ← оооочень → оооочень
# сегодня ← седня → седня
# что ← што → што
# осталось ← осталалось → оставалось
# статусы ← стратусы → стратусы
# смешные ← смшные → смшные
# однокурсница ← однокурссница → однокурссница
# естественно ← естесственно → естесственно
# естественно ← ессно → ессно
# завтра ← заффтра → заффтра
# получается ← получаеться → получаеться
# придется ← придеться → придеться
# позавчера ← позаввчера → позаввчера
# наконец-то ← наконецто → наконецто
# ручонки ← рученки → рученки
# кнопочки ← кнопачки → кнопачки
# прикладываем ← прикладывам → прикладывам
# следите ← следеите → следеите
# пассажирам ← пасажирам → пасажирам
# лежаки ← лежаки → лежали
# территорию ← территроию → территроию
# любопытства ← любопатства → любопатства
# деньги ← денги → денги
# отдаются ← отдаються → отдаються
# замечательные ← замечаельные → замечаельные
# насчет ← нащет → нащет
# отбеливания ← отбеливание → отбеливание
# трехчасовой ← 3хчасовой → 3хчасовой
# кодексам ← кодексам → кодексом
# заверив ← заверив → завершив
# официально ← оффициально → оффициально
# обрадовались ← обрадовались → образовались
# очень ← ооочень → ооочень
# прагматично ← прогматично → прогматично
# общаются ← общаються → общаються
# соедините ← соедените → соедените
# в ← вобщем → вобщем
# общем ← сниццо → сниццо
# снится ← мне → мне
# мне ← что → что
# что ← я → я
# я ← нашел → нашел
# нашел-таки ← таки → таки
# практически ← практичнески → практичнески
# естественно ← естесственно → естесственно
# сволочи ← сволачи → сволачи
# она ← ана → ана
# стрельбище ← стельбище → стельбище
# как-то ← както → факто
# очень ← оооочень → оооочень
# холодная ← холооодная → холооодная
# гостиная ← гостинная → гостинная
# вообще ← ваще → чаще
# долго-долго-долго ← доолго-дооолго-доооолго → доолго-дооолго-доооолго
# насчет ← нащет → нащет
# естественно ← ессно → ессно
# экскурсоводы ← эксурсоводы → эксурсоводы
# субботу ← субодту → субодту
# покажут ← покажунт → покажунт
# кино ← кено → кено
# кидал ← кедал → кедал
# кидалы ← кедалы → кедалы
# подскажите ← подскажыте → подскажыте
# кровищи ← кровищщи → кровищщи
# предлагаю ← прердлагаю → прердлагаю
# нравятся ← нравяться → нравяться
# покопаться ← покапаться → показаться
# люда ← люда → люди
# очень ← ооочень → ооочень
# сентябрьский ← сентябрский → сентябрский
# рекомендую ← рекокомендую → рекокомендую
# промозгло ← проморзгло → проморзгло
# в ← вообщем → вообщем
# общем-то ← то → то
# распределить ← рапредилить → рапредилить
# сушить ← сушить → судить
# одноклассники ← однаклассники → однаклассники
# напьешься ← напьешся → напьешся
# обожаю ← обажаю → обажаю
# насущного ← нсущного → нсущного
# теоретизированное ← теоретизированое → теоретизированое
# чтобы ← что → что
# больно ← бы → бы
# не ← больно → больно
# было ← небыло → небыло
# созерцать ← соцерцать → соцерцать
# провинция ← провниция → провниция
# разгадать ← разгодать → разгодать
# хочется ← хочеться → хочеться
# мочь ← мочь → дочь
# это ← ето → что
# одна ← одно → одно
# очень ← оооочень → оооочень
# адски ← аццки → аццки
# кощунство ← кошунство → кошунство
# способность ← спаособность → спаособность
# несколько ← нескольнко → нескольнко
# одноклассники ← однаклассники → однаклассники
# мамочки ← мааааммоооочкииии → мааааммоооочкииии
# госов ← госов → годов
# нравится ← нравиться → нравиться
# программка ← програмка → программа
# пресловутая ← преславутая → преславутая
# извините ← извените → извените
# выразился ← вырозился → вырозился
# напомнило ← напоменило → напоменило
# старый ← стааарый → стааарый
# придя ← прийдя → пройдя
# ирокез ← иракез → иракез
# это ← ето → что
# прикол ← прекол → прекол
# объехав ← обьехав → обьехав
# въехал ← вьехал → выехал
# получается ← получаеться → получаеться
# получается ← получаеться → получаеться
# не ← ни → ни
# половозрелые ← половозрлые → половозрлые
# естественно ← естесственно → естесственно
# как ← какбы → какбы
# бы ← из → из
# из-под ← под → под
# очень ← ооочень → ооочень
# новозаветная ← новозаветняя → новозаветняя
# это ← ето → что
# это ← ето → что
# обычные ← обычныэ → обычных
# негодные ← негодныэ → негодныэ
# люблю ← любю → любую
# потратить ← потртатить → потртатить
# расчетов ← рассчетов → рассчетов
# как-то ← както → факто
# вообще ← ваще → чаще
# бабешку ← бабежку → бабежку
# трепа ← трепа → трека
# жемчужинки ← жемчуженки → жемчуженки
# постарее ← постраее → постраее
# придя ← прийдя → пройдя
# сколько ← сколкьо → сколкьо
# острове ← острое → острое
# семантическая ← семантческая → семантческая
# превратиться ← превратититься → превратититься
# смяться ← смяться → сняться
# стечь ← стечь → степь
# все-таки ← все-таик → все-таик
# наконец-то ← наконецто → наконецто
# наконец-то ← наконецто → наконецто
# фоток ← фоток → поток
# залил ← залил → забил
# что ← че → че
# это ← ето → что
# утешаюсь ← утешюсь → утешюсь
# обмороженных ← обмороженых → обмороженых
# ошпаренных ← ошпареных → ошпареных
# пытаюсь ← пыттаюсь → пыттаюсь
# отпраздную ← отпразную → отпразную
# простите ← проостите → проостите
# начали ← начаили → начаили
# хочется ← хочеться → хочеться
# полетим ← поелетим → поелетим
# спасибо ← пасиб → пасиб
# сегодня ← седня → седня
# со ← сос → сос
# встречавшимися ← встречавщимися → встречавщимися
# солнышком ← солнушком → солнушком
# поэтому ← поэтмоу → поэтмоу
# насчет ← насчт → насчёт
# меняемся ← меняемся → меняется
# пронзительно ← пронизтельно → пронизтельно
# хочется ← хочеться → хочеться
# начальник ← начальнег → начальнег
# сегодня ← седня → седня
# чудесный ← чудестный → чудестный
# ждем ← ждем → ждет
# напыщенные ← напыщеные → напыщеные
# понедельник ← понедельнег → понедельнег
# продолжаем ← прдолжаем → прдолжаем
# солнце ← солцне → солцне
# только ← тока → тока
# сегодня ← седня → седня
# прямо ← пррямо → пррямо
# пинг-понг ← пингу-понгу → пингу-понгу
# предыстория ← предъистория → предъистория
# очень ← ооочень → ооочень
# сегодня ← седня → седня
# очень ← оочень → оочень
# добавляю ← добавляю → добавляют
# мясные ← мысные → мысные
# елку ← елку → ёлку
# отдирала ← отдирла → отдирла
# бантики ← бантики → балтики
# отдыхаем ← отыхаем → отыхаем
# конечно ← канешно → канешно
# по-любому ← полюбому → полюбому
# ого-го ← огого → огого
# вообще ← ваще → чаще
# незнакомая ← низакомая → низакомая
# девчонка ← дивченка → дивченка
# погода ← погда → когда
# рекомендуемо ← рекомундуемо → рекомундуемо
# равно ← ровно → ровно
# тахту ← тахту → тарту
# шкварчать ← шкворчать → шкворчать
# остальное ← остально → остальной
# ничего ← ниччего → ниччего
# тогда ← огда → когда
# справедливыми ← саправедливыми → саправедливыми
# слезятся ← слезяться → слезяться
# просмотреть ← просмотрет → просмотрет
# очень ← оочень → оочень
# что-то ← чтото → чтото
# как-то ← както → факто
# разве ← разьве → разьве
# получилась ← получилсась → получилсась
# найдутся ← найдуться → найдуться
# экспериментируя ← эксперементируя → эксперементируя
# рассматривает ← рассматирвает → рассматирвает
# т.к ← т.к → так
# очень ← ооочень → ооочень
# раскрытие ← расскрытие → расскрытие
# нашел ← нашол → нашёл
# совсем ← сосвсем → сосвсем
# прожигам ← прожегам → прожегам
# очень ← ооочень → ооочень
# мужчина ← мущщина → мущщина
# хочется ← хочеться → хочеться
# эгоистично ← егоистично → егоистично
# присоединишься ← присоеденишься → присоеденишься
# эх ← ээээххх → ээээххх
# очень ← оочень → оочень
# продажа ← продаа → продаж
# поздравляю ← поздравяю → поздравяю
# никогда ← никоглда → никоглда
# смирительную ← смерительную → смерительную
# дав ← даф → дал
# как-то ← както → факто
# отсрочку ← осрочку → осрочку
# охранник ← охраниик → охраниик
# по-любому ← полюбому → полюбому
# сегодня ← седня → седня
# очень ← ооооочень → ооооочень
# больше ← болше → более
# нашел ← нашол → нашёл
# хочется ← хочеться → хочеться
# горча ← горча → горка
# вообще ← ваще → чаще
# миллиарды ← милиардны → милиардны
# трех ← 3ех → тех
# поздравляю ← паздравляю → паздравляю
# это ← ето → что
# пассажир ← пассижир → пассижир
# хрен ← хрень → хрень
# скучно ← скууучнооо → скууучнооо
# дирижер ← дерижер → дерижер
# расчет ← рассчет → рассвет
# транспортировка ← траспортировка → траспортировка
# как-то ← как → как
# странно ← то → то
# на ← странно → странно
# улице ← на → на
# супер ← улице → улице
# просто ← супер → супер
# а ← просто → просто
# я ← а → а
# целый ← я → я
# день ← целый → целый
# проспала ← день → день
# потом ← проспала → проспала
# уборкой ← потом → потом
# занималась ← уборкой → уборкой
# ну ← занималась → занималась
# в ← ну → ну
# общем ← вобщем → вобщем
# низкокалорийное ← низкоколлорийное → низкоколлорийное
# ничего ← ничо → нико
# посмотри ← посмоти → посмоти
# запропала ← запрапала → запрапала
# расчеты ← рассчеты → рассчеты
# как-то ← както → факто
# подозрительно ← подощрительно → подощрительно
# подискутировали ← подисскутировали → подисскутировали
# просто ← порсто → порсто
# люблю ← люблюд → люблюд
# счастлив ← счастлифф → счастлифф
# президент ← прензидент → прензидент
# рассказик ← рассказег → рассказег
# где ← гнде → гнде
# хочется ← хочеться → хочеться
# перезванивает ← презванивает → презванивает
# по-любому ← полюбому → полюбому
# любимый ← любимоый → любимоый
# нечаянно ← нечайнно → нечайнно
# правильная ← правльная → правльная
# прогулялся ← пррогулялся → пррогулялся
# наконец-то ← наконецто → наконецто
# лекарственные ← лекартсвенные → лекартсвенные
# опосля ← опопсля → опопсля
# левостороннее ← левостроннее → левостроннее
# выпадет ← выпадет → выпадает
# из-за ← изза → изба
# напротив ← напрортив → напрортив
# угораздило ← угараздило → угараздило
# намазываем ← намазывем → намазывем
# естественно ← естессно → естессно
# коридоры ← корридоры → корридоры
# бродили ← бродили → бросили
# ранее ← раннее → раннее
# пост ← псто → псто
# что-то ← чтото → чтото
# рыться ← рыццо → рыццо
# хз ← хз → из
# ничего ← ничо → нико
# хочется ← хочеться → хочеться
# методологическое ← методолгическое → методолгическое
# сколько ← скока → скока
# сегодня ← седня → седня
# опухли ← опухли → опухоли
# девчонки ← девченки → девченки
# приземлились ← призимлились → призимлились
# целоваться ← целоваццо → целоваццо
# неудачники ← неудачнеги → неудачнеги
# спать ← сппать → сппать
# симпатичный ← симпотичный → симпотичный
# погуляем ← погкуляем → погкуляем
# обязательно ← обязаательно → обязаательно
# послезавтра ← послезафтра → послезафтра
# тусовка ← туссовка → туссовка
# открыла ← отркыла → отркыла
# обещанные ← обесчанные → обесчанные
# четвертая ← четвртая → четвёртая
# остановились ← отсановились → отсановились
# потому ← птому → этому
# свой ← сво → сво
# пожалуйста ← пожалуйсто → пожалуйсто
# очередная ← очеренданя → очеренданя
# оттуда ← отуда → откуда
# кто-то ← ктото → ктото
# привязанность ← првязанность → првязанность
# папилломавирусы ← папиломавирусы → папиломавирусы
# естественно ← естессно → естессно
# приятного ← прияного → прияного
# комендант ← коммендант → коммендант
# резво ← резво → резко
# продавцы ← проавцы → проавцы
# адски ← ацки → арки
# сегодня ← сегдьня → сегдьня
# патологически ← паталогически → паталогически
# пожелайте ← пожалайте → пожалайте
# представьте ← представитьте → представитьте
# попадались ← попадлись → попадлись
# съездил ← сьездил → сьездил
# разделенный ← разделеннный → разделеннный
# старую ← струю → струю
# только ← толькго → толькго
# что ← што → што
# смущение ← смушение → смешение
# хочется ← хочеться → хочеться
# ничего ← ничо → нико
# пятница ← пятницца → пятницца
# из-за ← изза → изба
# запарного ← запарного → западного
# вечер ← ве4ер → ветер
# напроситесь ← напрситесь → напрситесь
# оказывается ← оказуеться → оказуеться
# сегодня ← седня → седня
# подойдите ← подойтите → подойтите
# требую ← требую → требуют
# террористический ← террорестический → террорестический
# естественно ← естесственно → естесственно
# профессиональные ← проффессиональные → проффессиональные
# незнакомка ← незнакомка → незнакомца
# стартапу ← страртапу → страртапу
# катастрофически ← катострофически → катострофически
# что ← што → што
# причисляя ← причесляя → причесляя
# направлению ← нарпавлению → нарпавлению
# приходится ← приходиться → приходиться
# мелодрамы ← мелодрамми → мелодрамми
# наконец-то ← наконецто → наконецто
# очень ← ооооочень → ооооочень
# полночи ← полночи → полуночи
# одноклассники ← однаклассники → однаклассники
# базируемся ← базируемся → базируется
# молодежь ← молодеж → молодеж
# что-то ← чтото → чтото
# сходили ← схходили → схходили
# хочется ← хочеться → хочеться
# сегодня ← седня → седня
# сегодня ← седня → седня
# что ← че → че
# вот ← вооот → ворот
# 4-х ← 4х → 4х
# фоток ← фоток → поток
# фаланги ← фалаги → фалаги
# смотрятся ← смотряться → смотряться
# удалить ← удаплить → удаплить
# из-за ← изза → изба
# лучше ← лушче → лушче
# отбеливание ← отбеливанее → отбеливанее
# обожаю ← обажаю → обажаю
# кривляться ← кривлятся → кривлятся
# хочется ← хочеться → хочеться
# самодостаточность ← самоодостаточность → самоодостаточность
# разве ← разьве → разьве
# парализована ← парализованна → парализованна
# что ← чтот → этот
# что-то ← чтото → чтото
# в ← у → у
# очень ← ооочень → ооочень
# ненавижу ← неневижу → неневижу
# безысходность ← бузысходность → бузысходность
# нельзя ← нельязя → нельязя
# прощать ← прощать → продать
# яси ← яси → оси
# очень ← ооооочень → ооооочень
# сегодня ← седня → седня
# сегодня ← седня → седня
# позитив ← пазитив → пазитив
# террористы ← терраристы → терраристы
# очень ← оооочень → оооочень
# обтереть ← обтиреть → обтиреть
# претендент ← претендет → претендет
# очень ← ооооочень → ооооочень
# проклятые ← прррроклятые → прррроклятые
# ясей ← ясей → всей
# ведомость ← ведомость → ведомости
# очень ← ооочень → ооочень
# сегодня ← седня → седня
# азербайджан ← азейрбаджан → азейрбаджан
# восхитительный ← восхетительный → восхетительный
# жуть ← жуть → путь
# вообще ← ваще → чаще
# поскользнулся ← поскользулся → поскользулся
# хирурге ← хирурге → хирурга
# девчонки ← девченки → девченки
# собственно ← собстно → собстно
# посмотрела ← поссмотрела → поссмотрела
# самый ← сааамый → сааамый
# очень-очень ← ооочень-очень → ооочень-очень
# видать ← видать → видеть
# придется ← придеться → придеться
# чертов ← чортов → сортов
# онтогенетически ← онтогинетически → онтогинетически
# растолкала ← расталкала → расталкала
# какая-то ← какаято → какаято
# пишется ← пишеться → пишеться
# приметы ← прметы → прметы
# едем ← едем → едет
# съемочной ← съемолчной → съемолчной
# зарегистрироваться ← зарегистрироаться → зарегистрироаться
# напрашиваются ← напрашиваюттся → напрашиваюттся
# собственно ← собстно → собстно
# очень ← ооочень → ооочень
# тащусь ← ташшусь → ташшусь
# может ← можеть → можете
# маршрут ← маршурт → маршурт
# вообще ← ващще → ващще
# подонок ← падонаг → падонаг
# неопределенное ← неопределнное → неопределнное
# перкуссионист ← перкуссинист → перкуссинист
# одноклассники ← однокласники → однокласники
# почему-то ← почему → почему
# завис ← то → то
# в ← завис → завис
# общем ← вообщем → вообщем
# в ← вообщем → вообщем
# общем-то ← то → то
# отрисовала ← отрисавала → отрисавала
# кто-то ← ктото → ктото
# ведь ← веть → весь
# все-таки ← фсе-таки → фсе-таки
# естественно ← естессно → естессно
# получается ← получаеться → получаеться
# потому ← потомучто → потомучто
# что ← просто → просто
# просто ← невозможно → невозможно
# невозможно ← все → все
# все ← это → это
# это ← выместить → выместить
# вместить ← в → в
# в ← карточку → карточку
# карточку ← ну → ну
# ну ← ни → ни
# никак ← как → как
# накатило ← нактило → нактило
# наверху ← нверху → сверху
# поддерживаем ← поддерживаем → поддерживает
# пожалеть ← пажалеть → пажалеть
# его ← иво → иво
# сочувствие ← сачуствие → сачуствие
# успокоить ← успакоить → успакоить
# человека ← чилавека → чилавека
# сегодня ← седня → седня
# миллион ← мильон → миньон
# вообще ← ваще → чаще
# творите ← тварите → тварите
# теперь ← терь → тель
# возрастающей ← возростающей → возростающей
# вообще ← ваще → чаще
# отлично ← атлична → атлична
# предлагаю ← предлогаю → предлогаю
# кому-то ← комуто → комуто
# потому ← потмоу → потмоу
# неорганизованная ← неорганизованая → неорганизованая
# организм ← организьм → организьм
# первый ← певрый → певрый
# становится ← становиццо → становиццо
# ватной ← ватной → важной
# наверно ← наврено → наврено
# мечи ← мячи → мячи
# сегодня ← сегододня → сегододня
# попытке ← попытки → попытки
# ответственность ← ответствтенность → ответствтенность
# осамы ← осамы → осады
# слетел ← члетел → члетел
# рязань ← рязнань → рязнань
# папилломовирус ← папиломовирус → папиломовирус
# чувствую ← чувсвую → чувсвую
# интересно ← интерстно → интерстно
# сейчас ← ща → ща
# ничего ← ничо → нико
# адский ← аццкий → аццкий
# миллиардер ← милиардер → милиардер
# будить ← будить → судить
# одел ← одел → отдел
# akg ← akg → apg
# что-то ← чтото → чтото
# чувствуется ← чувствуеться → чувствуеться
# сегодня ← седня → седня
# карачках ← корачках → корачках
# предлагаю ← предалагаю → предалагаю
# конечно ← канешна → канешна
# частников ← частников → участников
# ничего ← ничо → нико
# не ← нне → нне
# почувствовала ← почувстовала → почувстовала
# режиссеру ← режисеру → режисеру
# что ← што → што
# что ← то → то
# когда-то ← когдато → когдато
# естественно ← естесственно → естесственно
# процветание ← прочветание → прочветание
# сегодня ← седня → седня
# из-за ← изза → изба
# придется ← прийдется → прийдется
# очень ← ооочень → ооочень
# ненавижу ← нинавижу → нинавижу
# девок ← девак → девак
# постараюсь ← постарюсь → постарюсь
# приемлемый ← приемлимый → приемлимый
# вообще ← ваще → чаще
# товарищ ← товарисч → товарисч
# сегодня ← седня → седня
# пронесла ← пронесла → принесла
# электрокнигу ← электрогнигу → электрогнигу
# как ← каааак → каааак
# очень ← оооочень → оооочень
# хочется ← хочеца → хочеца
# усиленно ← усиленено → усиленено
# репбазы ← реп → рек
# которые ← базы → базы
# оказались ← которые → которые
# крайне ← оказались → оказались
# близкими ← крайне → крайне
# друзьями ← близкими → близкими
# нежданным ← друзьями → друзьями
# в ← нежданным → нежданным
# общем ← вобщем → вобщем
# рок-н-ролла ← рокенрола → рокенрола
# любовь ← любоффь → любоффь
# естественно ← естесственно → естесственно
# проанализировали ← проаализировали → проаализировали
# распределили ← распределили → распределяли
# хочется ← хочеться → хочеться
# собранное ← собьранное → собьранное
# оказалось ← оказалалось → оказалалось
# что ← че → че
# это ← ето → что
# вообще-то ← вобще-то → вобще-то
# фантастические ← фантаститечские → фантаститечские
# состояние ← сосотояние → сосотояние
# реагируют ← реагирует → реагирует
# захотела ← заъотела → заъотела
# написать ← напсиать → напсиать
# очень ← ооооочень → ооооочень
# еще ← ишшо → ишшо
# обещаю ← обещаю → обещал
# это ← ето → что
# открытки ← откпытки → откпытки
# очень ← оооочень → оооочень
# вообще ← ваще → чаще
# черт-те ← черти → черти
# спасибо ← спаааасиб → спаааасиб
# отдельное ← одтельное → одтельное
# насчет ← нащет → нащет
# люблю ← любю → любую
# естественно ← естесственно → естесственно
# естественно ← естессно → естессно
# сливает ← сливает → сбивает
# урока ← урока → срока
# сворачиваю ← сварачиваю → сварачиваю
# баррикады ← барикады → барикады
# обещают ← обешают → обешают
# маминой ← маминой → машиной
# очень ← оооочень → оооочень
# товарищ ← товарисч → товарисч
# определяешься ← определяешся → определяется
# сообщите ← сообщете → сообщете
# как-то ← както → факто
# наберешься ← наберешся → наберешся
# тварь ← тварррь → тварррь
# ничего ← ничо → нико
# товарищ ← товарисч → товарисч
# можно ← можнго → можнго
# расставаньям ← раставаньям → раставаньям
# девчонки ← девченки → девченки
# спускаюсь ← спускюсь → спускюсь
# товарищ ← товарисч → товарисч
# что ← че → че
# еще ← ещее → ещее
# тысяч ← тыш → тыс
# поздравляю ← поздравлдяю → поздравлдяю
# давно ← давнооо → давнооо
# посмотрели ← пасмарели → пасмарели
# проблемная ← проблемнная → проблемнная
# оттуда ← отуда → откуда
# и ← ии → ии
# коктейль ← коктель → коктель
# усовершенствованный ← усовершенстваванный → усовершенстваванный
# профилактика ← профилиактика → профилиактика
# химиотерапии ← химиотерпии → химиотерпии
# скриншот ← скришнот → скришнот
# вообще ← ваще → чаще
# оказывается ← оказываецца → оказываецца
# посочувствовали ← посочуствовали → посочуствовали
# курю ← курю → курс
# охранник ← охраниик → охраниик
# очень ← ооочень → ооочень
# ссылка ← сцылка → сцылка
# поспишь ← поспшь → поспшь
# непонятных ← непонятнх → непонятно
# объясняла ← объяснала → объяснила
# начальнице ← началнице → началнице
# серебряные ← серебрянные → серебрянные
# из-за ← изза → изба
# куску ← куску → куско
# как-то ← както → факто
# теперь ← тепреь → тепреь
# банкроты ← банкроты → банкноты
# придется ← придеться → придеться
# стесняюсь ← стисняюсь → стисняюсь
# коломенское ← коломнеское → коломнеское
# потом ← потмо → потмо
# одноклассники ← однаклассники → однаклассники
# долго ← дооолго → дооолго
# остается ← остаецца → остаецца
# смириться ← смириццо → смириццо
# бороться ← бороццо → бороццо
# впечатление ← впечталение → впечталение
# что ← што → што
# черный ← чорный → чёрный
# мультики ← мууультики → мууультики
# вернулась ← вернууулась → вернууулась
# рaда ← рааада → рааада
# представьте ← представте → представте
# обрызгивается ← оббрызгивается → оббрызгивается
# подливает ← подливет → подливет
# потихоньку ← по-тихоньку → по-тихоньку
# планируем ← планируем → планирует
# развиться ← развицо → развито
# мужчина ← мущщина → мущщина
# параллельно ← паралелльно → паралелльно
# трата ← трата → брата
# постарайтесь ← прстарайтесь → прстарайтесь
# аборигенку ← абоpигенку → абоpигенку
# приезжей ← пpиезжей → пpиезжей
# насчет ← нащет → нащет
# почувствовав ← почувстовав → почувстовав
# поешьте ← поеште → поеште
# насчет ← нащет → нащет
# yкладываются ← yкладываются → складываются
# котоpых ← котоpых → которых
# не ← ни → ни
# очень ← ооочень → ооочень
# потрясающая ← потресающия → потресающия
# преподавательница ← преподовательница → преподовательница
# нравятся ← нравяться → нравяться
# счастливая ← счастлиывая → счастлиывая
# кошка ← кошшшшка → кошшшшка
# мягче ← мягше → мягше
# кто-то ← ктото → ктото
# кто-то ← ктото → ктото
# кто-то ← ктото → ктото
# естественно ← естесственно → естесственно
# сегодня ← седня → седня
# принципы ← приниципы → приниципы
# применяю ← применяю → применяют
# естественно ← естесственно → естесственно
# одиночеством ← одночеством → одночеством
# желаньем ← желаньем → желанием
# просмотр ← просмотер → просмотер
# контакте ← контакти → контакты
# естественно ← естесственно → естесственно
# никуда ← нукда → нукда
# ответьте ← ответтье → ответтье
# естественно ← естесственно → естесственно
# минутам ← минутам → минутах
# какие-то ← какие → какие
# плотники ← то → то
# объясняя ← плотники → плотники
# экзаменатору ← объясняя → объясняя
# что ← экзаменатору → экзаменатору
# связались ← что → что
# с ← связались → связались
# ней ← с → с
# через ← ней → ней
# емайл ← через → через
# говорилось ← емайл → емайл
# о ← говорилось → говорилось
# заборе ← о → о
# который ← заборе → заборе
# не ← который → который
# закрывается ← не → не
# затем ← закрывается → закрывается
# зашла ← затем → затем
# не ← зашла → зашла
# знаю ← незнаю → незнаю
# что-то ← чо-то → чо-то
# ничего ← ничо → нико
# скажи ← сцкажи → сцкажи
# его ← иво → иво
# шоколаде ← шоколаде → шоколада
# придется ← прийдется → прийдется
# совпали ← срвпали → срвпали
# связываем ← связываем → связывает
# заботились ← забоились → забоились
# когда-то ← когдато → когдато
# запятых ← запятых → занятых
# вставлял ← встявлял → встявлял
# позаботьтесь ← позабодтесь → позабодтесь
# пофотографировав ← пофоторафировав → пофоторафировав
# очищенный ← очищеный → очищеный
# новогоднее ← навогоднее → навогоднее
# естественно ← ессно → ессно
# вообще ← ваще → чаще
# постебался ← постибалса → постибалса
# потому ← потсому → потсому
# сногсшибательной ← сногсшибальной → сногсшибальной
# удается ← удеается → удеается
# благодаря ← бплгодаря → бплгодаря
# извините ← извените → извените
# это ← эта → эта
# проверка ← провекрка → провекрка
# когда-то ← когдато → когдато
# девчонки ← девченки → девченки
# написать ← напистаь → напистаь
# стасу ← стасу → стану
# ливня ← ливня → ливия
# мыле ← мыле → мысе
# пытаюсь ← пыраюсь → пыраюсь
# непредвиденные ← непридвиденные → непридвиденные
# поздравляю ← поздрваляю → поздрваляю
# говорю ← грю → грю
# ничего ← ничо → нико
# как-то ← както → факто
# хотеться ← хотеццо → хотеццо
# убиться ← убиться → учиться
# веником ← веником → великом
# нравится ← нравиццо → нравиццо
# поздравляю ← посдравляю → посдравляю
# очень ← ооочень → ооочень
# чувствовать ← чувстоввать → чувстоввать
# погода ← погда → когда
# как ← кааак → казак
# как ← каааак → каааак
# поверхностное ← поверхносное → поверхносное
# неискреннее ← неискренное → неискренное
# мастер-классах ← мастре-классах → мастре-классах
# вот ← воооот → воооот
# хочется ← хочеться → хочеться
# съездила ← съездела → съездела
# понаобещал ← понаобещщал → понаобещщал
# неуравновешенно ← неуравновешено → неуравновешено
# центром ← центрм → центра
# сильно ← вильно → вильно
# влево ← влева → слева
# расскажу ← рассказжу → рассказжу
# покажи ← покажиииии → покажиииии
# пожинаем ← поженаем → поженаем
# девчонками ← девочнками → девочнками
# 2/3 ← 2/3 → 273
# придется ← придеться → придеться
# некоторым ← некотороым → некотороым
# действие ← дейстиве → дейстиве
# лекарствами ← лекарствоми → лекарствоми
# собственно ← собсно → собсно
# прямо ← пррямо → пррямо
# зуб ← ззуб → ззуб
# зуб ← ззуб → ззуб
# попадает ← поппадает → поппадает
# как-то ← какето → какето
# изюминку ← изуминку → изуминку
# мне ← мной → мной
# будешь ← будеш → будет
# свои ← сваи → сваи
# описывать ← аписывать → записывать
# чтоб ← шоб → шоу
# расчет ← рассчет → рассвет
# берем ← берем → берег
# ничего ← ничо → нико
# совладав ← совлаладав → совлаладав
# мудрейший ← мудреший → мудреший
# прочитала ← прочтала → прочтала
# жизнь ← жизни → жизни
# очень ← оччень → оччень
# неожиданно ← неожиданнго → неожиданнго
# прекратите ← прератите → прератите
# собственно ← собссно → собссно
# хочется ← хочеться → хочеться
# 1101 ошибок из 9995 слов
# Точность: 0.890

# %% [markdown]
# 1101 ошибок из 9995 слов
#
# Точность: 0.890

# %%
def correction_4(word):

    if word in vocab:
        return word


    candidates = set()

    if word in delete_dict:
        candidates.update(delete_dict[word])

    if len(word) > 4:

        for i in range(len(word)):
            deletion = word[:i] + word[i+1:]
            if deletion in delete_dict:
                candidates.update(delete_dict[deletion])

    MIN_FREQ = 13
    candidates = {w for w in candidates if vocab.get(w, 0) >= MIN_FREQ}

    MAX_DISTANCE = 1
    candidates = {w for w in candidates if textdistance.levenshtein.distance(word, w) <= MAX_DISTANCE}

    if candidates:
        return max(candidates, key=lambda w: vocab.get(w, 0))

    return word

# %%
count_errors_symspell(bad, true, correction_4)
# Out:
# симпатичнейшее ← симпатичнейшое → симпатичнейшое
# апофеозом ← опофеозом → опофеозом
# поясним ← пояним → пояним
# получатся ← полчатся → полчатся
# очень ← оччччень → оччччень
# насчет ← нащщот → нащщот
# основная ← основая → основан
# напрасно ← нарасно → нарасно
# в ← вобщем → вобщем
# общем ← как → как
# как ← вы → вы
# вы ← знаете → знаете
# знаете ← из → из
# из ← моего → моего
# моего ← не → не
# недавнего ← давнего → давнего
# ящика ← ящека → ящека
# предлагаю ← предлагю → предлагю
# сегодняшнее ← сегодяшнее → сегодяшнее
# снятся ← снятся → снялся
# потому ← патаму → патаму
# что ← шта → шта
# пытаюсь ← пытаюсь → пытаясь
# повтыкав ← поффтыкав → поффтыкав
# ссоре ← соре → соре
# что-то ← чтото → чтото
# молодежь ← молодеж → молодеж
# участвовать ← учавствовать → учавствовать
# сегодня ← седня → седня
# навешать ← вешать → вешать
# это ← эт → эт
# конечно ← канешна → канешна
# начальник ← начальнег → начальнег
# зажег ← зажог → залог
# по-взрослому ← павзрослому → павзрослому
# предыдущую ← предудущую → предудущую
# подсаживается ← подсаживаеться → подсаживаеться
# какие-то ← какието → какието
# малолетние ← малолетнии → малолетнии
# молодежь ← молодеж → молодеж
# ощущаю ← ощушаю → ощушаю
# монголоидом ← монголойдом → монголойдом
# молчу ← молчю → молчю
# объелись ← обълись → обълись
# веселились ← ввеселились → ввеселились
# расспрашивая ← распрашивая → распрашивая
# зубодробительная ← зубодробительня → зубодробительня
# как ← каааак → каааак
# хочется ← хочеться → хочеться
# письмена ← писмена → писмена
# супермаркете ← супер-маркете → супер-маркете
# серебряные ← серебрянные → серебрянные
# расшифровать ← расщифровать → расщифровать
# самой-то ← самойто → самойто
# тут ← тул → тул
# вообще ← ваще → ваще
# только ← тока → тока
# наверное ← навернео → навернео
# очень ← ооочень → ооочень
# стараюсь ← стараюсь → стараясь
# как-то ← както → факто
# мужчину ← мущщину → мущщину
# никогда ← никада → никуда
# очень ← оооочень → оооочень
# симпатическая ← симаатическая → симаатическая
# потовые ← потовые → почтовые
# перспектива ← першпектива → першпектива
# препараты ← припораты → припораты
# съездили ← съездели → съездели
# расчете ← рассчете → рассвете
# купим ← купим → купил
# приветствуется ← приветствутется → приветствутется
# опасался ← опаслася → опаслася
# разжился ← расжился → расжился
# однажды ← однажэды → однажэды
# зубные ← зуные → зуные
# пользоваться ← пользоваццо → пользоваццо
# сочувствующие ← сочуствующие → сочуствующие
# креатив ← креатифф → креатифф
# если ← нсли → несли
# челка ← челка → белка
# естественно ← естесственно → естесственно
# обнимает ← однимает → поднимает
# основные ← основыные → основыные
# получается ← получаеться → получаеться
# разрушается ← разрушаеться → разрушаеться
# координирует ← кроординирует → кроординирует
# движение ← движениие → движениие
# правило ← правила → правила
# рассказчик ← расказчик → расказчик
# прочитал ← проичитал → проичитал
# открываю ← открыывю → открыывю
# написано ← написанно → написанной
# высыпание ← высыпвние → высыпвние
# пересказывать ← перессказывать → перессказывать
# пьяный ← пяный → пятый
# что-то ← чтото → чтото
# собственно ← собстно → собстно
# священнослужители ← священослужители → священослужители
# рясах ← рясах → рядах
# неосознанно ← неососознанно → неососознанно
# сохраню ← сохраю → сохраю
# сыро ← сыро → сырой
# вообще ← ваще → ваще
# ад ← ат → ат
# по-прежнему ← попрежнему → попрежнему
# никогда ← никада → никуда
# позже ← пожже → пожже
# когда-то ← когдато → когдато
# отдала ← отадала → отадала
# вообще ← ваще → ваще
# все ← фсе → фсе
# насчет ← нащет → нащет
# гулливера ← гуливера → гуливера
# самый ← самыи → самым
# гадости ← гадости → радости
# на ← но → но
# никак ← не-как → не-как
# обидели ← обидели → обители
# рекомендации ← рекоммендация → рекоммендация
# напроектировали ← напректировали → напректировали
# одноклассниках ← однокласниках → однокласниках
# вообще ← ваще → ваще
# еще ← еше → еше
# асфальтоукладчик ← афальтоукладчик → афальтоукладчик
# качество ← кчакчество → кчакчество
# зажатия ← зажатия → зачатия
# разве ← разьве → разьве
# прикольные ← прикодьные → прикодьные
# одноклассников ← однокласников → однокласников
# собственно ← собстно → собстно
# хочется ← хочеться → хочеться
# посмотреть ← помотрть → помотрть
# хочется ← хочеться → хочеться
# прикольные ← пприкольные → пприкольные
# начните ← начьните → начьните
# он ← онвыгребает → онвыгребает
# выгребает ← ее → ее
# ее ← из → из
# из-под ← под → под
# не ← небыло → небыло
# было ← никогда → никогда
# никогда ← любви → любви
# любви-то ← то → то
# мужиков ← мужуков → мужуков
# сегодняшние ← сегодяшние → сегодяшние
# начальник ← начальнег → начальнег
# зайти ← заити → гаити
# вконтакт ← вконтакт → вконтакте
# потеряна ← потреяна → потреяна
# ненавидишь ← ненавидшь → ненавидшь
# мыслящая ← мыслящаю → мыслящаю
# убрать ← убрть → убить
# процедура ← процедудура → процедудура
# коммунисты ← коммуниисты → коммуниисты
# сегодня ← седня → седня
# ответственно ← ответсвенно → ответсвенно
# очень ← оооочень → оооочень
# бесит ← бесит → бежит
# получается ← получаеться → получаеться
# серой ← сером → сером
# рисунком ← рисунко → рисунки
# продолжение ← продолжения → продолжения
# спасибо ← сапсибо → сапсибо
# тасовать ← тасовоать → тасовоать
# основной ← основныой → основныой
# очень ← оочень → оочень
# все ← фсе → фсе
# сегодня ← седня → седня
# страшно ← страааашно → страааашно
# нравятся ← нравяться → нравяться
# обогреватель ← обогреватель → обозреватель
# конечно ← канешна → канешна
# компания ← компнаия → компнаия
# превратит ← превратит → превратить
# праздник ← празнег → празнег
# встретиться ← встретицца → встретицца
# нахожусь ← нажусь → нажусь
# вообще ← ваще → ваще
# организмы ← огранизмы → огранизмы
# долго ← дооолго → дооолго
# садиться ← садится → садится
# серебряном ← серебрянном → серебрянном
# сегодня ← седня → седня
# по-любому ← полюбому → полюбому
# еще ← еше → еше
# ослуживание ← ослуживание → обслуживание
# безупречное ← безупречноне → безупречноне
# ищете ← ищите → ищите
# какого ← какова → какова
# района ← раена → равна
# объясни ← объясни → объяснил
# продолжительность ← пролжительность → пролжительность
# симпатичный ← симпотичный → симпотичный
# продул ← продул → продал
# угощали ← угошали → угошали
# открыл ← отркрыл → отркрыл
# подделанная ← подделаная → подделаная
# подробный ← подрбный → подобный
# обдумываю ← обдумывю → обдумывю
# отечественные ← отечетсвенные → отечетсвенные
# познакомиться ← познакомицца → познакомицца
# монастырь ← монастрырь → монастрырь
# большой ← большое → большое
# не ← незнаю → незнаю
# знаю ← ходить → ходить
# ходить ← на → на
# на ← море → море
# море ← делать → делать
# делать ← ремонт → ремонт
# ремонт ← кого → кого
# кого-нибудь ← нибудь → нибудь
# сроду ← сроду → среду
# осчастливленный ← ощастливленный → ощастливленный
# выхожу ← выхожу → выходу
# решаем ← решаем → решает
# колой ← колой → школой
# что ← чть → чуть
# естественно ← естесственно → естесственно
# естественно ← естесственно → естесственно
# поведайте ← поведйте → поведйте
# только ← тока → тока
# естественно ← естесственно → естесственно
# естественно ← естесственно → естесственно
# спасибо ← спапсибо → спапсибо
# начальник ← начальнег → начальнег
# поднимать ← поднмать → поднмать
# читаемость ← читаемсоть → читаемсоть
# мальчики ← мальчеги → мальчеги
# хорошее ← хооршее → хооршее
# потому ← потмоу → потмоу
# работодатели ← работадатели → работадатели
# присоединяюсь ← присоединаюсь → присоединаюсь
# это ← ето → лето
# сегодня ← седня → седня
# лосьончика ← лосьончека → лосьончека
# очень ← очнеь → очнеь
# парламентский ← парламентський → парламентський
# привезла ← приезла → приезда
# просвистевшая ← просвестевшая → просвестевшая
# обернуться ← оберутся → оберутся
# матерю ← матерю → матери
# сегодня ← седня → седня
# лишил ← лешил → решил
# постарайтесь ← постарайтеь → постарайтеь
# сумасшедшего ← сумашедшего → сумашедшего
# извините ← извените → извените
# чувствовалась ← чувстовалась → чувстовалась
# гордиться ← гордится → гордится
# поссорилась ← посорилась → посорилась
# каким-нибудь ← какимнить → какимнить
# лж ← лж → лож
# рюкзак ← рюкзазк → рюкзазк
# даже ← дае → дае
# вообще ← ваще → ваще
# мозаика ← мозайка → мозайка
# любое ← любоее → любоее
# паутину ← паути → паути
# непридуманная ← неридуманная → неридуманная
# история ← истоиря → истоиря
# пересказываю ← перессказываю → перессказываю
# подгрузился ← подргрузился → подргрузился
# основная ← основвная → основвная
# набирала ← наберала → наберала
# девчонки ← девченки → девченки
# завизжали ← завижжали → завижжали
# невозможно ← невозмозможно → невозмозможно
# пишите ← пишиите → пишиите
# неоднозначное ← неодназначное → неодназначное
# строятся ← стороятся → стороятся
# расчет ← рассчет → рассвет
# эмоциональная ← эмоциональаня → эмоциональаня
# кинокомпанией ← кинопокмпанией → кинопокмпанией
# будешь ← будеш → будет
# естественно ← естесственно → естесственно
# преинтереснейшее ← преинтерснейшее → преинтерснейшее
# долго ← дооолго → дооолго
# я ← мя → мя
# привыкла ← привыкла → привыкли
# очень ← оооочень → оооочень
# сегодня ← седня → седня
# что ← што → што
# осталось ← осталалось → оставалось
# статусы ← стратусы → стратусы
# смешные ← смшные → смшные
# однокурсница ← однокурссница → однокурссница
# естественно ← естесственно → естесственно
# мозг ← мозк → мозк
# естественно ← ессно → ессно
# завтра ← заффтра → заффтра
# получается ← получаеться → получаеться
# придется ← придеться → придеться
# позавчера ← позаввчера → позаввчера
# наконец-то ← наконецто → наконецто
# ручонки ← рученки → рученки
# кнопочки ← кнопачки → кнопачки
# прикладываем ← прикладывам → прикладывам
# следите ← следеите → следеите
# пассажирам ← пасажирам → пасажирам
# лежаки ← лежаки → лежали
# территорию ← территроию → территроию
# любопытства ← любопатства → любопатства
# деньги ← денги → денги
# отдаются ← отдаються → отдаються
# замечательные ← замечаельные → замечаельные
# насчет ← нащет → нащет
# отбеливания ← отбеливание → отбеливание
# еще ← еше → еше
# трехчасовой ← 3хчасовой → 3хчасовой
# кодексам ← кодексам → кодексом
# заверив ← заверив → завершив
# официально ← оффициально → оффициально
# обрадовались ← обрадовались → образовались
# очень ← ооочень → ооочень
# прагматично ← прогматично → прогматично
# общаются ← общаються → общаються
# соедините ← соедените → соедените
# в ← вобщем → вобщем
# общем ← сниццо → сниццо
# снится ← мне → мне
# мне ← что → что
# что ← я → я
# я ← нашел → нашел
# нашел-таки ← таки → таки
# практически ← практичнески → практичнески
# естественно ← естесственно → естесственно
# сволочи ← сволачи → сволачи
# она ← ана → ана
# стрельбище ← стельбище → стельбище
# как-то ← както → факто
# очень ← оооочень → оооочень
# холодная ← холооодная → холооодная
# гостиная ← гостинная → гостинная
# вообще ← ваще → ваще
# долго-долго-долго ← доолго-дооолго-доооолго → доолго-дооолго-доооолго
# насчет ← нащет → нащет
# естественно ← ессно → ессно
# экскурсоводы ← эксурсоводы → эксурсоводы
# субботу ← субодту → субодту
# покажут ← покажунт → покажунт
# кино ← кено → кено
# кидал ← кедал → кедал
# кидалы ← кедалы → кедалы
# подскажите ← подскажыте → подскажыте
# кровищи ← кровищщи → кровищщи
# предлагаю ← прердлагаю → прердлагаю
# нравятся ← нравяться → нравяться
# покопаться ← покапаться → показаться
# люда ← люда → блюда
# очень ← ооочень → ооочень
# сентябрьский ← сентябрский → сентябрский
# рекомендую ← рекокомендую → рекокомендую
# промозгло ← проморзгло → проморзгло
# в ← вообщем → вообщем
# общем-то ← то → то
# распределить ← рапредилить → рапредилить
# сушить ← сушить → судить
# одноклассники ← однаклассники → однаклассники
# напьешься ← напьешся → напьешся
# обожаю ← обажаю → обажаю
# насущного ← нсущного → нсущного
# теоретизированное ← теоретизированое → теоретизированое
# чтобы ← что → что
# больно ← бы → бы
# не ← больно → больно
# было ← небыло → небыло
# созерцать ← соцерцать → соцерцать
# провинция ← провниция → провниция
# разгадать ← разгодать → разгодать
# хочется ← хочеться → хочеться
# это ← ето → лето
# одна ← одно → одно
# очень ← оооочень → оооочень
# адски ← аццки → аццки
# кощунство ← кошунство → кошунство
# способность ← спаособность → спаособность
# несколько ← нескольнко → нескольнко
# одноклассники ← однаклассники → однаклассники
# мамочки ← мааааммоооочкииии → мааааммоооочкииии
# госов ← госов → годов
# нравится ← нравиться → нравиться
# программка ← програмка → программа
# пресловутая ← преславутая → преславутая
# извините ← извените → извените
# выразился ← вырозился → вырозился
# напомнило ← напоменило → напоменило
# старый ← стааарый → стааарый
# придя ← прийдя → пройдя
# ирокез ← иракез → иракез
# это ← ето → лето
# прикол ← прекол → прекол
# объехав ← обьехав → обьехав
# въехал ← вьехал → выехал
# получается ← получаеться → получаеться
# получается ← получаеться → получаеться
# не ← ни → ни
# половозрелые ← половозрлые → половозрлые
# естественно ← естесственно → естесственно
# как ← какбы → какбы
# бы ← из → из
# из-под ← под → под
# очень ← ооочень → ооочень
# новозаветная ← новозаветняя → новозаветняя
# это ← ето → лето
# это ← ето → лето
# обычные ← обычныэ → обычных
# негодные ← негодныэ → негодныэ
# люблю ← любю → любую
# потратить ← потртатить → потртатить
# расчетов ← рассчетов → рассчетов
# как-то ← както → факто
# вообще ← ваще → ваще
# бабешку ← бабежку → бабежку
# трепа ← трепа → трека
# жемчужинки ← жемчуженки → жемчуженки
# постарее ← постраее → постраее
# придя ← прийдя → пройдя
# сколько ← сколкьо → сколкьо
# острове ← острое → острое
# семантическая ← семантческая → семантческая
# превратиться ← превратититься → превратититься
# смяться ← смяться → сняться
# стечь ← стечь → степь
# все-таки ← все-таик → все-таик
# наконец-то ← наконецто → наконецто
# наконец-то ← наконецто → наконецто
# фоток ← фоток → поток
# залил ← залил → забил
# что ← че → че
# это ← ето → лето
# утешаюсь ← утешюсь → утешюсь
# обмороженных ← обмороженых → обмороженых
# ошпаренных ← ошпареных → ошпареных
# пытаюсь ← пыттаюсь → пыттаюсь
# отпраздную ← отпразную → отпразную
# простите ← проостите → проостите
# начали ← начаили → начаили
# хочется ← хочеться → хочеться
# полетим ← поелетим → поелетим
# спасибо ← пасиб → пасиб
# сегодня ← седня → седня
# со ← сос → сос
# встречавшимися ← встречавщимися → встречавщимися
# солнышком ← солнушком → солнушком
# поэтому ← поэтмоу → поэтмоу
# насчет ← насчт → насчёт
# меняемся ← меняемся → меняется
# пронзительно ← пронизтельно → пронизтельно
# хочется ← хочеться → хочеться
# начальник ← начальнег → начальнег
# сегодня ← седня → седня
# чудесный ← чудестный → чудестный
# напыщенные ← напыщеные → напыщеные
# понедельник ← понедельнег → понедельнег
# продолжаем ← прдолжаем → прдолжаем
# солнце ← солцне → солцне
# только ← тока → тока
# сегодня ← седня → седня
# прямо ← пррямо → пррямо
# пинг-понг ← пингу-понгу → пингу-понгу
# предыстория ← предъистория → предъистория
# очень ← ооочень → ооочень
# сегодня ← седня → седня
# очень ← оочень → оочень
# добавляю ← добавляю → добавляют
# мясные ← мысные → мысные
# отдирала ← отдирла → отдирла
# бантики ← бантики → балтики
# отдыхаем ← отыхаем → отыхаем
# конечно ← канешно → канешно
# по-любому ← полюбому → полюбому
# ого-го ← огого → огого
# вообще ← ваще → ваще
# незнакомая ← низакомая → низакомая
# девчонка ← дивченка → дивченка
# погода ← погда → когда
# рекомендуемо ← рекомундуемо → рекомундуемо
# равно ← ровно → ровно
# тахту ← тахту → тарту
# шкварчать ← шкворчать → шкворчать
# остальное ← остально → остальной
# ничего ← ниччего → ниччего
# тогда ← огда → когда
# справедливыми ← саправедливыми → саправедливыми
# слезятся ← слезяться → слезяться
# просмотреть ← просмотрет → просмотрет
# очень ← оочень → оочень
# что-то ← чтото → чтото
# как-то ← както → факто
# разве ← разьве → разьве
# получилась ← получилсась → получилсась
# найдутся ← найдуться → найдуться
# экспериментируя ← эксперементируя → эксперементируя
# рассматривает ← рассматирвает → рассматирвает
# очень ← ооочень → ооочень
# раскрытие ← расскрытие → расскрытие
# нашел ← нашол → нашёл
# совсем ← сосвсем → сосвсем
# прожигам ← прожегам → прожегам
# очень ← ооочень → ооочень
# мужчина ← мущщина → мущщина
# хочется ← хочеться → хочеться
# эгоистично ← егоистично → егоистично
# присоединишься ← присоеденишься → присоеденишься
# эх ← ээээххх → ээээххх
# очень ← оочень → оочень
# продажа ← продаа → продаж
# поздравляю ← поздравяю → поздравяю
# никогда ← никоглда → никоглда
# смирительную ← смерительную → смерительную
# дав ← даф → даф
# как-то ← както → факто
# отсрочку ← осрочку → осрочку
# охранник ← охраниик → охраниик
# по-любому ← полюбому → полюбому
# сегодня ← седня → седня
# очень ← ооооочень → ооооочень
# больше ← болше → более
# нашел ← нашол → нашёл
# хочется ← хочеться → хочеться
# горча ← горча → горка
# вообще ← ваще → ваще
# миллиарды ← милиардны → милиардны
# трех ← 3ех → 3ех
# поздравляю ← паздравляю → паздравляю
# это ← ето → лето
# пассажир ← пассижир → пассижир
# хрен ← хрень → хрень
# скучно ← скууучнооо → скууучнооо
# ужас ← ужыс → ужыс
# дирижер ← дерижер → дерижер
# расчет ← рассчет → рассвет
# транспортировка ← траспортировка → траспортировка
# как-то ← как → как
# странно ← то → то
# на ← странно → странно
# улице ← на → на
# супер ← улице → улице
# просто ← супер → супер
# а ← просто → просто
# я ← а → а
# целый ← я → я
# день ← целый → целый
# проспала ← день → день
# потом ← проспала → проспала
# уборкой ← потом → потом
# занималась ← уборкой → уборкой
# ну ← занималась → занималась
# в ← ну → ну
# общем ← вобщем → вобщем
# низкокалорийное ← низкоколлорийное → низкоколлорийное
# ничего ← ничо → ничто
# посмотри ← посмоти → посмоти
# запропала ← запрапала → запрапала
# расчеты ← рассчеты → рассчеты
# как-то ← както → факто
# подозрительно ← подощрительно → подощрительно
# подискутировали ← подисскутировали → подисскутировали
# просто ← порсто → порсто
# люблю ← люблюд → люблюд
# счастлив ← счастлифф → счастлифф
# президент ← прензидент → прензидент
# рассказик ← рассказег → рассказег
# где ← гнде → гнде
# хочется ← хочеться → хочеться
# перезванивает ← презванивает → презванивает
# по-любому ← полюбому → полюбому
# любимый ← любимоый → любимоый
# нечаянно ← нечайнно → нечайнно
# правильная ← правльная → правльная
# прогулялся ← пррогулялся → пррогулялся
# наконец-то ← наконецто → наконецто
# лекарственные ← лекартсвенные → лекартсвенные
# опосля ← опопсля → опопсля
# левостороннее ← левостроннее → левостроннее
# выпадет ← выпадет → выпадает
# из-за ← изза → изза
# напротив ← напрортив → напрортив
# угораздило ← угараздило → угараздило
# намазываем ← намазывем → намазывем
# естественно ← естессно → естессно
# коридоры ← корридоры → корридоры
# бродили ← бродили → бросили
# ранее ← раннее → раннее
# пост ← псто → псто
# что-то ← чтото → чтото
# рыться ← рыццо → рыццо
# ничего ← ничо → ничто
# хочется ← хочеться → хочеться
# методологическое ← методолгическое → методолгическое
# сколько ← скока → скока
# сегодня ← седня → седня
# опухли ← опухли → опухоли
# девчонки ← девченки → девченки
# приземлились ← призимлились → призимлились
# целоваться ← целоваццо → целоваццо
# неудачники ← неудачнеги → неудачнеги
# спать ← сппать → сппать
# симпатичный ← симпотичный → симпотичный
# погуляем ← погкуляем → погкуляем
# обязательно ← обязаательно → обязаательно
# послезавтра ← послезафтра → послезафтра
# тусовка ← туссовка → туссовка
# открыла ← отркыла → отркыла
# обещанные ← обесчанные → обесчанные
# четвертая ← четвртая → четвёртая
# остановились ← отсановились → отсановились
# потому ← птому → этому
# свой ← сво → сво
# пожалуйста ← пожалуйсто → пожалуйсто
# очередная ← очеренданя → очеренданя
# оттуда ← отуда → откуда
# кто-то ← ктото → ктото
# привязанность ← првязанность → првязанность
# папилломавирусы ← папиломавирусы → папиломавирусы
# естественно ← естессно → естессно
# приятного ← прияного → прияного
# комендант ← коммендант → коммендант
# резво ← резво → резко
# продавцы ← проавцы → проавцы
# адски ← ацки → ацки
# сегодня ← сегдьня → сегдьня
# патологически ← паталогически → паталогически
# пожелайте ← пожалайте → пожалайте
# представьте ← представитьте → представитьте
# попадались ← попадлись → попадлись
# съездил ← сьездил → сьездил
# разделенный ← разделеннный → разделеннный
# старую ← струю → струю
# только ← толькго → толькго
# что ← што → што
# смущение ← смушение → смешение
# хочется ← хочеться → хочеться
# ничего ← ничо → ничто
# пятница ← пятницца → пятницца
# из-за ← изза → изза
# запарного ← запарного → западного
# вечер ← ве4ер → ветер
# напроситесь ← напрситесь → напрситесь
# оказывается ← оказуеться → оказуеться
# сегодня ← седня → седня
# подойдите ← подойтите → подойтите
# требую ← требую → требуют
# террористический ← террорестический → террорестический
# естественно ← естесственно → естесственно
# профессиональные ← проффессиональные → проффессиональные
# незнакомка ← незнакомка → незнакомца
# стартапу ← страртапу → страртапу
# катастрофически ← катострофически → катострофически
# что ← што → што
# причисляя ← причесляя → причесляя
# направлению ← нарпавлению → нарпавлению
# приходится ← приходиться → приходиться
# мелодрамы ← мелодрамми → мелодрамми
# наконец-то ← наконецто → наконецто
# очень ← ооооочень → ооооочень
# полночи ← полночи → полуночи
# одноклассники ← однаклассники → однаклассники
# базируемся ← базируемся → базируется
# молодежь ← молодеж → молодеж
# что-то ← чтото → чтото
# сходили ← схходили → схходили
# хочется ← хочеться → хочеться
# сегодня ← седня → седня
# сегодня ← седня → седня
# что ← че → че
# вот ← вооот → ворот
# 4-х ← 4х → 4х
# фоток ← фоток → поток
# фаланги ← фалаги → фалаги
# смотрятся ← смотряться → смотряться
# удалить ← удаплить → удаплить
# из-за ← изза → изза
# лучше ← лушче → лушче
# отбеливание ← отбеливанее → отбеливанее
# обожаю ← обажаю → обажаю
# кривляться ← кривлятся → кривлятся
# хочется ← хочеться → хочеться
# самодостаточность ← самоодостаточность → самоодостаточность
# разве ← разьве → разьве
# парализована ← парализованна → парализованна
# что ← чтот → чтот
# что-то ← чтото → чтото
# в ← у → у
# очень ← ооочень → ооочень
# ненавижу ← неневижу → неневижу
# безысходность ← бузысходность → бузысходность
# нельзя ← нельязя → нельязя
# прощать ← прощать → продать
# яси ← яси → ясли
# очень ← ооооочень → ооооочень
# сегодня ← седня → седня
# сегодня ← седня → седня
# позитив ← пазитив → пазитив
# террористы ← терраристы → терраристы
# очень ← оооочень → оооочень
# обтереть ← обтиреть → обтиреть
# претендент ← претендет → претендет
# очень ← ооооочень → ооооочень
# проклятые ← прррроклятые → прррроклятые
# ведомость ← ведомость → ведомости
# очень ← ооочень → ооочень
# сегодня ← седня → седня
# азербайджан ← азейрбаджан → азейрбаджан
# восхитительный ← восхетительный → восхетительный
# вообще ← ваще → ваще
# поскользнулся ← поскользулся → поскользулся
# хирурге ← хирурге → хирурга
# девчонки ← девченки → девченки
# собственно ← собстно → собстно
# посмотрела ← поссмотрела → поссмотрела
# самый ← сааамый → сааамый
# очень-очень ← ооочень-очень → ооочень-очень
# видать ← видать → видеть
# придется ← придеться → придеться
# чертов ← чортов → сортов
# онтогенетически ← онтогинетически → онтогинетически
# растолкала ← расталкала → расталкала
# какая-то ← какаято → какаято
# пишется ← пишеться → пишеться
# приметы ← прметы → прметы
# съемочной ← съемолчной → съемолчной
# зарегистрироваться ← зарегистрироаться → зарегистрироаться
# напрашиваются ← напрашиваюттся → напрашиваюттся
# собственно ← собстно → собстно
# очень ← ооочень → ооочень
# тащусь ← ташшусь → ташшусь
# может ← можеть → можете
# маршрут ← маршурт → маршурт
# вообще ← ващще → ващще
# подонок ← падонаг → падонаг
# неопределенное ← неопределнное → неопределнное
# перкуссионист ← перкуссинист → перкуссинист
# одноклассники ← однокласники → однокласники
# почему-то ← почему → почему
# завис ← то → то
# в ← завис → завис
# общем ← вообщем → вообщем
# в ← вообщем → вообщем
# общем-то ← то → то
# отрисовала ← отрисавала → отрисавала
# кто-то ← ктото → ктото
# ведь ← веть → ветвь
# все-таки ← фсе-таки → фсе-таки
# естественно ← естессно → естессно
# получается ← получаеться → получаеться
# потому ← потомучто → потомучто
# что ← просто → просто
# просто ← невозможно → невозможно
# невозможно ← все → все
# все ← это → это
# это ← выместить → выместить
# вместить ← в → в
# в ← карточку → карточку
# карточку ← ну → ну
# ну ← ни → ни
# никак ← как → как
# накатило ← нактило → нактило
# наверху ← нверху → сверху
# поддерживаем ← поддерживаем → поддерживает
# пожалеть ← пажалеть → пажалеть
# его ← иво → иво
# сочувствие ← сачуствие → сачуствие
# успокоить ← успакоить → успакоить
# человека ← чилавека → чилавека
# сегодня ← седня → седня
# миллион ← мильон → миньон
# вообще ← ваще → ваще
# творите ← тварите → тварите
# теперь ← терь → тверь
# возрастающей ← возростающей → возростающей
# вообще ← ваще → ваще
# отлично ← атлична → атлична
# предлагаю ← предлогаю → предлогаю
# кому-то ← комуто → комуто
# потому ← потмоу → потмоу
# неорганизованная ← неорганизованая → неорганизованая
# организм ← организьм → организьм
# первый ← певрый → певрый
# становится ← становиццо → становиццо
# ватной ← ватной → важной
# наверно ← наврено → наврено
# мечи ← мячи → мячи
# сегодня ← сегододня → сегододня
# попытке ← попытки → попытки
# ответственность ← ответствтенность → ответствтенность
# осамы ← осамы → осады
# слетел ← члетел → члетел
# рязань ← рязнань → рязнань
# папилломовирус ← папиломовирус → папиломовирус
# чувствую ← чувсвую → чувсвую
# интересно ← интерстно → интерстно
# сейчас ← ща → ща
# ничего ← ничо → ничто
# адский ← аццкий → аццкий
# миллиардер ← милиардер → милиардер
# будить ← будить → судить
# одел ← одел → отдел
# что-то ← чтото → чтото
# чувствуется ← чувствуеться → чувствуеться
# сегодня ← седня → седня
# карачках ← корачках → корачках
# предлагаю ← предалагаю → предалагаю
# конечно ← канешна → канешна
# частников ← частников → участников
# ничего ← ничо → ничто
# не ← нне → нне
# почувствовала ← почувстовала → почувстовала
# режиссеру ← режисеру → режисеру
# что ← што → што
# что ← то → то
# когда-то ← когдато → когдато
# естественно ← естесственно → естесственно
# процветание ← прочветание → прочветание
# сегодня ← седня → седня
# из-за ← изза → изза
# придется ← прийдется → прийдется
# очень ← ооочень → ооочень
# ненавижу ← нинавижу → нинавижу
# девок ← девак → девак
# постараюсь ← постарюсь → постарюсь
# приемлемый ← приемлимый → приемлимый
# вообще ← ваще → ваще
# товарищ ← товарисч → товарисч
# сегодня ← седня → седня
# пронесла ← пронесла → принесла
# электрокнигу ← электрогнигу → электрогнигу
# как ← каааак → каааак
# очень ← оооочень → оооочень
# хочется ← хочеца → хочеца
# усиленно ← усиленено → усиленено
# репбазы ← реп → реп
# которые ← базы → базы
# оказались ← которые → которые
# крайне ← оказались → оказались
# близкими ← крайне → крайне
# друзьями ← близкими → близкими
# нежданным ← друзьями → друзьями
# в ← нежданным → нежданным
# общем ← вобщем → вобщем
# рок-н-ролла ← рокенрола → рокенрола
# любовь ← любоффь → любоффь
# естественно ← естесственно → естесственно
# проанализировали ← проаализировали → проаализировали
# распределили ← распределили → распределяли
# хочется ← хочеться → хочеться
# собранное ← собьранное → собьранное
# оказалось ← оказалалось → оказалалось
# что ← че → че
# это ← ето → лето
# вообще-то ← вобще-то → вобще-то
# фантастические ← фантаститечские → фантаститечские
# состояние ← сосотояние → сосотояние
# тоже ← тоэе → тоэе
# реагируют ← реагирует → реагирует
# захотела ← заъотела → заъотела
# написать ← напсиать → напсиать
# очень ← ооооочень → ооооочень
# еще ← ишшо → ишшо
# обещаю ← обещаю → обещал
# это ← ето → лето
# открытки ← откпытки → откпытки
# очень ← оооочень → оооочень
# вообще ← ваще → ваще
# черт-те ← черти → черти
# спасибо ← спаааасиб → спаааасиб
# отдельное ← одтельное → одтельное
# насчет ← нащет → нащет
# люблю ← любю → любую
# естественно ← естесственно → естесственно
# естественно ← естессно → естессно
# сливает ← сливает → сбивает
# урока ← урока → срока
# сворачиваю ← сварачиваю → сварачиваю
# баррикады ← барикады → барикады
# обещают ← обешают → обешают
# маминой ← маминой → машиной
# очень ← оооочень → оооочень
# товарищ ← товарисч → товарисч
# определяешься ← определяешся → определяется
# сообщите ← сообщете → сообщете
# как-то ← както → факто
# наберешься ← наберешся → наберешся
# тварь ← тварррь → тварррь
# ничего ← ничо → ничто
# товарищ ← товарисч → товарисч
# можно ← можнго → можнго
# расставаньям ← раставаньям → раставаньям
# девчонки ← девченки → девченки
# спускаюсь ← спускюсь → спускюсь
# товарищ ← товарисч → товарисч
# что ← че → че
# еще ← ещее → ещее
# тысяч ← тыш → тыш
# поздравляю ← поздравлдяю → поздравлдяю
# давно ← давнооо → давнооо
# посмотрели ← пасмарели → пасмарели
# проблемная ← проблемнная → проблемнная
# оттуда ← отуда → откуда
# и ← ии → ии
# коктейль ← коктель → коктель
# усовершенствованный ← усовершенстваванный → усовершенстваванный
# профилактика ← профилиактика → профилиактика
# химиотерапии ← химиотерпии → химиотерпии
# скриншот ← скришнот → скришнот
# вообще ← ваще → ваще
# оказывается ← оказываецца → оказываецца
# посочувствовали ← посочуствовали → посочуствовали
# охранник ← охраниик → охраниик
# очень ← ооочень → ооочень
# ссылка ← сцылка → сцылка
# поспишь ← поспшь → поспшь
# непонятных ← непонятнх → непонятно
# объясняла ← объяснала → объяснила
# начальнице ← началнице → началнице
# серебряные ← серебрянные → серебрянные
# из-за ← изза → изза
# куску ← куску → куско
# как-то ← както → факто
# теперь ← тепреь → тепреь
# банкроты ← банкроты → банкноты
# придется ← придеться → придеться
# стесняюсь ← стисняюсь → стисняюсь
# коломенское ← коломнеское → коломнеское
# потом ← потмо → потмо
# одноклассники ← однаклассники → однаклассники
# долго ← дооолго → дооолго
# остается ← остаецца → остаецца
# смириться ← смириццо → смириццо
# бороться ← бороццо → бороццо
# впечатление ← впечталение → впечталение
# что ← што → што
# черный ← чорный → чёрный
# мультики ← мууультики → мууультики
# вернулась ← вернууулась → вернууулась
# рaда ← рааада → рааада
# представьте ← представте → представте
# обрызгивается ← оббрызгивается → оббрызгивается
# подливает ← подливет → подливет
# потихоньку ← по-тихоньку → по-тихоньку
# планируем ← планируем → планирует
# развиться ← развицо → развито
# мужчина ← мущщина → мущщина
# параллельно ← паралелльно → паралелльно
# трата ← трата → брата
# постарайтесь ← прстарайтесь → прстарайтесь
# аборигенку ← абоpигенку → абоpигенку
# приезжей ← пpиезжей → пpиезжей
# насчет ← нащет → нащет
# почувствовав ← почувстовав → почувстовав
# поешьте ← поеште → поеште
# насчет ← нащет → нащет
# yкладываются ← yкладываются → складываются
# котоpых ← котоpых → которых
# не ← ни → ни
# очень ← ооочень → ооочень
# потрясающая ← потресающия → потресающия
# преподавательница ← преподовательница → преподовательница
# нравятся ← нравяться → нравяться
# счастливая ← счастлиывая → счастлиывая
# кошка ← кошшшшка → кошшшшка
# мягче ← мягше → мягше
# кто-то ← ктото → ктото
# кто-то ← ктото → ктото
# кто-то ← ктото → ктото
# естественно ← естесственно → естесственно
# сегодня ← седня → седня
# принципы ← приниципы → приниципы
# применяю ← применяю → применяют
# естественно ← естесственно → естесственно
# одиночеством ← одночеством → одночеством
# желаньем ← желаньем → желанием
# просмотр ← просмотер → просмотер
# контакте ← контакти → контакты
# естественно ← естесственно → естесственно
# никуда ← нукда → нукда
# ответьте ← ответтье → ответтье
# естественно ← естесственно → естесственно
# минутам ← минутам → минутах
# какие-то ← какие → какие
# плотники ← то → то
# объясняя ← плотники → плотники
# экзаменатору ← объясняя → объясняя
# что ← экзаменатору → экзаменатору
# связались ← что → что
# с ← связались → связались
# ней ← с → с
# через ← ней → ней
# емайл ← через → через
# говорилось ← емайл → емайл
# о ← говорилось → говорилось
# заборе ← о → о
# который ← заборе → заборе
# не ← который → который
# закрывается ← не → не
# затем ← закрывается → закрывается
# зашла ← затем → затем
# не ← зашла → зашла
# знаю ← незнаю → незнаю
# что-то ← чо-то → чо-то
# ничего ← ничо → ничто
# скажи ← сцкажи → сцкажи
# его ← иво → иво
# шоколаде ← шоколаде → шоколада
# придется ← прийдется → прийдется
# совпали ← срвпали → срвпали
# связываем ← связываем → связывает
# заботились ← забоились → забоились
# когда-то ← когдато → когдато
# запятых ← запятых → занятых
# вставлял ← встявлял → встявлял
# позаботьтесь ← позабодтесь → позабодтесь
# пофотографировав ← пофоторафировав → пофоторафировав
# очищенный ← очищеный → очищеный
# новогоднее ← навогоднее → навогоднее
# естественно ← ессно → ессно
# вообще ← ваще → ваще
# постебался ← постибалса → постибалса
# потому ← потсому → потсому
# сногсшибательной ← сногсшибальной → сногсшибальной
# удается ← удеается → удеается
# благодаря ← бплгодаря → бплгодаря
# извините ← извените → извените
# это ← эта → эта
# проверка ← провекрка → провекрка
# когда-то ← когдато → когдато
# девчонки ← девченки → девченки
# написать ← напистаь → напистаь
# стасу ← стасу → стану
# ливня ← ливня → ливия
# пытаюсь ← пыраюсь → пыраюсь
# непредвиденные ← непридвиденные → непридвиденные
# поздравляю ← поздрваляю → поздрваляю
# говорю ← грю → грю
# ничего ← ничо → ничто
# как-то ← както → факто
# хотеться ← хотеццо → хотеццо
# убиться ← убиться → учиться
# веником ← веником → великом
# нравится ← нравиццо → нравиццо
# поздравляю ← посдравляю → посдравляю
# очень ← ооочень → ооочень
# чувствовать ← чувстоввать → чувстоввать
# погода ← погда → когда
# как ← кааак → казак
# как ← каааак → каааак
# поверхностное ← поверхносное → поверхносное
# неискреннее ← неискренное → неискренное
# мастер-классах ← мастре-классах → мастре-классах
# вот ← воооот → воооот
# хочется ← хочеться → хочеться
# съездила ← съездела → съездела
# понаобещал ← понаобещщал → понаобещщал
# неуравновешенно ← неуравновешено → неуравновешено
# центром ← центрм → центра
# сильно ← вильно → вильно
# влево ← влева → слева
# расскажу ← рассказжу → рассказжу
# покажи ← покажиииии → покажиииии
# пожинаем ← поженаем → поженаем
# девчонками ← девочнками → девочнками
# придется ← придеться → придеться
# некоторым ← некотороым → некотороым
# действие ← дейстиве → дейстиве
# лекарствами ← лекарствоми → лекарствоми
# собственно ← собсно → собсно
# прямо ← пррямо → пррямо
# зуб ← ззуб → ззуб
# зуб ← ззуб → ззуб
# попадает ← поппадает → поппадает
# как-то ← какето → какето
# изюминку ← изуминку → изуминку
# мне ← мной → мной
# будешь ← будеш → будет
# свои ← сваи → сваи
# описывать ← аписывать → записывать
# чтоб ← шоб → шоб
# расчет ← рассчет → рассвет
# берем ← берем → берег
# ничего ← ничо → ничто
# совладав ← совлаладав → совлаладав
# мудрейший ← мудреший → мудреший
# прочитала ← прочтала → прочтала
# жизнь ← жизни → жизни
# очень ← оччень → оччень
# неожиданно ← неожиданнго → неожиданнго
# прекратите ← прератите → прератите
# собственно ← собссно → собссно
# хочется ← хочеться → хочеться
# 1089 ошибок из 9995 слов
# Точность: 0.891

# %% [markdown]
# 1089 ошибок из 9995 слов
#
# Точность: 0.891
